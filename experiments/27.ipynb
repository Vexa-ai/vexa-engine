# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('/app')

# %%
from content_manager import ContentManager

# %%
content_manager = await ContentManager.create()

await content_manager.get_contents(user_id='f05bd139-3fa1-4563-a900-2516dffb67b3')
# Out:
# {'total': 162,
#  'contents': [{'content_id': '0349a69c-8028-49e5-8d20-7906e4e1d5dd',
#    'type': 'meeting',
#    'text': None,
#    'timestamp': datetime.datetime(2024, 9, 5, 9, 16, 22),
#    'is_indexed': True,
#    'is_owner': True,
#    'access_level': 'owner',
#    'entities': []},
#   {'content_id': '048c81b0-359c-463f-8159-4ccbca8bf185',
#    'type': 'meeting',
#    'text': None,
#    'timestamp': datetime.datetime(2025, 1, 28, 10, 44, 41),
#    'is_indexed': False,
#    'is_owner': True,
#    'access_level': 'owner',
#    'entities': []},
#   {'content_id': '05016b38-185d-4bb9-9ccf-2352775a4522',
#    'type': 'meeting',
#    'text': None,
#    'timestamp': datetime.datetime(2024, 11, 8, 20, 33, 54),
#    'is_indexed': True,
#    'is_owner': True,
#    'access_level': 'owner',
#    'entities': []},
#   {'content_id': '07e1c53a-5157-4cfb-9a56-7672ad3482d9',
#    'type': 'meeting',
#    'text': None,
#    'timestamp': datetime.datetime(2025, 1, 14, 18, 31, 55),
# ...
