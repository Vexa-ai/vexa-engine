# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('/app')

# %%
from sqlalchemy import select, func
from psql_models import Content, ContentType
from psql_helpers import get_session

async def count_notes():
    async with get_session() as session:
        query = select(func.count()).select_from(Content).where(Content.type == ContentType.NOTE.value)
        result = await session.scalar(query)
        return result

# To execute:
note_count = await count_notes()
print(f"Total notes: {note_count}")
# Out:
# Total notes: 213

# %%
import os
API_URL = os.getenv('API_URL')

# %%
from api_client import APIClient

client = APIClient()


await client.set_email("dmitrygrankin0@gmail.com")

# %%
from psql_helpers import get_session
from sqlalchemy import select
from psql_models import Thread

# %%
async def debug_threads():
    async with get_session() as session:
        # Get all threads for user
        all_threads = await session.execute(
            select(Thread)
        )
        threads = all_threads.scalars().all()
        
        print(f"Total threads: {len(threads)}")
        print("\nThread details:")
        for t in threads:
            print(f"Thread ID: {t.thread_id}")
            print(f"Content ID: {t.content_id}")
            print(f"Thread name: {t.thread_name}")
            print("---")

# %%
await debug_threads()
# Out:
# Total threads: 6
#
# Thread details:
# Thread ID: 90dce980-5dff-4559-9e25-c59a39f6fce0
# Content ID: None
# Thread name: and the last person you mentioned name is?
# ---
# Thread ID: ff7aaa47-23e7-4af7-b871-4528e4272a72
# Content ID: None
# Thread name: and the last person you mentioned name is?
# ---
# Thread ID: ef7f61aa-4602-448b-aeed-622b47a741d0
# Content ID: None
# Thread name: who is this guy?
# ---
# Thread ID: 08bef20f-fccf-4fd9-bdf8-53b25839aae6
# Content ID: None
# Thread name: and the last person you mentioned name is?
# ---
# Thread ID: fe1307f9-0216-489f-8440-f9643cb96f17
# Content ID: 10f8dbae-e76a-4b59-b6db-1ef9a381c4d9
# Thread name: What is this document about?
# ---
# Thread ID: 6dc737f7-4cb9-40e0-a947-b871ac3a5dd1
# Content ID: a7ab7b39-ed6a-429e-988f-00191e477c69
# Thread name: What is this document about?
# ---

# %%
client.get_threads_by_entities(meeting_ids=['6a3451aa-f18c-4211-8140-fbc77ea7ba05'], entity_names=['Dmitry Grankin'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 client.get_threads_by_entities(meeting_ids=['6a3451aa-f18c-4211-8140-fbc77ea7ba05'], entity_names=['Dmitry Grankin'])
#
# AttributeError: 'APIClient' object has no attribute 'get_threads_by_entities'

# %%
client.get_threads(meeting_id='6a3451aa-f18c-4211-8140-fbc77ea7ba05')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 client.get_threads(meeting_id='6a3451aa-f18c-4211-8140-fbc77ea7ba05')
#
# TypeError: APIClient.get_threads() got an unexpected keyword argument 'meeting_id'

# %%
client.get_global_threads()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 client.get_global_threads()
#
# AttributeError: 'APIClient' object has no attribute 'get_global_threads'

# %%
await client.get_meetings()
# Out:
# {'total': 769,
#  'meetings': [{'meeting_id': 'f3eb1b39-c725-4ecf-8c4d-bd78eac81273',
#    'timestamp': '2024-12-20T18:01:42',
#    'is_indexed': True,
#    'access_level': 'owner',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin', 'Windy Hell']},
#   {'meeting_id': '794b68e5-0dc5-4cb4-b221-c42e338b6743',
#    'timestamp': '2024-12-20T13:25:41',
#    'is_indexed': True,
#    'access_level': 'owner',
#    'is_owner': True,
#    'speakers': ['Anton Saburov', 'Dmitriy Grankin']},
#   {'meeting_id': '84e9c288-12b7-435e-a2a2-fb54be218082',
#    'timestamp': '2024-12-20T13:20:12',
#    'is_indexed': False,
#    'access_level': 'owner',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin', 'Sergey Ryabenko']},
#   {'meeting_id': '3931f60c-93bd-425b-8a94-7ca645630bf3',
#    'timestamp': '2024-12-19T16:28:37',
#    'is_indexed': True,
#    'access_level': 'owner',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin']},
#   {'meeting_id': 'ca5db174-1c96-4067-9297-51faacbe15f4',
#    'timestamp': '2024-12-19T12:08:39',
#    'is_indexed': True,
#    'access_level': 'owner',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin']},
#   {'meeting_id': '6a3451aa-f18c-4211-8140-fbc77ea7ba05',
#    'timestamp': '2024-12-13T11:30:24',
#    'is_indexed': True,
#    'access_level': 'owner',
#    'is_owner': True,
#    'speakers': ['Dmitry Grankin', 'Viktoria Kharlamova']},
#   {'meeting_id': '77af4031-a5a9-4dae-ad90-80d12bdadde0',
#    'timestamp': '2024-12-12T16:00:31',
#    'is_indexed': True,
#    'access_level': 'owner',
#    'is_owner': True,
#    'speakers': ['AI Marketing Directory', 'Dmitry Grankin']},
#   {'meeting_id': '860f9495-13a2-486e-8abf-3b5a3ec22a48',
#    'timestamp': '2024-12-12T09:59:27',
#    'is_indexed': False,
#    'access_level': 'owner',
#    'is_owner': True,
#    'speakers': ['Dmitry Grankin', 'Евгения Садовская', 'Елизавета Иванова']},
#   {'meeting_id': '4f64ba1e-fd80-4b5d-a1be-345225028f6c',
#    'timestamp': '2024-12-11T18:30:54',
#    'is_indexed': True,
#    'access_level': 'owner',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin', 'Lara Vargas']},
#   {'meeting_id': '2a92e93e-dc1c-455d-acbb-182555197434',
#    'timestamp': '2024-12-10T11:01:14',
#    'is_indexed': True,
#    'access_level': 'owner',
#    'is_owner': True,
#    'speakers': ['Dmitry Grankin', 'Waqas Arshad']},
#   {'meeting_id': '15af0212-e418-4476-8586-085581bfd8c9',
#    'timestamp': '2024-12-06T16:21:25',
#    'is_indexed': True,
#    'access_level': 'owner',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin']},
#   {'meeting_id': '161f80a4-135f-4aa4-b2fc-84dec9d6445c',
#    'timestamp': '2024-12-06T12:04:36',
#    'is_indexed': True,
#    'access_level': 'owner',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin']},
#   {'meeting_id': '7a2b0c2f-c043-427c-b2a0-68e9a6a18b34',
#    'timestamp': '2024-12-06T10:30:30',
#    'is_indexed': True,
#    'access_level': 'owner',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin']},
#   {'meeting_id': 'd6b623d8-542e-40ed-8660-cdb9efceaf81',
#    'timestamp': '2024-12-05T19:00:52',
#    'is_indexed': True,
#    'access_level': 'owner',
#    'is_owner': True,
#    'speakers': ['Dmitry Grankin', 'Lara Vargas']},
#   {'meeting_id': 'e4b4ba0c-1249-400a-81eb-469361572591',
#    'timestamp': '2024-12-05T13:59:50',
#    'is_indexed': True,
#    'access_level': 'owner',
#    'is_owner': True,
#    'speakers': ['Dmitry Grankin', 'Nora Köppling', 'Sunny Wyrzykowski']},
#   {'meeting_id': '2182def0-c078-45f6-bce1-cbac254c8007',
#    'timestamp': '2024-12-05T11:02:05',
#    'is_indexed': True,
#    'access_level': 'owner',
#    'is_owner': True,
#    'speakers': ['Alex Shevliakov', 'Dmitry Grankin']},
#   {'meeting_id': '5401ff51-4f8f-4f95-a5d2-21564c9b3cc4',
#    'timestamp': '2024-12-05T10:02:10',
#    'is_indexed': True,
#    'access_level': 'owner',
#    'is_owner': True,
#    'speakers': ['Dmitry Grankin', 'Oleg Ageychev']},
#   {'meeting_id': '2a40c363-c52b-4f89-8719-e0be87591485',
#    'timestamp': '2024-12-04T15:31:04',
#    'is_indexed': True,
#    'access_level': 'owner',
#    'is_owner': True,
#    'speakers': ['Dmitry Grankin', 'Jasper Vanuytrecht']},
#   {'meeting_id': '21d4d45e-19c3-40c3-ad9d-277b5dc7405b',
#    'timestamp': '2024-12-03T18:40:42',
#    'is_indexed': True,
#    'access_level': 'owner',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin', 'Sergio Goriachev']},
#   {'meeting_id': 'a7973009-1387-47e4-a0cc-19694593194f',
#    'timestamp': '2024-12-03T14:31:18',
#    'is_indexed': False,
#    'access_level': 'owner',
#    'is_owner': True,
#    'speakers': ['Aleksandr Lavrinenko', 'Dmitry Grankin']},
#   {'meeting_id': '7bac546e-43b4-48f1-8347-35d567c805df',
#    'timestamp': '2024-12-03T14:01:01',
#    'is_indexed': True,
#    'access_level': 'owner',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin', 'Sergio Goriachev']},
#   {'meeting_id': 'e85a7645-53aa-4e18-92a9-09a5b1886f30',
#    'timestamp': '2024-12-03T13:01:15',
#    'is_indexed': True,
#    'access_level': 'owner',
#    'is_owner': True,
#    'speakers': ['Anna Pavlova (Lupenko)', 'Dmitry Grankin']},
#   {'meeting_id': '8eb8d512-2ba3-40f4-8535-8bba86779336',
#    'timestamp': '2024-12-03T11:05:12',
#    'is_indexed': True,
#    'access_level': 'owner',
#    'is_owner': True,
#    'speakers': ['Daniel', 'Dmitriy Grankin']},
#   {'meeting_id': '08b8398e-0b1b-4771-9516-f414888dc500',
#    'timestamp': '2024-12-03T10:23:18',
#    'is_indexed': True,
#    'access_level': 'owner',
#    'is_owner': True,
#    'speakers': []},
#   {'meeting_id': '33c14d85-55c7-4bce-854f-eb9e617c9ea5',
#    'timestamp': '2024-12-02T17:27:37',
#    'is_indexed': True,
#    'access_level': 'owner',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin']},
#   {'meeting_id': 'b2df54b2-e91e-4d41-bd4a-48c8fc99e5fb',
#    'timestamp': '2024-12-02T15:29:11',
#    'is_indexed': False,
#    'access_level': 'owner',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin', 'Igor Lyubimov']},
#   {'meeting_id': '1579143f-3d96-4346-9220-febb329ca5ce',
#    'timestamp': '2024-12-02T12:10:14',
#    'is_indexed': False,
#    'access_level': 'owner',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin', 'Tatiana Sukhova']},
#   {'meeting_id': '16705c46-ba51-4f1b-83d2-08e0bfc5eae5',
#    'timestamp': '2024-11-28T13:12:02',
#    'is_indexed': False,
#    'access_level': 'owner',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin']},
#   {'meeting_id': '8c21aec2-1d7c-4bb6-95da-c2d66085f85a',
#    'timestamp': '2024-11-26T16:29:52',
#    'is_indexed': False,
#    'access_level': 'owner',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin', 'Olga Nemirovskaya']},
#   {'meeting_id': '8f275c86-e397-43fe-a884-b4535f7f82e3',
#    'timestamp': '2024-11-26T15:01:49',
#    'is_indexed': False,
#    'access_level': 'owner',
#    'is_owner': True,
#    'speakers': ['Alisa Molokova', 'Dmitry Grankin']},
#   {'meeting_id': 'a5fe10ae-2525-44a5-8931-7033c353973c',
#    'timestamp': '2024-11-25T21:21:40',
#    'is_indexed': False,
#    'access_level': 'owner',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin']},
#   {'meeting_id': '317ddaa3-711c-482f-b830-4ee924963b70',
#    'timestamp': '2024-11-25T21:06:50',
#    'is_indexed': False,
#    'access_level': 'owner',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin']},
#   {'meeting_id': '61b8db8b-f0c6-4895-8ca2-00e82466c8da',
#    'timestamp': '2024-11-25T20:50:49',
#    'is_indexed': False,
#    'access_level': 'owner',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin']},
#   {'meeting_id': '4b253b0e-6b15-452a-b66c-da5f06ec3fcf',
#    'timestamp': '2024-11-25T20:17:18',
#    'is_indexed': False,
#    'access_level': 'owner',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin']},
#   {'meeting_id': 'd44d0430-2754-428b-b934-9264c255578c',
#    'timestamp': '2024-11-25T19:45:30',
#    'is_indexed': False,
#    'access_level': 'owner',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin']},
#   {'meeting_id': '1e98ec1a-891f-4e89-bca5-9be39c8a4856',
#    'timestamp': '2024-11-25T15:20:48',
#    'is_indexed': False,
#    'access_level': 'owner',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin']},
#   {'meeting_id': '7781e37d-f733-4bfc-ad18-041e8ba20231',
#    'timestamp': '2024-11-25T14:56:51',
#    'is_indexed': False,
#    'access_level': 'owner',
#    'is_owner': True,
#    'speakers': []},
#   {'meeting_id': '0220af3b-b112-47c5-b65f-6e75778c0842',
#    'timestamp': '2024-11-25T13:53:17',
#    'is_indexed': False,
#    'access_level': 'owner',
#    'is_owner': True,
#    'speakers': []},
#   {'meeting_id': '21a176db-7ff4-4c3c-a806-d6437a635388',
#    'timestamp': '2024-11-25T13:38:29',
#    'is_indexed': False,
#    'access_level': 'owner',
#    'is_owner': True,
#    'speakers': []},
#   {'meeting_id': '3f6ac1da-0bd8-4681-825a-4b29c68a61f6',
#    'timestamp': '2024-11-25T13:30:49',
#    'is_indexed': False,
#    'access_level': 'owner',
#    'is_owner': True,
#    'speakers': []},
#   {'meeting_id': '13c8cb72-9421-4181-a782-db4d66f12481',
#    'timestamp': '2024-11-25T13:11:33',
#    'is_indexed': False,
#    'access_level': 'owner',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin']},
#   {'meeting_id': '8056a2ad-0c94-4654-b888-321c68e6174c',
#    'timestamp': '2024-11-25T12:53:50',
#    'is_indexed': False,
#    'access_level': 'owner',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin']},
#   {'meeting_id': 'c0b22605-f51f-4307-bbbc-d873fe21f4e8',
#    'timestamp': '2024-11-25T11:47:50',
#    'is_indexed': False,
#    'access_level': 'owner',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin']},
#   {'meeting_id': '257b078d-2ae6-4cfe-8456-b95f7cc8bec1',
#    'timestamp': '2024-11-25T10:13:50',
#    'is_indexed': False,
#    'access_level': 'owner',
#    'is_owner': True,
#    'speakers': []},
#   {'meeting_id': 'bb03116a-9a62-4196-8bad-c4322095a8a3',
#    'timestamp': '2024-11-24T22:42:09',
#    'is_indexed': False,
#    'access_level': 'owner',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin']},
#   {'meeting_id': '361335a4-f97f-44b6-a0ba-aa2e81d74f88',
#    'timestamp': '2024-11-24T22:09:02',
#    'is_indexed': False,
#    'access_level': 'owner',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin']},
#   {'meeting_id': 'cc46bac8-a4f1-404d-b07d-d2e2231d15d8',
#    'timestamp': '2024-11-24T21:44:17',
#    'is_indexed': False,
#    'access_level': 'owner',
#    'is_owner': True,
#    'speakers': []},
#   {'meeting_id': 'f22e2fd3-8e15-4b7e-8d14-076b3bbb50af',
#    'timestamp': '2024-11-24T20:49:40',
#    'is_indexed': False,
#    'access_level': 'owner',
#    'is_owner': True,
#    'speakers': []},
#   {'meeting_id': 'a4ed2674-b383-4d2d-992c-d85ade04d21a',
#    'timestamp': '2024-11-24T20:24:25',
#    'is_indexed': False,
#    'access_level': 'owner',
#    'is_owner': True,
#    'speakers': []},
#   {'meeting_id': '5738f21e-7b78-41bc-84d9-cb0bbbc24c12',
#    'timestamp': '2024-11-24T14:53:49',
#    'is_indexed': False,
#    'access_level': 'owner',
#    'is_owner': True,
#    'speakers': []}]}

# %%
from IPython.display import clear_output, display, Markdown
from typing import Optional, List
from functools import wraps
from helpers import jupyter_stream_output

@jupyter_stream_output(markdown=True)
async def stream_chat(
    client,
    query: str,
    meeting_id: Optional[str] = None,
    entities: Optional[List[str]] = None,
    thread_id: Optional[str] = None,
    model: str = "gpt-4o-mini",
    temperature: float = 0.7
):
    response = client.chat(
        query=query,
        meeting_id=meeting_id,
        entities=entities,
        thread_id=thread_id,
        model=model,
        temperature=temperature
    )
    yield response

# %%
await stream_chat(
    client=client,
    query="hah?",
    thread_id="83e4427b-ad06-4586-bded-47a51e50377d",
)
# Out:
# {'thread_id': '83e4427b-ad06-4586-bded-47a51e50377d',
#  'linked_output': 'It seems there might have been some confusion in my previous response. The context provided includes various conversations among different individuals, but it doesn\'t specify who "these guys" are in your question. \n\nIf you could clarify which individuals or context you are referring to, I would be happy to provide more information!'}

# %%
# Out:
# <Response [500]>
