# %%
{
            "meeting_id": "e77ea83e-fe07-4e8b-879b-2939f208775f",
            "meeting_name": "тестирование",
            "timestamp": "2024-11-01T12:34:48",
            "is_indexed": true,
            "meeting_summary": "Процесс проверки работы системы.",
            "access_level": "OWNER",
            "is_owner": true,
            "speakers": [
                "nan (0)"
            ]
        {
        {
            "meeting_id": "c6bd2072-dcd6-45b9-8006-7b975bfe43ad",
            "meeting_name": "Увеличение видимости продуктов",
            "timestamp": "2024-10-04T11:09:37",
            "is_indexed": true,
            "meeting_summary": "Обсуждение **текущего статуса продуктов** на **Product Hunter**, включая их **видимость** и **позиции** в списках. Обсуждали, что некоторые продукты не показываются на главном экране, и что необходимо **улучшить видимость**, чтобы попасть в **первую десятку**. Также была поднята **необходимость ответов на комментарии пользователей** для повышения **вовлеченности** и **активности** в социальных сетях. Обсуждали **стратегию** по выходу в первую десятку, создание новых постов и анализ активных аккаунтов для взаимодействия.",
            "access_level": "search",
            "is_owner": true,
            "speakers": [
                "Dmitriy Grankin",
                "Olga Nemirovskaya"
            ]
        },
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('/app')

# %%
from vexa import VexaAPI, VexaAuth
from chat import MeetingSummaryContextProvider
from psql_helpers import get_session
vexa = VexaAPI()
await vexa.get_user_info()
# Out:
# Vexa token: 3ae04e20124d40babc5107e658c666b6
# User information retrieved successfully.
# {'id': 'ef7c085b-fdb5-4c94-b7b6-a61a3d04c210',
#  'email': '2280905@gmail.com',
#  'is_allowed_send_init_message': True,
#  'username': 'Dmitriy Grankin',
#  'first_name': 'Dmitriy',
#  'last_name': 'Grankin',
#  'image': None,
#  'created_timestamp': '2024-05-28T11:16:50.894711Z',
#  'updated_timestamp': '2024-11-28T15:25:57.256425Z'}

# %%
vexa.token
# Out:
# '3ae04e20124d40babc5107e658c666b6'

# %%
from psql_models import Meeting

# %%
from psql_helpers import read_table_async
await read_table_async(Meeting)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
from typing import List, Dict
import requests
BASE_URL = "http://localhost:8765"
headers = {"Authorization": f"Bearer {vexa.token}", "Content-Type": "application/json"}

# %%
user_id = vexa.user_id

# %%
meeting_id = '8c21aec2-1d7c-4bb6-95da-c2d66085f85a'

# %%
meeting_ids = [meeting_id]

# %%
query = 'what is it about?'

# %%
from prompts import Prompts
prompts = Prompts()
from chat import MeetingChatManager

# %%
prompt = prompts.single_meeting_2711

# %%
from helpers import jupyter_stream_output
from uuid import UUID

# %%
thread_id = None

# %%
@jupyter_stream_output(markdown=True)
async def chat_with_meeting(user_id: str, meeting_ids: list[UUID], query: str,thread_id: str):
    async with get_session() as session:
        summary_provider = MeetingSummaryContextProvider(meeting_ids, include_discussion_points=True)
        chat_manager = MeetingChatManager(session, context_provider=summary_provider)
        async for response in chat_manager.chat(
            user_id=user_id,
            query=query,
            meeting_ids=meeting_ids,
            thread_id=thread_id,
            temperature=0.7,
            prompt=prompt
        ):
            yield response

# Usage
response = await chat_with_meeting(
    thread_id=thread_id,
    user_id='ef7c085b-fdb5-4c94-b7b6-a61a3d04c210',
    meeting_ids=meeting_ids,
    query="custdev report, customer is Olga"
)
# Out:
# ## Short Summary
#
# The meeting focused on discussing issues and suggestions regarding meeting transcriptions. Olga Nemirovskaya expressed difficulties accessing the transcript during the meeting, and Dmitriy Grankin confirmed he faced similar challenges. They proposed improvements to the interface, sorting methods, and the implementation of a tagging system for better navigation and access to information.
#
# ## Main Points
#
# - Ольга Немировская не смогла открыть транскрипт во время встречи, что затруднило работу [Quote IDs 1-2].
#
# - Ольга предложила улучшить интерфейс для более удобного доступа к транскриптам и встречам, упомянув, что текущий интерфейс занимает слишком много места [Quote IDs 3-5].
#
# - Ольга предложила сортировать встречи по датам вместо спикеров, чтобы упростить поиск информации [Quote IDs 6-7].
#
# - Дмитрий предложил внедрить систему тегов для упрощения поиска встреч [Quote IDs 8-9].
#
# ...

# %%
stream_response()
async with get_session() as session:
# Out:
# <async_generator object stream_response at 0x7f771d2acb80>

# %%
async with get_session() as session:
    context = await context_provider.get_context(session, meeting_ids=meeting_ids)

# %%
print(context)
# Out:
# Meeting: Проблемы и предложения по транскрипции встреч
# Date: 2024-11-26 16:29:58.260000
# Summary:
# **Ольга Немировская** не смогла открыть **транскрипт** во время встречи, что затруднило работу. **Дмитрий Гранкин** подтвердил, что у него также возникли трудности с открытием. Ольга предложила улучшить **интерфейс** для более удобного доступа к **транскриптам** и встречам, отметив, что текущий интерфейс занимает слишком много места. Она также предложила сортировать встречи по **датам** вместо **спикеров**. Дмитрий предложил внедрить систему **тегов** для упрощения поиска встреч. Ольга и Дмитрий столкнулись с проблемами отображения информации на экране и обсудили использование **чата** и **транскриптов** в работе. Ольга отметила, что не всегда может быстро найти нужную информацию о встречах, что затрудняет ее работу. Обсуждались различные платформы для транскрипции встреч и их функционал, а также необходимость интеграции с **CRM**.
#
# Discussion Points:
# ...

# %%
from core import count_tokens

# %%
count_tokens(context)
# Out:
# 16083
