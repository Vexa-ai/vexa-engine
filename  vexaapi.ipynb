# %%
import sys
sys.path.append('/app')

# %%
from vexa import VexaAPI

vexa_api = VexaAPI()
# Out:
# Vexa token: 3ae04e20124d40babc5107e658c666b6

# %%
await vexa_api.get_meetings()
# Out:
# Request URL: http://host.docker.internal:8001/api/v1/calls/all
# Request Params: {'token': '3ae04e20124d40babc5107e658c666b6'}
# [{'id': 'bc0bcb5d-5d27-437e-9be9-1d368bdcdcd3',
#   'title': 'call_2024-06-03T09:14:48.631110+00:00',
#   'start_timestamp': '2024-06-03T09:14:48.631110Z',
#   'finish_timestamp': '2024-06-13T09:37:41.113555Z',
#   'meeting': {'id': 'cd81c41a-0eba-4021-93e2-f740d95df46e',
#    'external_id': 'qyo-vkuc-ubb',
#    'title': None},
#   'speakers': []},
#  {'id': '53cca12b-daee-49b3-9276-ec708043a023',
#   'title': 'call_2024-06-03T09:31:12.228905+00:00',
#   'start_timestamp': '2024-06-03T09:31:12.228905Z',
#   'finish_timestamp': '2024-06-13T10:28:22.068485Z',
#   'meeting': {'id': '85f9c1e3-c299-48a2-a660-2a77b8af8991',
#    'external_id': 'csx-mskk-qyk',
#    'title': None},
#   'speakers': []},
#  {'id': '7e58a9c6-047b-478b-8f41-922b6ef137c2',
#   'title': 'call_2024-06-03T10:27:38.112013+00:00',
#   'start_timestamp': '2024-06-03T10:27:38.112013Z',
# ...

# %%
df, _, start_datetime, speakers, transcript = await vexa_api.get_transcription(meeting_session_id='bc0bcb5d-5d27-437e-9be9-1d368bdcdcd3')

# %%
transcript
# Out:
# [{'speaker': 'Aurora Guardian',
#   'speaker_id': 'TBD',
#   'content': ' Субтитры сделал DimaTorzok Hi guys!',
#   'html_content': None,
#   'html_content_short': None,
#   'keywords': [],
#   'timestamp': '2024-06-03T09:15:29.715110Z'},
#  {'speaker': 'Aurora Guardian',
#   'speaker_id': 'TBD',
#   'content': ' Привет.',
#   'html_content': None,
#   'html_content_short': None,
#   'keywords': [],
#   'timestamp': '2024-06-03T09:15:46.283110Z'},
#  {'speaker': 'Aurora Guardian',
#   'speaker_id': 'TBD',
#   'content': ' Good morning, guys.',
#   'html_content': None,
#   'html_content_short': None,
#   'keywords': [],
#   'timestamp': '2024-06-03T09:16:02.447110Z'},
#  {'speaker': 'Aurora Guardian',
#   'speaker_id': 'TBD',
#   'content': ' Good morning.',
#   'html_content': None,
#   'html_content_short': None,
#   'keywords': [],
#   'timestamp': '2024-06-03T09:16:04.327110Z'},
#  {'speaker': 'Lunar Spider',
#   'speaker_id': 'TBD',
#   'content': ' Ok...',
# ...
