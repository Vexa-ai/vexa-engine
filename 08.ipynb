# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import pandas as pd
from sampling import fetch_joined_data,WeightedSampler

# %%
joined_df = await fetch_joined_data()
joined_df['meeting_time'] = pd.to_datetime(joined_df['meeting_timestamp']).dt.strftime('%Y-%m-%d')

# %%
sampler = WeightedSampler(joined_df, date_column='meeting_time',decay_factor=0.2)
sampled_redults = sampler.sample(n_samples=100)  # mode defaults to 'recency'

# %%
def get_unique_value_counts(df, columns, format_output=False):
    """
    Returns unique values and their counts for specified columns.
    
    Args:
        df (pd.DataFrame): Input dataframe
        columns (list): List of column names to analyze
        format_output (bool): If True, returns formatted string instead of dict
    
    Returns:
        dict or str: Dictionary of value counts or formatted string if format_output=True
    """
    result = {}
    
    for col in columns:
        try:
            value_counts = df[col].value_counts()
            value_dict_list = [{'value': value, 'count': count} 
                             for value, count in value_counts.items()]
            result[col] = value_dict_list
        except (TypeError, AttributeError):
            value_counts = df[col].astype(str).value_counts()
            value_dict_list = [{'value': value, 'count': count} 
                             for value, count in value_counts.items()]
            result[col] = value_dict_list
    
    if format_output:
        output_str = ""
        for col, value_list in result.items():
            output_str += f"\n{col}:\n"
            for item in value_list:
                output_str += f"  {item['value']}: {item['count']}\n"
        return output_str.strip()
    
    return result

# Get dictionary result
dict_result = get_unique_value_counts(joined_df, ['topic_type', 'topic_name', 'speaker_name'])

# Get formatted string result
str_result = get_unique_value_counts(joined_df, ['topic_type', 'topic_name', 'speaker_name'], format_output=True)

# %%
from core import BaseCall,system_msg,user_msg
from pydantic import BaseModel,Field
from datetime import datetime
from typing import Optional,List

# %%
class DateRange(BaseModel):
    start_date: Optional[datetime] = Field(None, description="Start date of the range")
    end_date: Optional[datetime] = Field(None, description="End date of the range")

class SearchFilter(BaseModel):
    topic_type: Optional[List[str]] = Field(None, description="List of topic types to filter by")
    topic_name: Optional[List[str]] = Field(None, description="List of topic names to filter by")
    speaker_name: Optional[List[str]] = Field(None, description="List of speaker names to filter by")
    date_range: Optional[DateRange] = Field(None, description="Date range to filter by")
    search_text: Optional[str] = Field(None, description="Text to search for in summary and details columns using similarity search")

# %%
def apply_search_filters(df: pd.DataFrame, filters: SearchFilter) -> pd.DataFrame:
    """
    Apply SearchFilter parameters to filter a DataFrame.
    
    Args:
        df (pd.DataFrame): Input DataFrame
        filters (SearchFilter): Search parameters
        
    Returns:
        pd.DataFrame: Filtered DataFrame
    """
    filtered_df = df.copy()
    
    # Apply list-based filters
    if filters.topic_type:
        filtered_df = filtered_df[filtered_df['topic_type'].isin(filters.topic_type)]
    
    if filters.topic_name:
        filtered_df = filtered_df[filtered_df['topic_name'].isin(filters.topic_name)]
        
    if filters.speaker_name:
        filtered_df = filtered_df[filtered_df['speaker_name'].isin(filters.speaker_name)]
    
    # Apply date range filter if provided
    if filters.date_range:
        if filters.date_range.start_date:
            filtered_df = filtered_df[
                pd.to_datetime(filtered_df['meeting_time']) >= filters.date_range.start_date
            ]
        if filters.date_range.end_date:
            filtered_df = filtered_df[
                pd.to_datetime(filtered_df['meeting_time']) <= filters.date_range.end_date
            ]
    
    # Apply text search if provided
    # Note: This assumes you have a text similarity search function
    # You might want to implement this based on your specific needs
    if filters.search_text:
        # Example using simple substring matching
        # Replace this with your actual similarity search implementation
        text_mask = (
            filtered_df['summary'].str.contains(filters.search_text, case=False, na=False) |
            filtered_df['details'].str.contains(filters.search_text, case=False, na=False)
        )
        filtered_df = filtered_df[text_mask]
    
    return filtered_df

# %%
class SearchParams(BaseCall):
    plan: SearchPlan = Field(..., description="Search plan with current step and feedback")
    
    @classmethod
    async def extract(cls, user_query: str, table_context: str, sampled_df: pd.DataFrame, 
                     previous_results: Optional[pd.DataFrame] = None, 
                     current_results: Optional[pd.DataFrame] = None,
                     step_number: int = 1,
                     model: str = "gpt-4o-mini", 
                     use_cache: bool = False, 
                     force_store: bool = False):
        current_time = datetime.now()
        
        # Convert sampled results to a readable format
        sample_context = f"""Sample of recent records:
{sampled_df[['meeting_time', 'topic_type', 'topic_name', 'speaker_name']].head().to_markdown()}
"""
        
        # Add current results context if available
        results_context = ""
        if current_results is not None:
            results_context = f"""
Current search results:
{current_results[['meeting_time', 'topic_type', 'topic_name', 'speaker_name', 'summary']].head().to_markdown()}
Total results: {len(current_results)} entries
"""
        
        output = await cls.call([
            system_msg("""Plan and execute a multi-step search strategy to thoroughly answer the user's query.
                      Use the provided table context to identify and handle variations and possible misspellings.
                      
                      For each step:
                      1. Check the table context for all relevant variations of search terms
                      2. Include all valid variations in the search filters
                      3. Analyze current results if available
                      4. Reflect on whether results are sufficient to answer the query
                      5. Determine if additional search steps are needed
                      
                      When reflecting on results, consider:
                      - Do we have enough context about all mentioned entities?
                      - Are we capturing all relevant time periods?
                      - Have we found all important perspectives/opinions?
                      - Are the results specific enough to answer the query?
                      - Would additional filters help focus the results?
                      
                      Provide a quality score (0-1) based on:
                      - Relevance to the query
                      - Completeness of the answer
                      - Specificity of the results
                      - Coverage of different aspects
                      
                      Include key findings that summarize what we've learned from the results."""),
            user_msg(f"""Current datetime: {current_time}

Table context showing available values:
{table_context}

{sample_context}
{results_context}

User query: {user_query}
Current step: {step_number}

Plan the search strategy and reflect on current results.""")
        ], model=model, use_cache=use_cache, force_store=force_store)
        
        return output[0].plan
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 class SearchParams(BaseCall):
#       2     plan: SearchPlan = Field(..., description="Search plan with current step and feedback")
#       4     @classmethod
#       5     async def extract(cls, user_query: str, table_context: str, sampled_df: pd.DataFrame,
#       6                      previous_results: Optional[pd.DataFrame] = None,
#    (...)
#      10                      use_cache: bool = False,
#      11                      force_store: bool = False):
#
# Cell In[9], line 2, in SearchParams()
#       1 class SearchParams(BaseCall):
# ----> 2     plan: SearchPlan = Field(..., description="Search plan with current step and feedback")
#       4     @classmethod
#       5     async def extract(cls, user_query: str, table_context: str, sampled_df: pd.DataFrame,
#       6                      previous_results: Optional[pd.DataFrame] = None,
#    (...)
#      10                      use_cache: bool = False,
#      11                      force_store: bool = False):
#      12         current_time = datetime.now()
#
# NameError: name 'SearchPlan' is not defined

# %%
class SearchReflection(BaseModel):
    is_sufficient: bool = Field(..., description="Whether current results are sufficient to answer the user query")
    missing_aspects: List[str] = Field(..., description="List of aspects still missing from the results")
    suggested_filters: Optional[SearchFilter] = Field(None, description="Suggested additional filters if needed")
    reasoning: str = Field(..., description="Explanation of why results are/aren't sufficient")
    quality_score: float = Field(..., ge=0, le=1, description="Score indicating how well these results answer the query (0-1)")
    key_findings: List[str] = Field(..., description="List of key insights found in current results")

class SearchPlan(BaseModel):
    steps: List[str] = Field(..., description="List of search steps to execute")
    current_filters: SearchFilter = Field(..., description="Current step search parameters")
    is_final: bool = Field(..., description="Whether this is the final search step")
    feedback: str = Field(..., description="Analysis of current results and next steps needed")
    reflection: Optional[SearchReflection] = Field(None, description="Reflection on search results quality")

async def iterative_search(query: str, joined_df: pd.DataFrame, context: str, sampled_df: pd.DataFrame, verbose: bool = True):
    all_iterations = []  # Store all iteration results and their reflections
    results = None
    step = 1
    best_score = 0
    best_results = None
    
    while True:
        if verbose:
            print(f"\n=== Step {step} ===")
            
        # Get search plan for current step
        search_plan = await SearchParams.extract(
            user_query=query,
            table_context=context,
            sampled_df=sampled_df,
            previous_results=results,
            current_results=results,  # Pass current results for reflection
            step_number=step
        )
        
        if verbose:
            print("\nSearch Plan:")
            print(f"Steps: {search_plan.steps}")
            print(f"Current Filters: {search_plan.current_filters}")
            print(f"Feedback: {search_plan.feedback}")
            if search_plan.reflection:
                print("\nReflection:")
                print(f"Sufficient: {search_plan.reflection.is_sufficient}")
                print(f"Missing aspects: {search_plan.reflection.missing_aspects}")
                print(f"Quality Score: {search_plan.reflection.quality_score}")
                print(f"Key Findings: {search_plan.reflection.key_findings}")
                print(f"Reasoning: {search_plan.reflection.reasoning}")
        
        # Apply current filters
        current_results = apply_search_filters(joined_df, search_plan.current_filters)
        
        if verbose:
            print(f"\nFound {len(current_results)} results in this step")
        
        # Update results - handle list columns by converting to tuples
        if results is None:
            results = current_results
            if verbose:
                print("First step - using initial results")
        else:
            # Convert list columns to tuples for both DataFrames
            for df in [results, current_results]:
                for col in df.columns:
                    if df[col].apply(lambda x: isinstance(x, list)).any():
                        df[col] = df[col].apply(lambda x: tuple(x) if isinstance(x, list) else x)
            
            old_len = len(results)
            results = pd.concat([results, current_results]).drop_duplicates()
            new_len = len(results)
            
            if verbose:
                print(f"Added {new_len - old_len} new unique results")
        
        # Store current iteration results and reflection
        if search_plan.reflection:
            iteration_info = {
                'step': step,
                'results': results.copy(),
                'reflection': search_plan.reflection,
                'filters': search_plan.current_filters,
                'quality_score': search_plan.reflection.quality_score
            }
            all_iterations.append(iteration_info)
            
            # Update best results if current score is higher
            if search_plan.reflection.quality_score > best_score:
                best_score = search_plan.reflection.quality_score
                best_results = results.copy()
                
                if verbose:
                    print(f"\nNew best results found! Score: {best_score}")
        
        # Check if we're done based on reflection
        if search_plan.reflection and search_plan.reflection.is_sufficient:
            if verbose:
                print("\nSearch complete - results deemed sufficient")
            break
            
        step += 1
        if step > 5:  # Safety limit
            if verbose:
                print("\nSearch stopped - reached maximum steps (5)")
            break
    
    # Use best results found during iterations
    results = best_results if best_results is not None else results
    
    # Convert tuple columns back to lists in final results
    for col in results.columns:
        if results[col].apply(lambda x: isinstance(x, tuple)).any():
            results[col] = results[col].apply(lambda x: list(x) if isinstance(x, tuple) else x)
    
    # Calculate relevance scores and sort results
    search_terms = set([term.lower() for term in query.split()])
    
    def calculate_relevance(row):
        text = f"{row['summary']} {row['details']}".lower()
        # Count occurrences of search terms
        term_matches = sum(text.count(term) for term in search_terms)
        # Boost score for more recent dates
        recency_boost = pd.to_datetime(row['meeting_time']).timestamp() / 1e9
        return term_matches + (recency_boost / 1e11)  # Normalize recency boost
    
    results['relevance_score'] = results.apply(calculate_relevance, axis=1)
    results = results.sort_values('relevance_score', ascending=False).drop(columns=['relevance_score'])
    
    if verbose:
        print(f"\nFinal Results: {len(results)} total unique entries")
        print(f"Best Quality Score: {best_score}")
        print("\nKey Findings Across Iterations:")
        for iteration in all_iterations:
            print(f"\nStep {iteration['step']} (Score: {iteration['quality_score']}):")
            for finding in iteration['reflection'].key_findings:
                print(f"- {finding}")
    
    return results, all_iterations

# %%
# Example usage
results = await iterative_search(
    query="what users say about vexa",
    joined_df=joined_df,
    context=str_result,
    sampled_df=sampled_redults
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 # Example usage
# ----> 2 results = await iterative_search(
#       3     query="what users say about vexa",
#       4     joined_df=joined_df,
#       5     context=str_result,
#       6     sampled_df=sampled_redults
#       7 )
#
# NameError: name 'iterative_search' is not defined

# %%
results[0]
# Out:
#       summary_index                                            summary  \
# 6                 8  Dmitriy Grankin is a speaker in the meeting, d...
# 9                 7  A speaker in the meeting who engages in a dial...
# 58                9  Co-speaker in the meeting focusing on product ...
# 74                7  Dmitriy Grankin is a speaker in the meeting di...
# 101               7  Dmitriy Grankin is a speaker in the meeting wh...
# ...             ...                                                ...
# 3082             10  Dmitry Grankin is a speaker in the meeting who...
# 3107              8  Dmitriy Grankin is a speaker who is developing...
# 3120              3  Dmitriy Grankin is the speaker of the meeting,...
# 3127              5  Dmitriy Grankin is the speaker of the meeting,...
# 3143             11  Dmitriy Grankin is a speaker who engages in di...
#
#                                                 details  \
# 6     He is focused on improving the user experience...
# 9     Dmitriy discusses the need for the system to a...
# 58    Dmitriy discusses the challenges of defining a...
# 74    He expresses opinions on full-time work versus...
# 101   Dmitriy emphasizes the importance of not spamm...
# ...                                                 ...
# 3082  He discusses the importance of LinkedIn outrea...
# 3107  He has been working on this project for the la...
# 3120  Dmitriy Grankin expressed thoughts on work and...
# 3127  Dmitriy initiates the meeting and interacts wi...
# 3143  Dmitriy is preparing new hypotheses for user e...
#
#                                         referenced_text       topic_name  \
# 6     Dmitriy Grankin:  можно показать тебе кое-что ...  Dmitriy Grankin
# 9     Sergey Ryabenko:  Ну нет, таски – это одно из....  Dmitriy Grankin
# 58                                                       Dmitriy Grankin
# 74    Alex Shevliakov:  набирать тип как консультант...  Dmitriy Grankin
# 101                                                      Dmitriy Grankin
# ...                                                 ...              ...
# 3082                      Dmitrii Chistov:  Все хорошо.   Dmitry Grankin
# 3107  Dmitriy Grankin:  или около того последние три...  Dmitriy Grankin
# 3120  Dmitriy Grankin:  Работать, не работать, работ...  Dmitriy Grankin
# 3127  Dmitriy Grankin:  Hmm. | Dmitriy Grankin:  Der...  Dmitriy Grankin
# 3143  Dmitriy Grankin:  да сейчас я скину я сейчас г...  Dmitriy Grankin
#
#      topic_type                            meeting_id  \
# 6        person  f5f969d6-675f-4d55-a604-78208e545dcd
# 9        person  2be605d6-d98d-475a-8969-838cb44a6fe9
# 58       person  e3dea53c-a0d6-4b10-ab63-8b4c120bd245
# 74       person  1c71070f-4427-4aae-ace0-2091f70dec5b
# 101      person  f3dd4aba-acde-46e0-9b6c-12591c740e0e
# ...         ...                                   ...
# 3082     person  dbf8ad27-649c-4a16-b5a1-5ab3db002bd9
# 3107     person  6e6e65ac-b626-4326-aab4-f2a8e9b0cdef
# 3120     person  8e319925-f6d4-4acd-82d3-705d94a824f7
# 3127     person  24f3dec7-23a0-4278-a21c-fe355332a853
# 3143     person  3ead8b34-f5de-42ef-8d28-5dd64a2b8669
#
#               meeting_timestamp     speaker_name  \
# 6    2024-09-16 15:35:48.424000  Dmitriy Grankin
# 9    2024-09-16 13:09:25.985999  Dmitriy Grankin
# 58   2024-09-16 19:02:08.440000  Dmitriy Grankin
# 74   2024-09-17 09:26:40.185999  Dmitriy Grankin
# 101  2024-09-17 09:49:06.520000  Dmitriy Grankin
# ...                         ...              ...
# 3082 2024-09-13 15:15:37.764000   Dmitry Grankin
# 3107 2024-09-13 16:03:40.114000  Dmitriy Grankin
# 3120 2024-09-15 10:53:01.284000  Dmitriy Grankin
# 3127 2024-09-16 09:17:52.070000  Dmitriy Grankin
# 3143 2024-09-16 09:47:34.620000  Dmitriy Grankin
#
#                             other_speakers meeting_time
# 6                          [Ilia Semukhin]   2024-09-16
# 9                        [Sergey Ryabenko]   2024-09-16
# 58                     [Olga Nemirovskaya]   2024-09-16
# 74                       [Alex Shevliakov]   2024-09-17
# 101                    [Olga Nemirovskaya]   2024-09-17
# ...                                    ...          ...
# 3082                     [Dmitrii Chistov]   2024-09-13
# 3107  [Дмитрий Гранкин, Александр Мелихов]   2024-09-13
# 3120                                    []   2024-09-15
# 3127                                    []   2024-09-16
# 3143                   [Olga Nemirovskaya]   2024-09-16
#
# [148 rows x 11 columns]

# %%
search_params
# Out:
# SearchFilter(topic_type=None, topic_name=['Vexa', 'VEXA', 'VEX.AI'], speaker_name=None, date_range=None, search_text='vexa')

# %%
apply_search_filters(joined_df, search_params)
# Out:
#       summary_index                                            summary  \
# 11                9  The process of managing tasks and responsibili...
# 109               1  The updated code needs to be built and tested ...
# 184              11  Celery is a task queue used for managing async...
# 195               0  The team discussed the qualifications of two c...
# 205               9  Andrey is referenced as a good developer with ...
# 210              15  Artificial Intelligence (AI) refers to the sim...
# 214               0  The team discussed the current state of a Reac...
# 217              20  GitHub is a platform for version control and c...
# 256               4  The team is open to experimenting with the cur...
# 307              21  JavaScript is a programming language commonly ...
# 310               3  There were discussions about problems with fil...
# 326               7  The team discussed existing CSS issues and the...
# 327               8  The team decided to break down the main page i...
# 333              18  Components refer to reusable building blocks i...
# 337               2  Dmitriy guided Sergey on generating an SSH key...
# 342               7  The team agreed to schedule a follow-up meetin...
# 345              10  API (Application Programming Interface) is a s...
# 346              11  SSHR is a tool or service mentioned in the con...
# 350              15  Replit is an online coding platform that allow...
# 353              18  React is a JavaScript library for building use...
# 356              23  No-code solutions refer to platforms that allo...
# 916              20  Marketing refers to the strategies and activit...
# 1051             13  Search functionality is crucial for the applic...
# 1059             14  Design refers to the visual and functional lay...
# 1092              8  Figma is a design tool mentioned in the meetin...
# 1181              3  Dmitriy raised concerns about his ability to r...
# 1182              4  Dmitriy and Sergey encountered issues with err...
# 1584              0  The team needs to finalize the setup of Google...
# 1607              1  The team discussed the need to deploy cookies ...
# 2752              0  Integrate Sergey into the team by familiarizin...
# 2753              1  Establish a reliable backup system for the dat...
# 2757              5  Prepare necessary documentation for the onboar...
# 2758              6  Ensure Sergey has access to the necessary repo...
# 2854              5  Sergey Ryabenko is a participant in the meetin...
#
#                                                 details  \
# 11    Dmitriy and Sergey discuss the need for a syst...
# 109   Dmitriy Grankin confirmed that the code has be...
# 184   Dmitriy clarifies its function as a scheduler ...
# 195   Dmitriy and Sergey expressed concerns about on...
# 205   Dmitriy and Sergey discuss Andrey's coding spe...
# 210   Dmitriy and Sergey discuss the implications of...
# 214   Dmitriy and Sergey reviewed the React files an...
# 217   Dmitriy and Sergey discuss the importance of v...
# 256   Dmitriy and Sergey expressed interest in testi...
# 307   Dmitriy and Sergey reference JavaScript in the...
# 310   Both Dmitriy and Sergey acknowledged issues wi...
# 326   Dmitriy and Sergey noted that there are CSS is...
# 327   Dmitriy and Sergey agreed that the current sin...
# 333   Dmitriy and Sergey talk about the need to brea...
# 337   Dmitriy explained the process of generating an...
# 342   Dmitriy and Sergey agreed to meet again after ...
# 345   Dmitriy and Sergey discuss issues related to A...
# 346   Dmitriy and Sergey discuss the use of SSH keys...
# 350   Dmitriy and Sergey discuss using Replit for th...
# 353   Dmitriy and Sergey discuss using React in thei...
# 356   Dmitriy and Sergey discuss the limitations and...
# 916   Dmitriy and Sergey discuss the marketing strat...
# 1051  Dmitriy and Sergey discuss implementing a comb...
# 1059  Dmitriy and Sergey discuss the need for a dash...
# 1092  Dmitriy and Sergey discuss using Figma for des...
# 1181  Dmitriy noted that while he can write code, he...
# 1182  During testing, they faced an error related to...
# 1584  This task is urgent and should be completed im...
# 1607  Dmitriy Grankin mentioned that the cookie depl...
# 2752  Sergey will be onboarded to understand the exi...
# 2753  Dmitriy emphasized the need for regular snapsh...
# 2757  Dmitriy will prepare documentation outlining t...
# 2758  Dmitriy will coordinate with the team to provi...
# 2854  Sergey is involved in the daily synchronizatio...
#
#                                         referenced_text  \
# 11    Sergey Ryabenko:  Ну нет, таски – это одно из....
# 109   Dmitriy Grankin:  Вот, тем не менее, он обнови...
# 184   Sergey Ryabenko:  Ну, говорю, самая главная пр...
# 195   Dmitriy Grankin:  Слушай, ну, ты слышал, как б...
# 205   Dmitriy Grankin:  Реально, Андрей, допустим, х...
# 210   Dmitriy Grankin:  Overqualified. Интересная фо...
# 214   Dmitriy Grankin:  показать и понять что тут во...
# 217
# 256   :  Да, надо попробовать, это практически безоп...
# 307
# 310   :  С суппортами проблемы. | :  Ну, у меня тоже...
# 326   Dmitriy Grankin:  ну вот непонятно всем говори...
# 327   Sergey Ryabenko:  который ты скопировал, вот э...
# 333   Sergey Ryabenko:  который ты скопировал, вот э...
# 337   Dmitriy Grankin:  Так, ну я тебе сейчас, я теб...
# 342      :  Давай, я тогда как приеду со школы, напишу.
# 345
# 346
# 350
# 353
# 356
# 916
# 1051
# 1059
# 1092
# 1181  Dmitriy Grankin:  Ну, фронт я не умею читать, ...
# 1182  Sergey Ryabenko:  Почему-то, да, возвращает Er...
# 1584  Dmitriy Grankin:  Okay, just briefly what's go...
# 1607
# 2752  Dmitriy Grankin:  я думаю, что какой у нас пла...
# 2753  Dmitriy Grankin:  нужно какой-то сделать он bo...
# 2757  Dmitriy Grankin:  получить вот что нам нужно д...
# 2758  Dmitriy Grankin:  получить вот что нам нужно д...
# 2854
#
#                                              topic_name            topic_type  \
# 11                                      task management               concept
# 109                               Code Update and Build                  task
# 184                                              Celery               product
# 195   Discussion on candidate qualifications and fit...               concern
# 205                                              Andrey                person
# 210                                                  AI               concept
# 214                      Current state of React project            discussion
# 217                                              GitHub               company
# 256               Experimentation with existing systems           opportunity
# 307                                          JavaScript  programming language
# 310                    File handling and support issues               concern
# 326                   Address CSS issues in the project                  task
# 327                  Decide on page component breakdown                  task
# 333                                          components               concept
# 337                                  SSH key generation                  task
# 342                           Future meeting scheduling           action plan
# 345                                                 API               concept
# 346                                                SSHR               product
# 350                                              Replit               product
# 353                                               React               product
# 356                                   No-code solutions               concept
# 916                                           маркетинг                 topic
# 1051                                              поиск                 topic
# 1059                                             дизайн                 topic
# 1092                                              Figma               product
# 1181        Frontend code readability and collaboration               concern
# 1182                    Error handling in API responses               problem
# 1584          Set up Google Analytics for user tracking           action plan
# 1607                 Deployment of cookies on dashboard                  task
# 2752                  Onboarding new team member Sergey           action plan
# 2753                              Backup database setup                  task
# 2757                          Documentation preparation                  task
# 2758            Access to repositories and server setup                  task
# 2854                                    Sergey Ryabenko                person
#
#                                 meeting_id          meeting_timestamp  \
# 11    2be605d6-d98d-475a-8969-838cb44a6fe9 2024-09-16 13:09:25.985999
# 109   377bbdf0-3502-4e32-950f-44a1ef0fa0ed 2024-09-17 10:21:16.480000
# 184   52cd3cf1-7c60-4e77-b861-69ca6ffe914e 2024-09-18 11:57:28.220000
# 195   52cd3cf1-7c60-4e77-b861-69ca6ffe914e 2024-09-18 11:57:28.220000
# 205   52cd3cf1-7c60-4e77-b861-69ca6ffe914e 2024-09-18 11:57:28.220000
# 210   52cd3cf1-7c60-4e77-b861-69ca6ffe914e 2024-09-18 11:57:28.220000
# 214   8ead624d-bab2-4c6b-b837-0c97d5e6f32a 2024-09-18 17:37:35.184000
# 217   ce1988d6-b5a7-4c04-b322-d986523f0e3c 2024-09-23 13:29:51.040000
# 256   4336b4b4-7a6d-4ec7-9d62-d4620ecdbe4d 2024-09-19 13:57:01.704000
# 307   ce1988d6-b5a7-4c04-b322-d986523f0e3c 2024-09-23 13:29:51.040000
# 310   c17d3344-672f-457a-bf59-1b095614bcfc 2024-09-23 09:26:24.270000
# 326   2991351f-26e5-4d49-b1a0-daeaa77b18e5 2024-09-23 11:09:16.803999
# 327   2991351f-26e5-4d49-b1a0-daeaa77b18e5 2024-09-23 11:09:16.803999
# 333   2991351f-26e5-4d49-b1a0-daeaa77b18e5 2024-09-23 11:09:16.803999
# 337   ce1988d6-b5a7-4c04-b322-d986523f0e3c 2024-09-23 13:29:51.040000
# 342   ce1988d6-b5a7-4c04-b322-d986523f0e3c 2024-09-23 13:29:51.040000
# 345   ce1988d6-b5a7-4c04-b322-d986523f0e3c 2024-09-23 13:29:51.040000
# 346   ce1988d6-b5a7-4c04-b322-d986523f0e3c 2024-09-23 13:29:51.040000
# 350   ce1988d6-b5a7-4c04-b322-d986523f0e3c 2024-09-23 13:29:51.040000
# 353   ce1988d6-b5a7-4c04-b322-d986523f0e3c 2024-09-23 13:29:51.040000
# 356   ce1988d6-b5a7-4c04-b322-d986523f0e3c 2024-09-23 13:29:51.040000
# 916   e2864cf9-f8d5-4a22-85bc-d07557b634ee 2024-10-14 09:39:39.514000
# 1051  e2864cf9-f8d5-4a22-85bc-d07557b634ee 2024-10-14 09:39:39.514000
# 1059  e2864cf9-f8d5-4a22-85bc-d07557b634ee 2024-10-14 09:39:39.514000
# 1092  2b309a6a-7d85-4a1c-aaa8-4de0c94a03c3 2024-10-14 10:21:54.670000
# 1181  aa87b543-f5c9-426c-a6ed-77b26f93e0da 2024-10-20 12:46:32.230000
# 1182  aa87b543-f5c9-426c-a6ed-77b26f93e0da 2024-10-20 12:46:32.230000
# 1584  6baf67cc-a30f-45ae-be59-255b011415ee 2024-08-30 09:24:55.280000
# 1607  4fd4df87-3886-47e4-8173-9a1990c64d01 2024-08-30 09:47:59.870000
# 2752  cde02f21-5001-4f19-b477-5dc4a04017fd 2024-09-11 10:57:53.150000
# 2753  cde02f21-5001-4f19-b477-5dc4a04017fd 2024-09-11 10:57:53.150000
# 2757  cde02f21-5001-4f19-b477-5dc4a04017fd 2024-09-11 10:57:53.150000
# 2758  cde02f21-5001-4f19-b477-5dc4a04017fd 2024-09-11 10:57:53.150000
# 2854  f7515f24-af43-4f07-9932-21255978d204 2024-09-12 09:16:15.900000
#
#          speaker_name                                     other_speakers  \
# 11    Dmitriy Grankin                                  [Sergey Ryabenko]
# 109   Dmitriy Grankin                                  [Sergey Ryabenko]
# 184   Dmitriy Grankin                                  [Sergey Ryabenko]
# 195   Dmitriy Grankin                                  [Sergey Ryabenko]
# 205   Dmitriy Grankin                                  [Sergey Ryabenko]
# 210   Dmitriy Grankin                                  [Sergey Ryabenko]
# 214   Dmitriy Grankin                                  [Sergey Ryabenko]
# 217   Dmitriy Grankin                                  [Sergey Ryabenko]
# 256   Dmitriy Grankin                                  [Sergey Ryabenko]
# 307   Dmitriy Grankin                                  [Sergey Ryabenko]
# 310   Dmitriy Grankin                                  [Sergey Ryabenko]
# 326   Dmitriy Grankin                                  [Sergey Ryabenko]
# 327   Dmitriy Grankin                                  [Sergey Ryabenko]
# 333   Dmitriy Grankin                                  [Sergey Ryabenko]
# 337   Dmitriy Grankin                                  [Sergey Ryabenko]
# 342   Dmitriy Grankin                                  [Sergey Ryabenko]
# 345   Dmitriy Grankin                                  [Sergey Ryabenko]
# 346   Dmitriy Grankin                                  [Sergey Ryabenko]
# 350   Dmitriy Grankin                                  [Sergey Ryabenko]
# 353   Dmitriy Grankin                                  [Sergey Ryabenko]
# 356   Dmitriy Grankin                                  [Sergey Ryabenko]
# 916   Dmitriy Grankin                                  [Sergey Ryabenko]
# 1051  Dmitriy Grankin                                  [Sergey Ryabenko]
# 1059  Dmitriy Grankin                                  [Sergey Ryabenko]
# 1092  Dmitriy Grankin                                  [Sergey Ryabenko]
# 1181  Dmitriy Grankin                                  [Sergey Ryabenko]
# 1182  Dmitriy Grankin                                  [Sergey Ryabenko]
# 1584  Dmitriy Grankin  [Olga Nemirovskaya, Sergey Ryabenko, Okafor Ik...
# 1607  Dmitriy Grankin  [Andrey Pisankin, Sergey Ryabenko, Olga Nemiro...
# 2752  Dmitriy Grankin             [SR, Xut tuX, XT, DG, Sergey Ryabenko]
# 2753  Dmitriy Grankin             [SR, Xut tuX, XT, DG, Sergey Ryabenko]
# 2757  Dmitriy Grankin             [SR, Xut tuX, XT, DG, Sergey Ryabenko]
# 2758  Dmitriy Grankin             [SR, Xut tuX, XT, DG, Sergey Ryabenko]
# 2854   Dmitry Grankin       [Sergey Ryabenko, Xut tuX, Karine Stepanyan]
#
#      meeting_time
# 11     2024-09-16
# 109    2024-09-17
# 184    2024-09-18
# 195    2024-09-18
# 205    2024-09-18
# 210    2024-09-18
# 214    2024-09-18
# 217    2024-09-23
# 256    2024-09-19
# 307    2024-09-23
# 310    2024-09-23
# 326    2024-09-23
# 327    2024-09-23
# 333    2024-09-23
# 337    2024-09-23
# 342    2024-09-23
# 345    2024-09-23
# 346    2024-09-23
# 350    2024-09-23
# 353    2024-09-23
# 356    2024-09-23
# 916    2024-10-14
# 1051   2024-10-14
# 1059   2024-10-14
# 1092   2024-10-14
# 1181   2024-10-20
# 1182   2024-10-20
# 1584   2024-08-30
# 1607   2024-08-30
# 2752   2024-09-11
# 2753   2024-09-11
# 2757   2024-09-11
# 2758   2024-09-11
# 2854   2024-09-12

# %%
search_params
# Out:
# SearchFilter(topic_type=['product', 'company', 'idea', 'discussion'], topic_name=['VEX', 'Vexa', 'VEXA'], speaker_name=None, date_range=None, search_text=None)

# %%
joined_df[joined_df['topic_type'].isin(['product', 'company', 'idea', 'discussion'])].sort_values(by='meeting_time',ascending=True)
# Out:
#       summary_index                                            summary  \
# 1289             12  Google Ads is a platform being set up for mark...
# 1293             16  Телеграм is a messaging platform being conside...
# 1321             10  The dashboard is a key focus of the meeting, w...
# 1322             11  The extension is mentioned as a product that i...
# 1377             12  Google Analytics is a web analytics service th...
# ...             ...                                                ...
# 1240             12  Zoom is another video conferencing tool mentio...
# 1241             13  Telegram is a messaging app that Dmitry used t...
# 1242             14  A Chrome Extension developed by Dmitry to enha...
# 1243             16  WhatsApp is a messaging platform that Özay men...
# 1244             17  iPhone is mentioned as having a feature that a...
#
#                                                 details  \
# 1289  Olga mentions that Google Ads is in the setup ...
# 1293  Olga expresses concerns about the future of Те...
# 1321  Dmitriy emphasizes the need for a user-friendl...
# 1322  Sergey indicates that working on the dashboard...
# 1377  The discussion revolves around integrating Goo...
# ...                                                 ...
# 1240  Similar to Google Meet, Zoom is referenced as ...
# 1241  Dmitry mentions using Telegram in conjunction ...
# 1242  Dmitry discusses the development of a Chrome e...
# 1243  Özay discusses the difficulty of recording cal...
# 1244  Özay references the iPhone's ability to record...
#
#                                         referenced_text        topic_name  \
# 1289  Olga Nemirovskaya:  Google Ads. Короче, все в ...        Google Ads
# 1293  Olga Nemirovskaya:  Вот. Значит, дальше. Что у...          Телеграм
# 1321  Dmitriy Grankin:  Yeah, but like, it looks lik...         dashboard
# 1322  Sergey Ryabenko:  Um, yeah, then let's, let's ...         extension
# 1377  Dmitriy Grankin:  Своя система аналитики, нам ...  Google Analytics
# ...                                                 ...               ...
# 1240  Dmitry Grankin:  yes definitely you do and uh ...              Zoom
# 1241  Özay Demirezen:  Because like, yeah, pretty mu...          Telegram
# 1242                 Özay Demirezen:  Okay, yeah, this,  Chrome Extension
# 1243  Dmitry Grankin:  with fred fred you know okay ...          WhatsApp
# 1244  Özay Demirezen:  I just checked, like WhatsApp...            iPhone
#
#      topic_type                            meeting_id       meeting_timestamp  \
# 1289    product  cd43879a-0b16-4473-9744-04ae567626ff 2024-08-26 19:14:18.976
# 1293    product  cd43879a-0b16-4473-9744-04ae567626ff 2024-08-26 19:14:18.976
# 1321    product  29fb1a35-e656-4435-89db-cbd8ad221a79 2024-08-27 09:17:03.250
# 1322    product  29fb1a35-e656-4435-89db-cbd8ad221a79 2024-08-27 09:17:03.250
# 1377    product  99ade764-fd60-4e9a-9621-66cc037cb865 2024-08-27 19:34:48.996
# ...         ...                                   ...                     ...
# 1240    product  50d5d659-3a57-42f2-8f32-31c7145ebe91 2024-10-24 09:32:32.980
# 1241    product  50d5d659-3a57-42f2-8f32-31c7145ebe91 2024-10-24 09:32:32.980
# 1242    product  50d5d659-3a57-42f2-8f32-31c7145ebe91 2024-10-24 09:32:32.980
# 1243    product  50d5d659-3a57-42f2-8f32-31c7145ebe91 2024-10-24 09:32:32.980
# 1244    product  50d5d659-3a57-42f2-8f32-31c7145ebe91 2024-10-24 09:32:32.980
#
#            speaker_name       other_speakers meeting_time
# 1289  Olga Nemirovskaya    [Dmitriy Grankin]   2024-08-26
# 1293  Olga Nemirovskaya    [Dmitriy Grankin]   2024-08-26
# 1321    Dmitriy Grankin    [Sergey Ryabenko]   2024-08-27
# 1322    Sergey Ryabenko    [Dmitriy Grankin]   2024-08-27
# 1377    Dmitriy Grankin  [Olga Nemirovskaya]   2024-08-27
# ...                 ...                  ...          ...
# 1240     Dmitry Grankin     [Özay Demirezen]   2024-10-24
# 1241     Dmitry Grankin     [Özay Demirezen]   2024-10-24
# 1242     Dmitry Grankin     [Özay Demirezen]   2024-10-24
# 1243     Özay Demirezen     [Dmitry Grankin]   2024-10-24
# 1244     Özay Demirezen     [Dmitry Grankin]   2024-10-24
#
# [347 rows x 11 columns]
