# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('/app')

# %%
from psql_helpers import get_meetings_by_ids

# %%
from search import SearchAssistant

# Create instance
search_assistant = SearchAssistant()

# Initialize (required before use)
await search_assistant.initialize()
# Out:
# 17:05:51 - vexa_api - INFO - Initializing SearchAssistant
# Fetching 5 files:   0%|          | 0/5 [00:00<?, ?it/s]
# Fetching 29 files:   0%|          | 0/29 [00:00<?, ?it/s]

# %%
user_id = 'ef7c085b-fdb5-4c94-b7b6-a61a3d04c210'

# %%
# Search across accessible meetings
results = await search_assistant.search(
    query="twitter",
    user_id=user_id,
    limit=200,  # optional, default 200
    min_score=0.4  # optional, default 0.4
)

# %%
results.head(50)
# Out:
#          topic_name       speaker_name  \
# 0           Колково                 OM
# 1        публикация                nan
# 2              logo                 DG
# 3             пазло                 DG
# 4             спичи                 DG
# 5             стейт                nan
# 6           вестинг                 TS
# 7            бойлер                 DG
# 8           реплика                 DG
# 9           консоль                 AS
# 10           фидбэк                 DG
# 11           плагин                 SR
# 12             Стас                 DG
# 13           пресид                 MZ
# 14          инстанс                 SR
# 15               ТЗ                 SR
# 16             ссср    Дмитрий Гранкин
# 17             куки                 SR
# 18            юзеры  Olga Nemirovskaya
# 19       колл токен     Сергей Рябенко
# 20            скрам                 DG
# 21            скрам                 DG
# 22          ипотека                 DG
# 23          ипотека                 MM
# 24        комьюнити                 ON
# 25        комьюнити                 ON
# 26  Что происходит?                (0)
# 27          vexa.ai    Dmitriy Grankin
# 28          vexa.ai                 DG
# 29          стартап                 DG
# 30          стартап               Олег
# 34          стартап                 MJ
# 33          стартап                 TS
# 32          стартап                 DG
# 31          стартап                 DG
# 35            кейсы                 DG
# 36       юнит-тесты                 NF
# 37       комплайент                 DG
# 38       комплайент                 DG
# 39             Счет                 DG
# 40        нотейкеры  Olga Nemirovskaya
# 41          верстка                 DG
# 42         фаундеры  Olga Nemirovskaya
# 43           бэкэнд                 NF
# 45           бэкэнд                 DG
# 46           бэкэнд                 SR
# 44           бэкэнд                 NF
# 47           бэкэнд                 SR
# 48           Эээ...                (1)
# 50     стрит-ретейл                 IB
#
#                                               summary  \
# 0   Бизнес-школа, где Ольга училась и где проводил...
# 1            Процесс размещения информации в системе.
# 2   The logo is a visual element of the extension ...
# 3                     Обсуждение загадки или вопроса.
# 4                       Проблемы с обработкой спичей.
# 5                         Состояние задачи в системе.
# 6   Вестинг - это процесс, при котором акции или о...
# 7   Бойлер - система, которая обрабатывает заказы ...
# 8   Реплика базы данных, которая используется для ...
# 9   Инструмент для разработчиков, обсуждаемый учас...
# 10  Фидбэк рассматривается как важный элемент разв...
# 11  Плагин - это расширение, которое обсуждается в...
# 12  Стас - человек, упоминаемый в контексте обсужд...
# 13      Пресид - ранний этап финансирования стартапа.
# 14  Инстанс обсуждается в контексте работы с проек...
# 15  ТЗ (техническое задание) упоминается как необх...
# 16  Ссср упоминается в контексте работы с редактор...
# 17  Файлы, используемые для хранения информации о ...
# 18  Юзеры refer to the users of the product Векса,...
# 19  Колл токен упоминается в контексте работы с AP...
# 20  Скрам обсуждается как методология, которую Дми...
# 21  Скрам упоминается как методология, которую Дми...
# 22  Ипотека - финансовый инструмент, обсуждаемый Д...
# 23  Тема обсуждения, касающаяся получения ипотеки ...
# 24  Комьюнити, обсуждаемое как место для взаимодей...
# 25  Комьюнити обсуждается как потенциальный канал ...
# 26  Вопрос о текущей ситуации или происходящих соб...
# 27  Vexa.ai is the company behind the transcriptio...
# 28  vexa.ai is the website where the transcription...
# 29  Стартап - это новая компания, которая разрабат...
# 30         Стартап - бизнес, которым занимается Олег.
# 34  Стартап обсуждается в контексте его развития и...
# 33     Компания, в которой Татьяна начинает работать.
# 32  Стартап - это новая компания, часто с инноваци...
# 31     Стартап, над которым работает Дмитрий Гранкин.
# 35                         Интерес к реальным кейсам.
# 36   Метод тестирования кода, обсуждаемый на встрече.
# 37  Соблюдение норм и правил, обсуждаемое в контек...
# 38  Соблюдение норм и правил в области защиты данных.
# 39                       Финансовый счет для бизнеса.
# 40  Тематика, обсуждаемая Ольгой в контексте новых...
# 41  Верстка — задача, которую обсуждают участники ...
# 42  Фаундеры are founders of other products who ma...
# 43  Часть интернет-магазина, отвечающая за хранени...
# 45  Бэкэнд интернет-магазина, который будет сохран...
# 46         Обсуждение разработки бэкэнда для проекта.
# 44  Бэкэнд системы, который будет сохранять и упра...
# 47         Обсуждение разработки бэкэнда для системы.
# 48     Выражение неопределенности или замешательства.
# 50  Стрит-ретейл, упоминаемый в контексте бизнеса,...
#
#                                               details  \
# 0   Ольга делится своим опытом обучения в Колково,...
# 1   Обсуждаются методы публикации данных и их дост...
# 2   There are complaints about the logo being hard...
# 3   Дмитрий Гранкин задает вопрос о том, почему в ...
# 4   Дмитрий исследует, в какой момент теряются спи...
# 5   Обсуждаются состояния 'Завершено' и 'Не заверш...
# 6   Татьяна обсуждает условия вестинга в контексте...
# 7   Бойлер отвечает за распределение заказов между...
# 8   Реплика должна быть на той же архитектуре, что...
# 9   Обсуждается использование консоли для дебаггин...
# 10  Дмитрий говорит о необходимости получения обра...
# 11  Участники обсуждают различные плагины, которые...
# 12  Обсуждается, что у Стаса возникли проблемы с д...
# 13  Майк и Дмитрий обсуждают этапы финансирования,...
# 14  Обсуждаются проблемы с поднятием нового инстан...
# 15  Сергей говорит о необходимости собрать ТЗ из о...
# 16  Дмитрий обсуждает, как подключить ссср к редак...
# 17  Обсуждается их использование в системе и необх...
# 18  The team is focusing on reaching out to юзеры ...
# 19  Сергей обсуждает, как колл токен используется ...
# 20  Дмитрий предлагает игнорировать традиционные п...
# 21  Дмитрий говорит о необходимости адаптироваться...
# 22  Дмитрий делится своим опытом получения ипотеки...
# 23  Макс и Дмитрий обсуждают процесс получения ипо...
# 24  Olga говорит о том, что она взаимодействует с ...
# 25  Ольга говорит о необходимости рассмотреть комь...
# 26  Вопрос задан в начале встречи, возможно, для в...
# 27  Dmitriy mentions that users can install the Ve...
# 28  Dmitriy mentions that users can easily install...
# 29  Обсуждаются стартапы, для которых Татьяна и Дм...
# 30  Олег говорит о своем стартапе и о том, как он ...
# 34  Maksim делится своими мыслями о стартапе, его ...
# 33  Татьяна упоминает, что она была вынуждена прин...
# 32  Дмитрий и Татьяна обсуждают, как их идеи могут...
# 31  Дмитрий рассказывает о своем стартапе, связанн...
# 35  Гранкин выражает интерес к реальным кейсам, ко...
# 36  Обсуждаются подходы к написанию юнит-тестов дл...
# 37  Обсуждение вопросов комплайента и уведомлений ...
# 38  Обсуждается, как компания соблюдает требования...
# 39         Обсуждаются проблемы открытия счета в США.
# 40  Ольга смотрит новые посты про нотейкеры и их и...
# 41  Дмитрий говорит о необходимости верстки и о то...
# 42  Olga proposes a reciprocal promotion strategy ...
# 43  Обсуждается необходимость создания бэкэнда для...
# 45  Обсуждается создание бэкэнда для интернет-мага...
# 46  Сергей говорит о тестовом бэке и необходимости...
# 44  Обсуждается реализация бэкэнда для интернет-ма...
# 47  Сергей говорит о тестовом бэке и необходимости...
# 48  Слово используется как реакция на вопрос, возм...
# 50  Обсуждается, что бизнес будет сосредоточен на ...
#
#                               meeting_id                   timestamp  \
# 0   e2f3a86b-e94d-4967-8dad-89ac78a0617c         2024-09-13T10:17:17
# 1   37769a4e-fd8d-4193-8a91-f001a16649b2         2024-11-03T12:26:49
# 2   74f0615a-57c2-4b0a-93e7-a3886f5766fd  2024-09-10T09:17:58.620000
# 3   b7307556-45d8-424a-84f2-c29ecf6f112c         2024-11-19T12:02:50
# 4   c0b22605-f51f-4307-bbbc-d873fe21f4e8         2024-11-25T11:47:50
# 5   a88412e4-3df6-4c31-92d7-78b354c741bc         2024-11-10T18:59:16
# 6   ed953dc9-002d-4202-905e-269cc982a3f3         2024-09-30T15:35:51
# 7   f3053994-3feb-46e6-bd68-f745f428c00c         2024-09-24T10:00:38
# 8   9d4ac692-ec0f-4e9e-a82b-eff6c81c7fe9         2024-09-12T10:58:49
# 9   1c71070f-4427-4aae-ace0-2091f70dec5b         2024-09-17T09:26:34
# 10  5401ff51-4f8f-4f95-a5d2-21564c9b3cc4  2024-12-05T10:02:26.870000
# 11  2b309a6a-7d85-4a1c-aaa8-4de0c94a03c3         2024-10-14T10:21:51
# 12  0eceb16a-7732-4e91-931b-ab588771dd41         2024-09-06T19:02:28
# 13  e1d2fbb4-8f91-42bd-99d2-438d13778da9         2024-08-26T14:00:00
# 14  7df0ee56-0173-46af-a468-0ff0e65965ba         2024-09-25T14:49:33
# 15  2b309a6a-7d85-4a1c-aaa8-4de0c94a03c3         2024-10-14T10:21:51
# 16  ce1988d6-b5a7-4c04-b322-d986523f0e3c         2024-09-23T13:29:27
# 17  ad09fa20-04e3-426a-b930-f4f1139836bf         2024-08-30T08:44:03
# 18  08a4b53e-6ff1-4a95-9263-57ca27f0995a         2024-10-02T10:46:11
# 19  ce1988d6-b5a7-4c04-b322-d986523f0e3c         2024-09-23T13:29:27
# 20  74f30386-e91f-4075-a0f8-f5c859481d7d         2024-11-20T10:21:46
# 21  74f30386-e91f-4075-a0f8-f5c859481d7d         2024-11-20T10:21:46
# 22  e1d2fbb4-8f91-42bd-99d2-438d13778da9         2024-08-26T14:00:00
# 23  7122979f-9b4e-4d0f-92c7-18f6b1034197         2024-09-09T16:31:30
# 24  b1c57a93-7750-4633-a579-4d374d9c99f5         2024-09-11T18:41:54
# 25  99e22c95-9f1c-4704-b6ab-394e5d54e970         2024-09-12T19:33:33
# 26  b3b8bd73-39f7-4155-84e1-c5c121f2f75b         2024-11-19T18:19:09
# 27  8eb8d512-2ba3-40f4-8535-8bba86779336  2024-12-03T11:05:19.504000
# 28  8eb8d512-2ba3-40f4-8535-8bba86779336  2024-12-03T11:05:19.504000
# 29  ed953dc9-002d-4202-905e-269cc982a3f3         2024-09-30T15:35:51
# 30  8029be21-158c-48b0-a057-880da2371844         2024-09-02T19:55:26
# 34  cffaef24-0478-4b6a-93f9-533635e826bf         2024-09-01T12:01:05
# 33  1579143f-3d96-4346-9220-febb329ca5ce  2024-12-02T12:10:23.270000
# 32  ed953dc9-002d-4202-905e-269cc982a3f3         2024-09-30T15:35:51
# 31  c450ea95-dc3b-4bf8-9e47-1d4f7b99e6b7         2024-09-27T12:34:46
# 35  7afff477-c0bd-44c1-92c9-75f94ac75d68         2024-11-18T20:00:08
# 36  0e6d4428-6c61-4289-91e4-7173b1a21121         2024-09-17T12:30:33
# 37  fb2aea72-f75d-4790-99dc-bbc4c7219a31         2024-10-04T16:17:26
# 38  fb2aea72-f75d-4790-99dc-bbc4c7219a31         2024-10-04T16:17:26
# 39  a2926b2d-f4eb-4bcc-864f-27607faa39fb         2024-08-30T17:04:58
# 40  e941833d-5234-4f52-9a2a-d68f9ba45e13         2024-09-17T19:05:27
# 41  377bbdf0-3502-4e32-950f-44a1ef0fa0ed         2024-09-17T10:21:15
# 42  08a4b53e-6ff1-4a95-9263-57ca27f0995a         2024-10-02T10:46:11
# 43  0e6d4428-6c61-4289-91e4-7173b1a21121         2024-09-17T12:30:33
# 45  0e6d4428-6c61-4289-91e4-7173b1a21121         2024-09-17T12:30:33
# 46  e2864cf9-f8d5-4a22-85bc-d07557b634ee  2024-10-14T09:39:39.514000
# 44  0e6d4428-6c61-4289-91e4-7173b1a21121         2024-09-17T12:30:33
# 47  e2864cf9-f8d5-4a22-85bc-d07557b634ee  2024-10-14T09:39:39.514000
# 48  b3b8bd73-39f7-4155-84e1-c5c121f2f75b         2024-11-19T18:19:09
# 50  dd65ab42-1870-4158-9e2a-276fa5bda674         2024-10-10T16:34:37
#
#        score                                      vector_scores exact_matches  \
# 0   0.948847                           {'topic_name': 0.948847}            []
# 1   0.946242  {'topic_name': 0.94624174, 'summary': 0.529147...            []
# 2   0.936343                          {'topic_name': 0.9363429}            []
# 3   0.934121   {'topic_name': 0.9341209, 'summary': 0.53966472}            []
# 4   0.932155     {'topic_name': 0.932155, 'summary': 0.5821487}            []
# 5   0.929222  {'topic_name': 0.92922163, 'summary': 0.568439...            []
# 6   0.925752   {'topic_name': 0.9257517, 'details': 0.33112115}            []
# 7   0.923406                          {'topic_name': 0.9234059}            []
# 8   0.919374                          {'topic_name': 0.9193741}            []
# 9   0.917464                          {'topic_name': 0.9174643}            []
# 10  0.915911                         {'topic_name': 0.91591084}            []
# 11  0.915608                          {'topic_name': 0.9156084}            []
# 12  0.914468                          {'topic_name': 0.9144678}            []
# 13  0.914135                         {'topic_name': 0.91413546}            []
# 14  0.912834  {'topic_name': 0.91283405, 'details': 0.338457...            []
# 15  0.912078                         {'topic_name': 0.91207844}            []
# 16  0.911230                         {'topic_name': 0.91123027}            []
# 17  0.910931                          {'topic_name': 0.9109311}            []
# 18  0.909809                         {'topic_name': 0.90980875}            []
# 19  0.908083                          {'topic_name': 0.9080826}            []
# 20  0.908068                         {'topic_name': 0.90806806}            []
# 21  0.908068                         {'topic_name': 0.90806806}            []
# 22  0.908004                          {'topic_name': 0.9080039}            []
# 23  0.908004                          {'topic_name': 0.9080039}            []
# 24  0.906879                         {'topic_name': 0.90687895}            []
# 25  0.906879                         {'topic_name': 0.90687895}            []
# 26  0.906767  {'topic_name': 0.9067675, 'summary': 0.5400521...            []
# 27  0.906105                          {'topic_name': 0.9061048}            []
# 28  0.906105                          {'topic_name': 0.9061048}            []
# 29  0.905887                         {'topic_name': 0.90588737}            []
# 30  0.905887                         {'topic_name': 0.90588737}            []
# 34  0.905887                         {'topic_name': 0.90588737}            []
# 33  0.905887  {'topic_name': 0.90588737, 'summary': 0.526371...            []
# 32  0.905887                         {'topic_name': 0.90588737}            []
# 31  0.905887                         {'topic_name': 0.90588737}            []
# 35  0.905729  {'topic_name': 0.90572894, 'summary': 0.577374...            []
# 36  0.904939                          {'topic_name': 0.9049393}            []
# 37  0.904589  {'topic_name': 0.90458894, 'details': 0.32555002}            []
# 38  0.904589                         {'topic_name': 0.90458894}            []
# 39  0.904136  {'topic_name': 0.90413594, 'details': 0.32688325}            []
# 40  0.903973                          {'topic_name': 0.9039726}            []
# 41  0.903868  {'topic_name': 0.90386766, 'summary': 0.508648...            []
# 42  0.902988                         {'topic_name': 0.90298814}            []
# 43  0.901795                           {'topic_name': 0.901795}            []
# 45  0.901795                           {'topic_name': 0.901795}            []
# 46  0.901795                           {'topic_name': 0.901795}            []
# 44  0.901795                           {'topic_name': 0.901795}            []
# 47  0.901795                           {'topic_name': 0.901795}            []
# 48  0.901628   {'topic_name': 0.90162754, 'details': 0.3399583}            []
# 50  0.900939                           {'topic_name': 0.900939}            []
#
#    source
# 0    main
# 1    main
# 2    main
# 3    main
# 4    main
# 5    main
# 6    main
# 7    main
# 8    main
# 9    main
# 10   main
# 11   main
# 12   main
# 13   main
# 14   main
# 15   main
# 16   main
# 17   main
# 18   main
# 19   main
# 20   main
# 21   main
# 22   main
# 23   main
# 24   main
# 25   main
# 26   main
# 27   main
# 28   main
# 29   main
# 30   main
# 34   main
# 33   main
# 32   main
# 31   main
# 35   main
# 36   main
# 37   main
# 38   main
# 39   main
# 40   main
# 41   main
# 42   main
# 43   main
# 45   main
# 46   main
# 44   main
# 47   main
# 48   main
# 50   main

# %%
meeitngs_ids = results.sort_values('score', ascending=False)['meeting_id'].unique().tolist()

# %%
result = await get_meetings_by_ids(
    meeting_ids=meeitngs_ids, 
    user_id=user_id
)

# %%
result
# Out:
# {'total': 89,
#  'meetings': [{'meeting_id': 'e2f3a86b-e94d-4967-8dad-89ac78a0617c',
#    'meeting_name': 'Отделение маркетинга от продукта',
#    'timestamp': datetime.datetime(2024, 9, 13, 10, 17, 17),
#    'is_indexed': True,
#    'meeting_summary': 'Обсуждение **текущего состояния разработки продукта** и **необходимости дальнейшего проектирования маркетинга**. Дмитрий Гранкин отметил, что **разработка идет медленно**, и необходимо **отделить маркетинг от продуктовых гипотез**, чтобы **тестировать маркетинговые сообщения быстрее**. Обсуждение идеи **проведения интервью** и участия в **предпринимательских сообществах** для привлечения внимания к продукту. Необходимо **проверить гипотезы через взаимодействие с пользователями** и анализ их потребностей. Обсуждение **структуры взаимодействия между заказчиком и агентством**. Определение **KPI для маркетинга и продукта** с целью получить **200 платящих пользователей** в течение двух месяцев. Запланировано **начало работы с агентством с 24 сентября**.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitry Grankin', 'Olga Miller']},
#   {'meeting_id': '37769a4e-fd8d-4193-8a91-f001a16649b2',
#    'meeting_name': 'Оптимизация фронтенда и бэкенда',
#    'timestamp': datetime.datetime(2024, 11, 3, 12, 26, 49),
#    'is_indexed': True,
#    'meeting_summary': 'Обсуждение **оптимальных решений** для **фронтенда** с целью **повышения эффективности** работы. **Дмитрий** предложил рассмотреть различные подходы, включая **парное программирование** и использование **Replit** для совместной работы. Также была обсуждена **необходимость публикации** текущей версии **бэкенда** на **NGX**. Обсуждались **методы работы с API** для получения данных о **встречах** и необходимость **обновления методов API** для корректной работы с фронтендом. Участники обсудили **подключение по SSH** и использование **токенов** для авторизации. В завершение, обсуждались аспекты **интеграции** и **коллаборации** в процессе разработки.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin', 'Sergey Ryabenko']},
#   {'meeting_id': '74f0615a-57c2-4b0a-93e7-a3886f5766fd',
#    'meeting_name': 'Extension Design and Functionality Updates',
#    'timestamp': datetime.datetime(2024, 9, 10, 9, 17, 58, 620000),
#    'is_indexed': True,
#    'meeting_summary': 'The team discussed **changes** in the **design** and **functionality** of the **extension**, particularly focusing on **updates** that were implemented yesterday. **Dmitriy Grankin** mentioned significant **design changes** this year but was unsure about specific details, noting he built the extension but did not test it thoroughly. **Delays** with **transcriptions** during the meeting were a concern, with **Sergey Ryabenko** noting issues not encountered in previous tests. Several **bugs** and **visibility problems** were identified, including an **invisible logo** and issues with **thread expansion**. The team plans to release another **build** for testing to address these issues and decided to remove the **rename speaker button** from the extension.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin',
#     'Dmitry Grankin',
#     'Karine Stepanyan',
#     'Sergey Ryabenko']},
#   {'meeting_id': 'b7307556-45d8-424a-84f2-c29ecf6f112c',
#    'meeting_name': 'Оптимизация управления встречами',
#    'timestamp': datetime.datetime(2024, 11, 19, 12, 2, 50),
#    'is_indexed': True,
#    'meeting_summary': 'Обсуждение **необходимости оптимизации** управления встречами из-за **технических проблем**. Дмитрий Гранкин отметил, что возникли **проблемы с видимостью активной встречи**, что требует **оптимизации процесса управления встречами**. Также упоминались **обновление системы** и **перезапуск системы** для решения текущих проблем. В ходе встречи обсуждалась **тема Интекс монета**, а также загадка о **лодке** и **мяче**, что могло быть метафорой для обсуждения.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin']},
#   {'meeting_id': 'c0b22605-f51f-4307-bbbc-d873fe21f4e8',
#    'meeting_name': 'Проблемы с иммьютабл данными',
#    'timestamp': datetime.datetime(2024, 11, 25, 11, 47, 50),
#    'is_indexed': True,
#    'meeting_summary': 'Обсуждение **проблем** с **иммьютабл данными** и **потерей данных** в системах. **Анализ** работы с **базой данных** и **процессами обработки спичей**. **Тестирование** компонентов системы, связанных со **спикером**. Обсуждение работы **пайплайнов** и **асинхронной обработки данных**. Упоминание о **субтитрах**, созданных **DimaTorzok**.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin']},
#   {'meeting_id': 'a88412e4-3df6-4c31-92d7-78b354c741bc',
#    'meeting_name': 'Тестирование и алгоритм индексации',
#    'timestamp': datetime.datetime(2024, 11, 10, 18, 59, 16),
#    'is_indexed': True,
#    'meeting_summary': 'Обсуждение **тестирования** системы **шерстных**, необходимость дальнейших **тестов**. **Разработка** **алгоритма индексации** для системы, учитывающего состояния **завершенности** и **индексации**.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin']},
#   {'meeting_id': 'ed953dc9-002d-4202-905e-269cc982a3f3',
#    'meeting_name': 'Создание экосистемы для дизайнеров',
#    'timestamp': datetime.datetime(2024, 9, 30, 15, 35, 51),
#    'is_indexed': True,
#    'meeting_summary': 'Обсуждение **важности создания впечатления** на ранних стадиях проектов и как **дизайн** может помочь в этом. **Татьяна** подчеркивает, что создание впечатления критически важно, и дизайн играет ключевую роль в этом процессе. **Дмитрий** объясняет концепцию **SAFE** и как можно использовать свои услуги вместо денег для получения **акций стартапов**, что может быть выгодно для дизайнеров. Обсуждение возможности создания **экосистемы** для дизайнеров, работающих по **бартерной модели**. Татьяна делится своим опытом работы с **логотипами** и страхами, связанными с конкурсами. Обсуждение текущих **проблем с финансированием** и возможных решений через бартерные модели. Обсуждение **дизайн-систем** и необходимости разработки их для стартапов.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin', 'Tatiana Sukhova']},
#   {'meeting_id': 'f3053994-3feb-46e6-bd68-f745f428c00c',
#    'meeting_name': 'Обсуждение функционала Вексы',
#    'timestamp': datetime.datetime(2024, 9, 24, 10, 0, 38),
#    'is_indexed': True,
#    'meeting_summary': 'Участники обсудили **продукт** - ассистент для **встреч Google Meet**, включая его **функционал** и **архитектуру**. Продукт включает **три микросервиса**, использует **Redis** и **Postgres**, и обеспечивает **транскрипцию в реальном времени**. Обсуждены **задачи** по **мейнтенансу** и **расширению функционала**, необходимость **перехода в облако Google Cloud** для улучшения работы, а также **подключение веб-сокетов** для улучшения **коммуникации**. Участники поделились своим **опытом** в разработке **микросервисов** и обсудили **архитектуру** для проекта, аналогичного **Uber**.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin', 'Jenish Mursidinov', 'Sergey Ryabenko']},
#   {'meeting_id': '9d4ac692-ec0f-4e9e-a82b-eff6c81c7fe9',
#    'meeting_name': 'Реализация базы данных и тестирование',
#    'timestamp': datetime.datetime(2024, 9, 12, 10, 58, 49),
#    'is_indexed': True,
#    'meeting_summary': 'Обсуждение реализации базы данных с использованием **Primary** и **Реплика**. **Реплика** будет проверять наличие **реплицированных данных** и, в случае их отсутствия, будет **бэкапиться** из **Primary**. Также обсуждалось **нагрузочное тестирование** для **аудиосервиса** и создание **мониторинга** для отслеживания состояния **сервисов** и **Redis**. Упомянута необходимость **оптимизации** обработки **аудио** и **транскрайбинга**.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin', 'Sergey Fofanov']},
#   {'meeting_id': '1c71070f-4427-4aae-ace0-2091f70dec5b',
#    'meeting_name': 'Оптимизация рабочего процесса и фриланс',
#    'timestamp': datetime.datetime(2024, 9, 17, 9, 26, 34),
#    'is_indexed': True,
#    'meeting_summary': 'Обсуждение **гибкости рабочего времени**, включая **фулл-тайм** и **фриланс** как оптимальный вариант, но с неуверенностью в необходимости полного рабочего времени. Рассмотрены **проблемы с дебаггингом**, включая трудности в воспроизведении ошибок и недостаточную квалификацию **тестировщиков**. Обсуждены методы **поиска фрилансеров** через знакомых и Telegram, а также негативный опыт с платформами, такими как **Upwork**. Обсуждение состояния **кода** и используемых технологий, необходимость использования современных фреймворков для оптимизации разработки. Рассмотрены аспекты **дизайна** и **UX**, их влияние на работу, а также проблемы с **фронт-энд** и **бэк-энд** разработкой.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Alex Shevliakov', 'Dmitriy Grankin']},
#   {'meeting_id': '5401ff51-4f8f-4f95-a5d2-21564c9b3cc4',
#    'meeting_name': 'Ассистент Google Meet и его возможности',
#    'timestamp': datetime.datetime(2024, 12, 5, 10, 2, 26, 870000),
#    'is_indexed': True,
#    'meeting_summary': 'Обсуждение функциональности **ассистента** для **Google Meet**, который собирает и структурирует **знания** пользователей. Ассистент, названный **Векция**, предоставляет пользователям доступ к их личной информации и помогает формулировать мысли. Он работает в реальном времени с задержкой около 10 секунд, генерируя **транскрипцию** и выделяя **важные моменты**. Создание структуры для **базы знаний**, собранной из разговоров, позволит пользователям извлекать информацию из предыдущих разговоров и получать краткие резюме. Обсуждение вопросов **безопасности** и **конфиденциальности** данных пользователей, а также важности **обратной связи** от пользователей для улучшения продукта. Рассмотрение **маркетинга** и стратегий привлечения пользователей, а также уникальных **конкурентных преимуществ** продукта.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitry Grankin', 'Oleg Ageychev']},
#   {'meeting_id': '2b309a6a-7d85-4a1c-aaa8-4de0c94a03c3',
#    'meeting_name': 'Улучшение плагина для Figma',
#    'timestamp': datetime.datetime(2024, 10, 14, 10, 21, 51),
#    'is_indexed': True,
#    'meeting_summary': 'Обсуждение **возможностей плагина** для **генерации HTML** из элементов **Figma**. Участники отметили **проблемы с производительностью** плагина, который **долго обрабатывает запросы**. Обсуждалась **необходимость в профессиональном дизайне-моде** для улучшения работы с плагином. Также был предложен **план по тестированию** плагина с использованием **trial-версии**. Участники рассмотрели возможность использования **Tailwind** для улучшения стилей и обсудили **необходимость найти верстальщика** для работы над проектом.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin', 'Sergey Ryabenko']},
#   {'meeting_id': '0eceb16a-7732-4e91-931b-ab588771dd41',
#    'meeting_name': 'Оптимизация опросника и кампаний',
#    'timestamp': datetime.datetime(2024, 9, 6, 19, 2, 28),
#    'is_indexed': True,
#    'meeting_summary': 'Обсуждение **структуры опросника**, который будет включать **5 вопросов**: **имя**, **имейл**, **компания**, **должность** и **цель использования продукта**. Принято решение оставить **текущий дизайн сайта** и формы, чтобы не затягивать процесс. Необходимо передать форму **Сергею до воскресенья** для запуска рекламной кампании. Обсуждалась **оптимизация рекламных кампаний** для **разных стран**: выделение отдельных кампаний для **Эмиратов**, **Нигерии** и **Филиппин**, с возможностью отключения кампании для Филиппин. Планируется создание **комьюнити** вокруг продукта для повышения вовлеченности пользователей через **Telegram**, **WhatsApp** и **Discord**. Необходимо настроить **интеграцию** для **маркетинговых коммуникаций** через **MailChimp**.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin', 'Olga Nemirovskaya']},
#   {'meeting_id': 'e1d2fbb4-8f91-42bd-99d2-438d13778da9',
#    'meeting_name': 'Инвестиции и развитие продукта Векса',
#    'timestamp': datetime.datetime(2024, 8, 26, 14, 0),
#    'is_indexed': True,
#    'meeting_summary': 'Дмитрий Гранкин рассказал о **текущих стадиях инвестирования** в проект **Векса** и о том, как они планируют развивать продукт. Он упомянул, что они только начали **тестирование продукта** и собираются привлекать клиентов через **маркетинговые инструменты**. Цель - достичь **200 платящих пользователей** для следующего раунда финансирования. Также обсуждался **функционал помощника** для звонков в **Google Meet**, который предоставляет **транскрипцию** и подсвечивает **ключевые слова**. Дмитрий отметил, что **точность распознавания имен** и названий компаний можно улучшить, и предложил добавить механизм для повышения точности. Обсуждалась **целевой аудитории** продукта, включая людей, работающих в разных доменных областях. Дмитрий и Майк обсудили **этапы привлечения инвестиций**, включая **пресид** и **сид** раунды, а также **ожидания** по раундам. Дмитрий описал, какой должна быть **идеальная команда стартапа**, включая опыт и совместную работу. Он также рассказал о **состоянии компании** и **финансовых вопросах**, включая отсутствие выручки и банковского счета.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin', 'Mike Zakharov']},
#   {'meeting_id': '7df0ee56-0173-46af-a468-0ff0e65965ba',
#    'meeting_name': 'Оценка кандидата на пробный период',
#    'timestamp': datetime.datetime(2024, 9, 25, 14, 49, 33),
#    'is_indexed': True,
#    'meeting_summary': 'Обсуждение **кандидата** на позицию **бэкэнд-разработчика**, который продемонстрировал **хорошие навыки**, но не показал **достаточного опыта** в написании кода. Кандидат имеет **три с половиной года опыта**, но не хватает **жизненного опыта**. Обсуждается возможность его **найма на пробный период**. Необходимо запросить у кандидата **реальный код** для оценки его навыков. Обсуждаются **проблемы с текущими сервисами**, возникшие из-за изменений, внесенных текущим разработчиком, и планируется следующий контакт с кандидатом для получения дополнительной информации.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin', 'Sergey Ryabenko']},
#   {'meeting_id': 'ce1988d6-b5a7-4c04-b322-d986523f0e3c',
#    'meeting_name': 'Проблемы с API и интеграция редактора',
#    'timestamp': datetime.datetime(2024, 9, 23, 13, 29, 27),
#    'is_indexed': True,
#    'meeting_summary': 'Обсуждение **проблем с API** и **форматами данных**, включая **необходимость очистки данных** и **баги**. Настройка **интеграции редактора sargon-react-editor** с локальным файлом **atom2.env**. Обсуждение **SSH-ключей** и процесса подключения через **SSH**. Рассмотрение новых **возможностей редактора**, таких как работа с несколькими файлами и интеграция с **API OpenAI**. Обсуждение **недостатков текущей реализации API** и необходимости **фильтрации участников** встреч. Проблемы с **транскрипцией** и **документацией** по API.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin', 'Sergey Ryabenko']},
#   {'meeting_id': 'ad09fa20-04e3-426a-b930-f4f1139836bf',
#    'meeting_name': 'Тестирование пропускной способности системы',
#    'timestamp': datetime.datetime(2024, 8, 30, 8, 44, 3),
#    'is_indexed': True,
#    'meeting_summary': 'Обсуждение **узкого места** в системе **транскрипции**, связанного с **обработкой аудио** и **коннекшенами**. Необходимо определить, где именно возникает **узкое место** в системе, чтобы улучшить её производительность. Проведение **тестирования** для определения **пропускной способности** системы, включая организацию **50 одновременных встреч** для проверки нагрузки. Подготовка **аудио чанков** для тестирования, запись времени **задержки транскрипции** для анализа производительности. Обсуждение внедрения **куки** для отслеживания пользователей, проверка интеграции **Google Analytics** и обсуждение хранения **UTM-меток**.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Andrey Pisankin', 'Dmitriy Grankin', 'Sergey Ryabenko']},
#   {'meeting_id': '08a4b53e-6ff1-4a95-9263-57ca27f0995a',
#    'meeting_name': 'Продвижение продукта Векса',
#    'timestamp': datetime.datetime(2024, 10, 2, 10, 46, 11),
#    'is_indexed': True,
#    'meeting_summary': 'Обсуждение **необходимости** обратиться к **теплым контактам** для **продвижения продукта Векса**. **Определение условий** для размещения **постов** о продукте. **Создание черновиков постов** для пользователей, которые согласились разместить информацию о продукте. **Обновление страницы** на **Product Hunt** перед запуском продукта. **Чистка лендингов** и **соцсетей**, обновление **логотипа**. **Запрос помощи** у **Алексея** для продвижения продукта через его **нетворк**. **Разделение задач** по обращению к контактам. Обсуждение **ожидаемого количества переходов** и **регистраций пользователей** после запуска продукта.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin', 'Olga Nemirovskaya']},
#   {'meeting_id': '74f30386-e91f-4075-a0f8-f5c859481d7d',
#    'meeting_name': 'Парное программирование и его вызовы',
#    'timestamp': datetime.datetime(2024, 11, 20, 10, 21, 46),
#    'is_indexed': True,
#    'meeting_summary': 'Обсуждение **парного программирования** и его применения в команде. **Сергей** выражает **сомнения** в **масштабируемости** этого подхода, поднимая вопросы о **комфорте программистов** и возможном **выгорании**. **Дмитрий** делится своими трудностями с **React-кодом** и необходимостью **оптимизации** работы. Обсуждаются **конкретные задачи** для **Артема** и планируется **эксперимент** по совместной работе с ним. Также упоминаются **ноу-код** и **гитхаб** как инструменты, которые могут помочь в работе.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin', 'Sergey Ryabenko']},
#   {'meeting_id': '7122979f-9b4e-4d0f-92c7-18f6b1034197',
#    'meeting_name': 'Стартапы в AI и ипотека в Португалии',
#    'timestamp': datetime.datetime(2024, 9, 9, 16, 31, 30),
#    'is_indexed': True,
#    'meeting_summary': '**Макс** и **Дмитрий** обсуждают свои **стартапы**, включая **AI Travel Guide** и **real-time meeting assistant** для **Google**. **Макс** делится опытом получения **ипотеки** в **Португалии**, включая взаимодействие с банками и брокерами. **Дмитрий** дает советы по покупке **недвижимости** и анализирует **ипотечные ставки** и условия. Обсуждаются технологии для записи встреч и использование **гранолы** для транскрипции. Также затрагиваются темы **инвестиций** и **рынка недвижимости** в **Кашкайше** и **Белошколе**.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitry Grankin', 'Max Mironov']},
#   {'meeting_id': 'b1c57a93-7750-4633-a579-4d374d9c99f5',
#    'meeting_name': 'Проблемы с лендингом и маркетингом',
#    'timestamp': datetime.datetime(2024, 9, 11, 18, 41, 54),
#    'is_indexed': True,
#    'meeting_summary': 'Обсуждение **активности в LinkedIn**, включая **написание постов** и **комментариев**, а также **взаимодействие с потенциальной аудиторией**. Ольга отметила, что её посты получают хорошие **импрессии** и она добавила много новых **контактов**, интересующихся заметками по **Google Meet**. Обсуждение **проблем с лендинг-пейджем**, который ведет на **ошибку 404**. Ольга предложила улучшить сайт и лендинг-пейдж для повышения **конверсии**. Также обсуждались **маркетинговые усилия** и их эффективность в свете проблем с сайтом. Упоминались **статистика пользователей**, **новые юзеры**, **UTM-метки** и необходимость их использования для отслеживания трафика.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin', 'Olga Nemirovskaya']},
#   {'meeting_id': '99e22c95-9f1c-4704-b6ab-394e5d54e970',
#    'meeting_name': 'Обсуждение лендинга и гипотез',
#    'timestamp': datetime.datetime(2024, 9, 12, 19, 33, 33),
#    'is_indexed': True,
#    'meeting_summary': 'Обсуждение **необходимости копии лендинга** и его готовности. **Проверка нового лендинга для Google Ads**. **Обновление текстов и картинок на сайте**. **Поиск респондентов для тестирования**. **Планирование встреч на следующую неделю**. **Переделка основных сайтов**. **Обсуждение обратной связи от пользователей**. **Тестирование гипотез на большой аудитории**. **Подготовка к выходу на Product Hunt**. **Статистика пользователей и звонков**.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin', 'Olga Nemirovskaya']},
#   {'meeting_id': 'b3b8bd73-39f7-4155-84e1-c5c121f2f75b',
#    'meeting_name': 'Текущая ситуация и неопределенность',
#    'timestamp': datetime.datetime(2024, 11, 19, 18, 19, 9),
#    'is_indexed': True,
#    'meeting_summary': '**Что происходит?** - Вопрос о **текущей ситуации** или **происходящих событиях**. Вопрос задан в начале встречи, возможно, для выяснения **текущего состояния дел**. **Эээ...** - Выражение **неопределенности** или **замешательства**. Слово используется как реакция на вопрос, возможно, указывая на необходимость времени для **обдумывания**.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': []},
#   {'meeting_id': '8eb8d512-2ba3-40f4-8535-8bba86779336',
#    'meeting_name': 'Vexa Plugin Features and Market Insights',
#    'timestamp': datetime.datetime(2024, 12, 3, 11, 5, 19, 504000),
#    'is_indexed': True,
#    'meeting_summary': "**Dmitriy Grankin** showcased the **Vexa plugin**, which **transcribes conversations in real-time** and highlights **important points interactively**. The plugin can be installed from **vexa.ai** and works in **any language**, providing a **competitive advantage** over other transcription tools. **Dmitriy** highlighted the **competitive edge** of **Vexa** over other tools, particularly in its **real-time capabilities** and **language adaptability**. **Daniel** expressed dissatisfaction with current transcription tools, particularly their **language handling** and **accuracy**. There is a strong interest in the **Brazilian market** for the **Vexa plugin**, particularly among **crypto enthusiasts**. **Daniel** agreed to test the **Vexa plugin** and provide feedback on its functionality and market approach. Concerns about **data privacy** were raised, and **Dmitriy** assured that conversations are stored **locally** and not sent to any server. He proposed an **enterprise solution** where the **Vexa plugin** could run on a client's own servers for enhanced privacy. The meeting also touched on the limitations of other tools like **TLDV** and **Fireflies**, and the preference for **Google Meet** as the primary video conferencing tool.",
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Daniel', 'Dmitriy Grankin']},
#   {'meeting_id': '8029be21-158c-48b0-a057-880da2371844',
#    'meeting_name': 'Обсуждение Chrome Extension для транскрипции',
#    'timestamp': datetime.datetime(2024, 9, 2, 19, 55, 26),
#    'is_indexed': True,
#    'meeting_summary': 'Обсуждение продукта - **Chrome Extension** для **транскрипции аудио в текст**. Участники представили себя и обсудили свой опыт в **разработке**. Обсуждение **технического стека** и **архитектуры проекта**, включая **микросервисную архитектуру** и функции каждого микросервиса. Рассмотрены **Redis** и **Celery** для хранения данных и асинхронной обработки задач. Обсуждение отсутствия **админки** и ее потенциальной необходимости. Обсуждение **финансирования стартапа** и планов на будущее, включая получение **инвестиций**. Обсуждение технологий, таких как **FastAPI** и **Django**, а также **Data Science** и использование **SVM**. Упоминание о **криптовалютном кошельке** и других проектах.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin', 'Олег']},
#   {'meeting_id': 'c450ea95-dc3b-4bf8-9e47-1d4f7b99e6b7',
#    'meeting_name': 'Стартапы и легализация врачей',
#    'timestamp': datetime.datetime(2024, 9, 27, 12, 34, 46),
#    'is_indexed': True,
#    'meeting_summary': 'Дмитрий и Игорь обсуждают **переезд** и **жизнь в разных странах**, таких как **Кипр** и **Португалия**, делятся опытом и **плюсами и минусами** жизни в этих местах. Дмитрий делится идеей своего **стартапа** по **транскрибированию встреч** в реальном времени, обсуждает **маркетинг** и **привлечение пользователей**. Игорь рассказывает о своем бизнесе, который помогает **врачам легализоваться в Эмиратах**, включая подготовку к экзаменам и помощь с документами. Также обсуждаются планы по созданию **сообщества для предпринимателей** и форматы встреч.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitry Grankin', 'Igor Vinidiktov']},
#   {'meeting_id': '1579143f-3d96-4346-9220-febb329ca5ce',
#    'meeting_name': 'Идеи UX и стартапы Татьяны',
#    'timestamp': datetime.datetime(2024, 12, 2, 12, 10, 23, 270000),
#    'is_indexed': True,
#    'meeting_summary': '**Татьяна** предложила **улучшить UX**, изменив **дизайн таблицы**, чтобы она не занимала много **вертикального пространства** и выделяла **важные элементы**. Она считает, что поле должно быть самым значимым элементом и его нужно выделить ярче. Также Татьяна начала новую работу в качестве **дизайн-лида** в стартапе в индустрии **дистрибуции вина**. Она поделилась своим опытом участия в **акселераторе** и проблемами с заполнением таблицы **CastDev**, что затрудняет ее участие в акселераторе. Татьяна предложила создать **шаблоны для заданий**, адаптированные под конкретные бизнесы, и использовать различные **источники данных** для улучшения работы с информацией. Она выразила беспокойство по поводу **записи встреч** и **конфиденциальности данных**. Татьяна рассказала о своем взаимодействии с **инвестором** и стартапом, который ищет финансирование.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin', 'Tatiana Sukhova']},
#   {'meeting_id': 'cffaef24-0478-4b6a-93f9-533635e826bf',
#    'meeting_name': 'Статус стартапа и обновления продукта',
#    'timestamp': datetime.datetime(2024, 9, 1, 12, 1, 5),
#    'is_indexed': True,
#    'meeting_summary': 'Обсуждение **статуса стартапа**: Maksim Jmihov сообщил, что стартап **сохранился**, но была **продана только технология**. Ожидаются **деньги на американском счете**, но пока не получены. Обсуждение **обновлений UX** и **функционала продукта**, которые должны быть завершены к **четвергу**. Проблемы с **интеграцией платежной системы** и **открытием банковского счета**. Обсуждение **клиентской базы** и **маркетинга**, что привело к появлению **15 бесплатных пользователей**. Запланирована **демонстрация нового интерфейса** и **дашборда**. Обсуждение стратегии по **улучшению продукта** с акцентом на **реалтайм-транскрипцию**. Обсуждение **работы с фрилансерами** и **автоматизации задач**. Обсуждение **конкурентов** и их подходов, а также важности **коммуникации с клиентами**.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin', 'Maksim Jmihov']},
#   {'meeting_id': '7afff477-c0bd-44c1-92c9-75f94ac75d68',
#    'meeting_name': 'Обновление авторизации и токенов',
#    'timestamp': datetime.datetime(2024, 11, 18, 20, 0, 8),
#    'is_indexed': True,
#    'meeting_summary': 'Обсуждение **обновления метода авторизации** для **упрощения процесса** и **избежания регистрации** в разных местах. **Необходимость тестирования нового кода** авторизации для проверки его **работоспособности**. Идея **оптимизации процесса авторизации** для **сокращения времени** на обсуждения и улучшения **взаимопонимания** в команде. Проблема с **получением токена** и его **интеграцией** в новый метод авторизации. Обсуждение **юзердата** и **Storage Service** в контексте авторизации, а также проблемы с **дашбордом**. Упоминание о **фрикциях** в команде и необходимости их **сокращения**.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin', 'Sergey Ryabenko']},
#   {'meeting_id': '0e6d4428-6c61-4289-91e4-7173b1a21121',
#    'meeting_name': 'Создание бэкэнда интернет-магазина',
#    'timestamp': datetime.datetime(2024, 9, 17, 12, 30, 33),
#    'is_indexed': True,
#    'meeting_summary': 'Обсуждение **создания бэкэнда** для **интернет-магазина**, который будет **сохранять** и **отображать продукты**. Основные задачи включают **импорт продуктов** из **удаленного каталога** через **API**, определение **структуры данных** для продуктов, подход к **хранению цен** (в **центах** для избежания ошибок с плавающей точкой), **планирование архитектуры API** для получения данных, а также **валидацию** и **обработку ошибок** при импорте. Также обсуждались **юнит-тестирование** кода и архитектура для проекта, подобного **Uber**, включая **нагрузочное тестирование** и **масштабирование** системы.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin', 'Nick Frolov', 'Sergey Ryabenko']},
#   {'meeting_id': 'fb2aea72-f75d-4790-99dc-bbc4c7219a31',
#    'meeting_name': 'Стратегия продвижения в соцсетях',
#    'timestamp': datetime.datetime(2024, 10, 4, 16, 17, 26),
#    'is_indexed': True,
#    'meeting_summary': 'Обсуждение **стратегии** по **взаимодействию** с **продакхантером** в **LinkedIn**, включая **отправку сообщений** и **создание постов**. **Планирование** публикации постов в **Instagram** и **TikTok** на **португальском** и **бразильском** языках. Анализ **конкуренции** в **Бразилии** и отсутствие активных конкурентов. Проблемы с **email-рассылкой** и ее **неэффективностью**. Вопросы соблюдения **GDPR** и **комплаенса**. Сбор **отзывов** от пользователей и их значимость.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin', 'Olga Nemirovskaya']},
#   {'meeting_id': 'a2926b2d-f4eb-4bcc-864f-27607faa39fb',
#    'meeting_name': 'Обновление VEX и маркетинг',
#    'timestamp': datetime.datetime(2024, 8, 30, 17, 4, 58),
#    'is_indexed': True,
#    'meeting_summary': 'Обсуждение текущего состояния **VEX**, необходимость **обновления** и его функциональности. **Маркетинг** для привлечения новых клиентов, обсуждение стратегий и проблем с открытием **банковского счета** в США. **Управление активами** и налоговые стратегии для клиентов, а также идея создания **аудиокниг** с использованием технологий **генерации голоса** от **Eleven Labs**.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmtiry Grankin', 'Matt Lewis']},
#   {'meeting_id': 'e941833d-5234-4f52-9a2a-d68f9ba45e13',
#    'meeting_name': 'Работа с Reddit и Product Hunt',
#    'timestamp': datetime.datetime(2024, 9, 17, 19, 5, 27),
#    'is_indexed': True,
#    'meeting_summary': 'Обсуждение текущих проблем с **публикациями** на **Reddit** и активностью на **Product Hunt**. **Olga Nemirovskaya** упомянула, что **сообщения** отправляются только по **Product Hunt** и что есть сложности с **модерацией** постов на **Reddit**. Она планирует продолжать взаимодействие через **комментарии** и обсуждения. Также обсуждалось **перенос** ланча на следующую неделю, необходимость выбора **текстов** для работы с **дизайнерами** в **Figma**, проблемы с доступом к **LinkedIn**, и новые посты про **нотейкеры** и **Клода**.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin', 'Olga Nemirovskaya']},
#   {'meeting_id': '377bbdf0-3502-4e32-950f-44a1ef0fa0ed',
#    'meeting_name': 'Готовность проекта и задачи',
#    'timestamp': datetime.datetime(2024, 9, 17, 10, 21, 15),
#    'is_indexed': True,
#    'meeting_summary': 'Обсуждение текущего состояния проекта, где **Сергей** упомянул о **90% готовности**, что включает в себя различные **метрики здоровья** и **активности**. Необходимо **обновить код** и создать **дашборд**, который был сформирован как **MVP**. Обсуждение необходимости **верстки** и поиска **фрилансеров** для выполнения этой задачи. Планируется **тестирование** нового продукта и **онбординг** новых пользователей. Обсуждение **финансовых вопросов** и ставок, связанных с оплатой работы. Обсуждение нового продукта с **векторным поиском** для улучшения функциональности.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin', 'Sergey Ryabenko']},
#   {'meeting_id': 'e2864cf9-f8d5-4a22-85bc-d07557b634ee',
#    'meeting_name': 'Проблемы записи и бэкенд-разработка',
#    'timestamp': datetime.datetime(2024, 10, 14, 9, 39, 39, 514000),
#    'is_indexed': True,
#    'meeting_summary': 'Обсуждение **проблемы** с **записью звонков**, которая **периодически останавливается**, что критично для работы. Необходимо обеспечить **стабильную запись**. Также планируется работа с **бэкенд-разработчиками** для улучшения функционала, включая **создание тестового бэкенда** и **реализацию фильтрации и поиска** в **векторной базе данных**. Обсуждение **дизайна дашборда** и **интеграции платежной системы LemonSqueeze**. Рассмотрены **долговые обязательства** и планы по их погашению. Обсуждение **аналитики активных пользователей** и возможности внедрения **системы ачивок**.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin', 'Sergey Ryabenko']},
#   {'meeting_id': 'dd65ab42-1870-4158-9e2a-276fa5bda674',
#    'meeting_name': 'Создание скрипта для контакт-центра',
#    'timestamp': datetime.datetime(2024, 10, 10, 16, 34, 37),
#    'is_indexed': True,
#    'meeting_summary': 'Обсуждение **разработки скрипта** для **первого звонка** в **контакт-центре**, включая **анализ звонков** для создания текстов, **использование AI** для обработки данных, **фильтрацию звонков** по качеству, **разработку MVP**, **интеграцию с API**, **оптимизацию работы с аудиофайлами**, и создание **обучающего материала** для операторов. Участники обсуждают **промпт-инжиниринг** и **модель AI** для улучшения взаимодействия с клиентами.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin', 'Igor Bessonov']},
#   {'meeting_id': 'cde02f21-5001-4f19-b477-5dc4a04017fd',
#    'meeting_name': 'Обсуждение задач и онбординга',
#    'timestamp': datetime.datetime(2024, 9, 11, 10, 57, 53, 150000),
#    'is_indexed': True,
#    'meeting_summary': 'Обсуждение **новых участников команды** и их **ролей**. Представлены **Сергей** (фронтенд) и **Сергей** (бэкенд), обсуждены их **навыки** и **опыт**. Определены **задачи** по **бэкенду** и **онбордингу** нового сотрудника. Обсуждена **необходимость создания бэкапов базы данных** для предотвращения потери данных. Запланирован **переезд в Google Cloud** и **тестирование узких мест**. Подготовка **документов** и **соглашений** с компанией. Обсуждение **коммуникаций** в команде и их **эффективности**. Обсуждение **рабочего процесса** и **формата задач**. Настройка **доступа** к **репозиториям** и **серверу**. Обсуждение **практик бэкапа** и **восстановления данных** в **PostgreSQL**. Планирование **будущих задач** и **функционала** после онбординга.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin', 'Sergey Ryabenko', 'Xut tuX']},
#   {'meeting_id': '8ff59e4c-7cf3-444d-88bc-c6b25392e3e2',
#    'meeting_name': 'Дебаг и интеграция локального чата',
#    'timestamp': datetime.datetime(2024, 11, 6, 15, 42, 37),
#    'is_indexed': True,
#    'meeting_summary': 'Необходимо провести **дебаг** **локального чата**, чтобы устранить текущие проблемы с его работой. Локальный чат должен работать аналогично **глобальному**, с использованием **thread id**. Обсуждались изменения в **API**, которые необходимы для корректной работы локального чата. Также необходимо создать и протестировать новые функции, такие как интеграция с **Google аутентификацией** и создание **лендинга** для чата. Обсуждались проблемы с **токенами**, которые мешают доступу к необходимым функциям, и планирование дальнейших шагов по интеграции новых функций и исправлению ошибок.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin', 'Sergey Ryabenko']},
#   {'meeting_id': '0975286d-9436-429d-8c74-889242d1b956',
#    'meeting_name': 'Проблема с безопасностью токена',
#    'timestamp': datetime.datetime(2024, 11, 10, 12, 10, 39, 300000),
#    'is_indexed': True,
#    'meeting_summary': 'Обсуждение инцидента, связанного с **подцеплением токена**. Участник **nan** сообщил о том, что кто-то **подцепил его токен**, что может указывать на **проблемы с безопасностью** или **доступом к системе**. Упоминается, что это может указывать на возможные **проблемы с безопасностью**.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': []},
#   {'meeting_id': 'be01a03e-daf7-48e9-a867-fa5e08219d30',
#    'meeting_name': 'Обновление БТ и создание клубов',
#    'timestamp': datetime.datetime(2024, 8, 25, 14, 55, 29),
#    'is_indexed': True,
#    'meeting_summary': 'Обсуждение **необходимости обновления** версии БТ с **8.14.0** до **8.20.1** из-за проблем с **контентом** и **HTML-контентом**, который приходит пустым. Рассмотрение идеи создания **клуба по электротехнике** для детей, где они смогут заниматься **моделированием** и **программированием**. Обсуждение **API авторизации LinkedIn** и **структуры сообщений** в чате, чтобы избежать повторения имен спикеров. Предложение создать **расширение** для упрощения записи задач без необходимости запуска митинга.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin', 'Sergey Ryabenko']},
#   {'meeting_id': '3540f190-1f83-4100-8d6f-e648752f336d',
#    'meeting_name': 'LinkedIn Lead Generation Strategies',
#    'timestamp': datetime.datetime(2024, 9, 26, 12, 2, 2),
#    'is_indexed': True,
#    'meeting_summary': 'The meeting focused on **lead generation via LinkedIn**, discussing its effectiveness as a primary channel for outreach. **Dmitry** expressed the need for a more strategic approach, noting that immediate networking has become **exhausting** and **not scalable**. **Andy** raised concerns about **Google Ads**, highlighting the **non-linear** nature of marketing and the difficulty in finding effective strategies. **Competitor analysis** was conducted, identifying key players like **Otter.ai**, **Fireflies**, and **Fathom**. The potential to target **larger companies** by addressing **data security** and **privacy concerns** was discussed, along with the importance of **content creation** for LinkedIn, particularly engaging **video content**. The use of **Google Keyword Planner** for identifying relevant keywords was also emphasized, alongside the need for **ad copy** and **landing page testing** to optimize conversion rates.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Andy Black', 'Dmitry Grankin']},
#   {'meeting_id': 'e4b4ba0c-1249-400a-81eb-469361572591',
#    'meeting_name': 'Business Strategy and User Growth',
#    'timestamp': datetime.datetime(2024, 12, 5, 13, 59, 51, 280000),
#    'is_indexed': True,
#    'meeting_summary': "**Overview of current business situation and bottlenecks**: Sunny Wyrzykowski aims to understand the **current business situation** and **bottlenecks** faced by **Dmitry Grankin**. Dmitry mentioned that he currently has around **300 users** and is looking to increase this number significantly in the next **6-12 months**. He faces challenges with **payment integration** and lacks a **bank account**, which limits his ability to monetize the product. **Discussion of goals for the business**: Dmitry expressed his goal to reach a few thousand **paying users** within the next **6-12 months**, aiming for each user to pay **$20 monthly**. He is testing **sharing functionality** to enhance collective knowledge access. **Exploration of target audience and user statistics**: Dmitry shared insights about his target audience, primarily **Google Meet users**, with significant interest from **Brazilian crypto teams**. He highlighted the **multilingual capability** of his product as a competitive advantage. **Discussion of current user acquisition strategies**: Dmitry discussed his current strategies for acquiring users, primarily through **word of mouth** and some outreach efforts, including **Product Hunt** and **LinkedIn**. **Proposal for a strategy session with a consulting expert**: Sunny proposed a **strategy session** with one of Ace Makers' consulting experts to analyze Dmitry's current situation and create an initial plan with action steps for the next six months. **Clarification of consulting fees and structure**: Sunny clarified the investment required for consulting services from Ace Makers, ranging from **1,800 to 2,300 euros** per month for a six-month program. **Feedback on competitor products**: Dmitry provided feedback on **Fathom**, a competitor product he is currently using, expressing satisfaction with its performance. **Discussion of product features and advantages**: Dmitry highlighted the unique features of his product, including remaining silent during calls and offering **multilingual support**.",
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitry Grankin', 'Nora Köppling', 'Sunny Wyrzykowski']},
#   {'meeting_id': 'd7d8d9e4-f349-42b3-9599-f9707f1405f8',
#    'meeting_name': 'Стратегии привлечения пользователей',
#    'timestamp': datetime.datetime(2024, 9, 10, 9, 28, 46),
#    'is_indexed': True,
#    'meeting_summary': 'Обсуждение **низкого использования Google Ads** среди конкурентов, таких как **Fireflies**, **Notte** и **Supernormal**, что может указывать на более эффективные стратегии. Создание **списка платных и бесплатных директорий** для увеличения трафика. Анализ **конкурентных преимуществ и недостатков**, выявленных через общение с пользователями. Разработка **лендинг-пейджей** на разных языках для привлечения международной аудитории. Определение **целевой аудитории** для более эффективного маркетинга. Сбор и анализ **отзывов пользователей** для улучшения продукта. Подготовка к запуску на **Product Hunt** для увеличения видимости продукта. Анализ **трафика конкурентов** и определение **гипотез** для привлечения пользователей. Устранение **недостатков продукта** на основе отзывов пользователей.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin', 'Olga Nemirovskaya']},
#   {'meeting_id': 'fa6923af-1655-4564-bc97-6f436e0e664e',
#    'meeting_name': 'Аналитика анбординга и маркетинг',
#    'timestamp': datetime.datetime(2024, 9, 6, 14, 38, 4),
#    'is_indexed': True,
#    'meeting_summary': 'Обсуждение текущей **аналитики** по **анбордингам**, чтобы понять, как они работают и какие есть возможности для **улучшения**. Участники обсудили, что у всех есть анбординги в каком-то виде, и это важно для **конверсии**. Также была проведена **оценка анбординга конкурентов** (TLDV и FireFiles) для выявления лучших практик. Обсуждалась **идея создания комьюнити** для пользователей, чтобы использовать **транскрипции** и улучшать продукт. Участники разработали **план по улучшению конверсии** через анбординг, включая создание формы для сбора данных пользователей. Обсуждение результатов **Google Ads** и планов по их **оптимизации** также было важной частью встречи. Участники обсудили **выход на Product Hunt** для получения фидбэка и первых регистраций.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitrii Bashkirov', 'Dmitry Grankin']},
#   {'meeting_id': '50d5d659-3a57-42f2-8f32-31c7145ebe91',
#    'meeting_name': 'User Retention and Investment Insights',
#    'timestamp': datetime.datetime(2024, 10, 24, 9, 32, 32),
#    'is_indexed': True,
#    'meeting_summary': "**Özay Demirezen** shared **positive feedback** about **user retention** and the **steady growth** of the user base for his product, indicating that the product is promising despite not being fully mature. He mentioned having some users with good retention rates and is currently developing features based on **user requirements**. **Özay** discussed his experience with securing **investment** and the challenges of managing **cash flow** in a startup environment, mentioning a **one million** investment but facing challenges with **cash burn**. **Dmitry Grankin** raised a concern about the inability to **record phone calls**, especially during on-the-go conversations, and suggested exploring solutions to integrate this feature into **Özay's product**. **Özay** shared insights on the **crowded market** for his product and the challenges of competing with established players, emphasizing the importance of understanding **competition** and **user needs**. He outlined plans for future product development based on **user feedback** and engagement metrics.",
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitry Grankin', 'Özay Demirezen']},
#   {'meeting_id': '563c58ec-10ce-4c14-ba47-cddf45e87902',
#    'meeting_name': 'Работа с микросервисами и планы',
#    'timestamp': datetime.datetime(2024, 9, 10, 11, 3, 49),
#    'is_indexed': True,
#    'meeting_summary': 'Обсуждались **детали работы с микросервисами**, включая их **архитектуру** и **функциональность**. Упоминались три **микросервиса**: один для **получения звука**, второй для **транскрибирования** и **хранения данных**, третий для **взаимодействия с пользователем**. Также обсуждались технологии, такие как **OLM** и **Celery** для **многопоточной обработки задач**. Обсуждены **планы по завершению текущего проекта**, который заканчивается через две недели, связанный с **мониторингом системы**. Спикер ищет новые возможности по **графику работы** и **зарплате**, открытый к предложениям о **подработке** или **фуллтайме**.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitry Grankin', 'Nick Frolov']},
#   {'meeting_id': 'c17d3344-672f-457a-bf59-1b095614bcfc',
#    'meeting_name': 'Обсуждение прототипа и интеграции',
#    'timestamp': datetime.datetime(2024, 9, 23, 9, 26, 16),
#    'is_indexed': True,
#    'meeting_summary': 'Обсуждение **прототипа проекта** как **почти полнофункционального**, но требующего дальнейшей работы. **Интеграция новой кнопки** для улучшения функциональности. Предложение использовать **Google Cloud** для создания инстансов и совместной работы. Обсуждение **проблем с поддержкой** и разбивкой файлов. Запланирован **созвон с Артемом** для обсуждения сайта.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin',
#     'Dmitriy Grankin (Presentation)',
#     'Sergey Ryabenko']},
#   {'meeting_id': 'aa87b543-f5c9-426c-a6ed-77b26f93e0da',
#    'meeting_name': 'Разработка API и интерфейса',
#    'timestamp': datetime.datetime(2024, 10, 20, 12, 46, 32, 230000),
#    'is_indexed': True,
#    'meeting_summary': 'Обсуждение **API** и **фронтенда**: **Дмитрий Гранкин** сообщил о разработке **API** и **фронтенда**, который пока не работает должным образом. **Сергей Рябенко** поделился мнением о модели **LAMA 3.2** с 90 миллиардами параметров, которая показала хорошие результаты в тестировании. Обсуждались задачи по **доработке интерфейса** для клиента, **исправлению ошибок** в коде, **интеграции с LocalStorage** для хранения данных пользователя и **планированию дальнейших шагов** по проекту. Также упоминались конкуренты, такие как **NVIDIA**, **GPT-4**, **SONNET** и **реплито**.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin', 'Sergey Ryabenko']},
#   {'meeting_id': '331c3dbb-9233-4894-ad9d-6a537df88b7b',
#    'meeting_name': 'Лицензированный продукт для компаний',
#    'timestamp': datetime.datetime(2024, 9, 9, 9, 55, 46),
#    'is_indexed': True,
#    'meeting_summary': 'Обсуждение возможности предоставления **лицензированного продукта** для компаний с проблемами **приватности**. Продукт должен работать **локально** и удовлетворять требованиям **безопасности**. Планирование **аутричей** для выявления интереса к продукту. Необходимость связи с **Екатериной Вабрайк** для анализа **массивов данных**. Проверка тестовой **воронки** на платформе **VEX**. Обсуждение **email-маркетинга** и интеграции с **MailChimp**. Оптимизация **рекламных материалов** и **лендингов**.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin', 'Olga Nemirovskaya']},
#   {'meeting_id': '0c743875-dd3b-498c-ada8-6b75d45542ed',
#    'meeting_name': 'Индексация и функционал чата',
# ...
#   {'meeting_id': '66528ad8-a00c-41e2-adfa-6ee53c18b7ff',
#    'meeting_name': 'Подключение и настройка SSH',
#    'timestamp': datetime.datetime(2024, 11, 20, 14, 40, 37),
#    'is_indexed': True,
#    'meeting_summary': "Обсуждение процесса **подключения к серверу** через **SSH**, включая **создание новых SSH ключей**, **настройку конфигурации SSH**, использование **VS Code** для работы с SSH, а также проблемы с **доступом и ключами SSH**. Участники обсуждают **ввод паролей** при подключении и возможные ошибки, такие как **'Permission denied'**.",
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Artem Puzik', 'Dmitriy Grankin']},
#   {'meeting_id': '27d45c17-ef8d-49f4-bf40-85567c479c11',
#    'meeting_name': 'Эффективность встреч и обновления',
#    'timestamp': datetime.datetime(2024, 11, 14, 15, 49, 17),
#    'is_indexed': True,
#    'meeting_summary': 'Обсуждение текущего состояния **встреч** и их **эффективности**. **Дмитрий Гранкин** поднял вопрос о том, как проходят **встречи** и насколько они **эффективны**. Обсуждение включает в себя **анализ** текущих процессов и возможные **улучшения**. Также упомянуто о необходимости **обновления системы** **Ективните козиралката**, что может повлиять на работу **встреч** и их организацию. Обсуждены **проблемы**, возникающие в процессе работы, и текущие **задачи**.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin']},
#   {'meeting_id': '553fcfe6-0143-4971-99e7-213245f63347',
#    'meeting_name': 'Оптимизация Vexa и новые идеи',
#    'timestamp': datetime.datetime(2024, 10, 30, 14, 13, 33),
#    'is_indexed': True,
#    'meeting_summary': 'Обсуждение **производительности фронтенда**, включая **синхронность** и **оптимизацию кода**. Планирование **доработки Vexa Multi Assistant** для улучшения функционала. Идея создания **white label версии** для юристов. Обсуждение возможности проведения **курсов по Vexa**. Планирование **роутинга** для нового функционала. Упоминание о **мобильной версии** продукта и его использовании в **судебных заседаниях**. Обсуждение **документов**, **инженерных навыков**, **прототипирования**, **маркировки**, **лайфкодинга** и **дизайн системы**.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin', 'Sergey Ryabenko']},
#   {'meeting_id': 'e85a7645-53aa-4e18-92a9-09a5b1886f30',
#    'meeting_name': 'Ассистент для Google Meet и партнерства',
#    'timestamp': datetime.datetime(2024, 12, 3, 13, 1, 31, 464000),
#    'is_indexed': True,
#    'meeting_summary': 'Обсуждение возможностей **ассистента для звонков Google Meet**, который может делать **транскрипцию** и собирать **знания**. Ассистент использует модель **Charge 5** для преобразования звука в текст и создания **дашборда** для анализа звонков. Необходимо протестировать его функционал. Обсуждение текущего состояния **пользовательской базы** и **конкуренции** на рынке. Пользовательская база растет медленно, но продукт конкурентоспособен. Планирование **бизнес-завтрака** на тему **партнерств**, где резиденты делятся опытом. Запуск нового формата **мастер-майнд** для тестирования **маркетинговых гипотез**. Обсуждение **членского взноса** клуба в 200 евро в месяц.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Anna Pavlova (Lupenko)', 'Dmitry Grankin']},
#   {'meeting_id': '2647ed9b-411e-46dc-ba53-c08ef2887479',
#    'meeting_name': 'Идеи по стартапам и токенизации',
#    'timestamp': datetime.datetime(2024, 10, 18, 15, 23, 30),
#    'is_indexed': True,
#    'meeting_summary': 'Обсуждение функционала нового **ассистента** для **звонков**, который записывает **аудио** и **видео**, а также позволяет **искать** и **фильтровать** звонки. Рассмотрены **планы** по стартапу в **Португалии**, где один из участников является **соло-фаундером**. Обсуждение **токенизации недвижимости** для упрощения доступа к инвестициям, а также использование **искусственного интеллекта** в **путешествиях**. Затронуты вопросы **гражданства** и жизни в **Аргентине** и **Португалии**, а также проблемы с реализацией **реального времени** в продукте. Обсуждены **планы** по улучшению функционала **VEX** и использование **криптовалют** в инвестициях.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin', 'Sergio Goriachev']},
#   {'meeting_id': '08b8398e-0b1b-4771-9516-f414888dc500',
#    'meeting_name': 'Тестовая запись и Userflow',
#    'timestamp': datetime.datetime(2024, 12, 3, 10, 23, 18),
#    'is_indexed': True,
#    'meeting_summary': 'Обсуждение **тестовой записи** для понимания, как она пройдет, и **вопрос о Userflow** для уточнения деталей и визуализации. **Тестовая запись** проводится для анализа процесса и выявления возможных проблем, а также для понимания, как пройдет встреча. Интересует, как выглядит **пользовательский поток** в контексте обсуждаемой темы.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': []},
#   {'meeting_id': '83597753-71c0-4792-a3a2-cc275abaa221',
#    'meeting_name': 'Future Plans Overview',
#    'timestamp': datetime.datetime(2024, 11, 10, 13, 15, 8),
#    'is_indexed': True,
#    'meeting_summary': 'The meeting opened with a general inquiry about the **upcoming agenda** and what will be discussed. The speaker expressed **curiosity** about the **topics** that will be covered, indicating a need for **clarity** on **future plans** and **objectives**. A statement reflected a sense of **anticipation** for **future events** or discussions.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': []},
#   {'meeting_id': 'f5114d1b-b319-4474-8d7e-24f96fd5241b',
#    'meeting_name': 'Проверка связи перед встречей',
#    'timestamp': datetime.datetime(2024, 11, 24, 13, 32, 41),
#    'is_indexed': True,
#    'meeting_summary': 'Обсуждение началось с **проверки связи**, что является **стандартной практикой** перед началом встречи.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': []},
#   {'meeting_id': '0220af3b-b112-47c5-b65f-6e75778c0842',
#    'meeting_name': 'Причины пропуска и личная роль',
#    'timestamp': datetime.datetime(2024, 11, 25, 13, 53, 17),
#    'is_indexed': True,
#    'meeting_summary': 'Обсуждение **причины**, по которой **что-то может быть пропущено**. Упоминается возможность **пропуска** чего-то по **неизвестной причине**. Говорящий размышляет о своей **роле** в каком-то процессе.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': []},
#   {'meeting_id': '472fca20-8cf3-4910-b08d-88b93d4919ef',
#    'meeting_name': 'Разработка стартапа Vexa и планы',
#    'timestamp': datetime.datetime(2024, 9, 6, 16, 21, 24),
#    'is_indexed': True,
#    'meeting_summary': 'Обсуждение стартапа **Vexa** и его продукта, который находится на стадии **пресета** и занимается **транскрибацией речи в текст**. **Юрий Б** представил свой опыт в **ML** и **бэкенд-разработке**, включая использование **FastAPI**, **Docker**, **Postgres** и **Redis**. Обсуждалась **архитектура решения** на **Flask** и планы по **развитию функциональности** продукта, включая интеграцию с **векторными базами данных**. Также обсуждались вопросы **занятости** и **оплаты работы** для нового сотрудника, а также методы **коммуникации** в команде через **Telegram**.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin', 'Юрий Б']},
#   {'meeting_id': 'e6ce439d-5802-4914-8271-4fbcea74ee94',
#    'meeting_name': 'Коробочные решения и анализ данных',
#    'timestamp': datetime.datetime(2024, 9, 9, 15, 30, 50, 724000),
#    'is_indexed': True,
#    'meeting_summary': 'Обсуждение **коробочного решения** для компаний, позволяющего устанавливать **бэкэнд** в контуре организации для соблюдения **privacy concern**. Рассмотрение **анализа массивов текстов** для извлечения полезной информации и анализа конкурентов. Идея создания продукта для людей с ограничениями, включая **автоматическую транскрипцию** и перевод. Обсуждение **инвестиционных возможностей** для стартапов в области **HR** и **психологического тестирования**. Обсуждение **программного обеспечения** для **транскрипции** и **анализа данных** в реальном времени.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitry Grankin', 'Tatiana Illarionova-Zervas']},
#   {'meeting_id': 'b2df54b2-e91e-4d41-bd4a-48c8fc99e5fb',
#    'meeting_name': 'Эффективность воронок продаж и автоматизация',
#    'timestamp': datetime.datetime(2024, 12, 2, 15, 29, 11),
#    'is_indexed': True,
#    'meeting_summary': 'Обсуждение **воронок продаж** и их **эффективности**. Игорь и Дмитрий отметили важность **прогрева пользователей** перед **платным контентом**. Обсуждены проблемы с **переключением языков** во время звонков, что приводит к **потере информации**. Дмитрий поделился опытом использования **тактика** для записи звонков, его недостатками, включая **неаккуратную транскрипцию** и отсутствие **аудиозаписей**. Игорь представил функционал **Vex.ai** для автоматизации работы с записями звонков. Обсуждены проблемы с **автоматизацией задач** после звонков и стоимость лицензий на **тактик** и **Vex.ai**.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin', 'Igor Lyubimov']},
#   {'meeting_id': '895fd1f2-fa6f-4611-890f-18876d918a60',
#    'meeting_name': 'Продукт Векса и управление выручкой',
#    'timestamp': datetime.datetime(2024, 9, 6, 18, 2, 21),
#    'is_indexed': True,
#    'meeting_summary': 'Дмитрий представил продукт **Векса**, который является **онлайн-системой** для **распознавания речи** в **реальном времени** с возможностью **выделения важных моментов**. Продукт пока не публичный, имеет **задержку в 15 секунд** и позволяет пользователям взаимодействовать с контекстом разговора. Даниил рассказал о системе **управления выручкой**, которая включает **прогнозирование спроса** и **оптимизацию цен** для авиакомпаний. Обсуждались **планы по созданию портала** для пользователей, где будут храниться все звонки и транскрипции. Также отмечалась **уникальность продукта Векса** благодаря способности обрабатывать аудио в реальном времени и обсуждались **доступность разработчиков** и **финансовые ожидания**.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Daniil Andreev', 'Dmitry Grankin']},
#   {'meeting_id': 'b8880903-8d2c-4924-b6a8-64f73b8b52ad',
#    'meeting_name': 'AI Marketing Strategies and Collaborations',
#    'timestamp': datetime.datetime(2024, 10, 10, 18, 45, 35, 984000),
#    'is_indexed': True,
#    'meeting_summary': '**AI Marketing Directory** is a curated directory of **AI business tools**, focusing on **influencer marketing** primarily on **Twitter**, with plans to expand to other platforms. The company operates a **backend content service** leveraging a network of **influencers** to promote AI tools through curated content, aiming for **maximum exposure** for their partners by paying influencers to share their content. They discussed their **influencer marketing strategy**, utilizing a network of influencers to repost content for engagement. Examples of **successful** and **unsuccessful products** were shared, including **Hautech**, which allows online fashion designers to showcase their designs using AI, and **Quick Blocks**, which struggled due to a mismatch in target audience. The company optimizes for **clicks** but emphasizes the importance of generating **sales** as a key performance indicator. They proposed a collaboration with **Vexa**, including specific offerings and pricing, and concluded with plans for **follow-up communication**.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['AI Marketing Directory', 'Dmitry Grankin', 'Ethan Noah']},
#   {'meeting_id': '3ead8b34-f5de-42ef-8d28-5dd64a2b8669',
#    'meeting_name': 'Стратегия маркетинга и кастдева',
#    'timestamp': datetime.datetime(2024, 9, 16, 9, 47, 32),
#    'is_indexed': True,
#    'meeting_summary': 'Обсуждение **новых постов на Reddit**, один из которых **собрал 1300 просмотров**. Идея написать **сравнение конкурентов** для привлечения внимания к продукту. **Сбор информации о пользователях** для улучшения продукта через **кастдев**. Подготовка **лендинг-пейджа** для тестирования интереса пользователей. Определение **целевой аудитории** и **квалификация респондентов** для тестирования продукта. Тестирование **value proposition** для определения привлекательности продукта. Упоминание **Google Meta** и **Product Hunt** как инструментов для анализа конкурентов.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin', 'Olga Nemirovskaya']},
#   {'meeting_id': '55fb40e1-096c-4280-b205-aa4cc68f6c76',
#    'meeting_name': 'SEO и Google Ads стратегии',
#    'timestamp': datetime.datetime(2024, 9, 6, 14, 31, 40),
#    'is_indexed': True,
#    'meeting_summary': 'Обсуждение **маркетинговых стратегий** конкурентов, включая **SEO**. **Необходимо пересмотреть** текущие **рекламные кампании** в **Google Ads**. Также требуется **развивать** начальный **фреймворк онбординга** и понять, как **интерпретировать данные** из **SimilarWeb**.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitry Grankin', 'Olga Nemirovskaya']},
#   {'meeting_id': '045b1182-d64d-421a-8b33-1ff503e7fd58',
#    'meeting_name': 'Промоция постов и использование Клода',
#    'timestamp': datetime.datetime(2024, 9, 2, 18, 7, 19),
#    'is_indexed': True,
#    'meeting_summary': 'Обсуждение **постов** и их **продвижения**, включая **просмотры** и **комментарии**. Рассмотрение **возможностей** использования **Клода** для **автоматизации** обработки **звонков** и создания **отчетов**. Планирование **воркшопов** и мероприятий, обсуждение их **содержания** и **формата**. Анализ **состояния сайта** и его **SEO-оптимизации**, необходимость перехода с **Тильды** на другой **конструктор**. Обсуждение **активности** в **LinkedIn** и анализ **конверсии** постов.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin', 'Olga Nemirovskaya']},
#   {'meeting_id': 'eee87a80-0a72-4468-a105-8534bd6a6c21',
#    'meeting_name': 'Проверка записей и изменения в Тильде',
#    'timestamp': datetime.datetime(2024, 8, 30, 15, 1, 10),
#    'is_indexed': True,
#    'meeting_summary': 'Обсуждение **проверки записей sign-in** для пользователей, чтобы понять, есть ли какие-либо данные о регистрации. Все записи **sign-in** оказались **нулевыми**. Ольга должна внести **изменения в Тильду** для установки домена. Также обсуждалась **вставка HTML кода в секцию head** сайта, где необходимо убрать старый код и заменить его на новый. Обсуждение **проблем с куками** и их настройками, где было отмечено, что куки не работают по умолчанию и необходимо явно указывать, что отправка должна происходить с куками. Важность **командной работы** и достижения конечного результата также была затронута.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin', 'Olga Nemirovskaya', 'Sergey Ryabenko']},
#   {'meeting_id': '40001390-7187-47a7-9284-a1dab5dc0df6',
#    'meeting_name': 'Форматы вебинаров и мастер-классов',
#    'timestamp': datetime.datetime(2024, 9, 5, 18, 45, 16, 340000),
#    'is_indexed': True,
#    'meeting_summary': 'Обсуждение **оптимального количества участников** для **вебинаров** и **мастер-классов** для обеспечения **вовлеченности** и **обратной связи**. Оптимальное количество участников для вебинаров - **3-10 человек**. Обсуждение необходимости **разделения участников** на группы по интересам для более эффективного общения. Разработка формата **взаимодействия** с участниками после мастер-классов, включая **серии практических воркшопов**. Идея разработки **продукта для транскрибирования** и анализа звонков для **корпоративных клиентов** с акцентом на **безопасность** и **контроль данных**. Обсуждение **снижения конверсий** и **регистраций** пользователей, необходимость анализа причин. Разработка стратегии **email-рассылок** для активных пользователей. Поиск информации о **хакатонах** и **акселераторах** для участия.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin', 'Olga Nemirovskaya']}]}

# %%
from api_client import global_search
result = global_search(query="product hunt", limit=200, min_score=0.4)
result
# Out:
# {'total': 68,
#  'meetings': [{'meeting_id': '4ff12d56-f520-4391-a283-03d6365b49e6',
#    'meeting_name': 'Vexa Usability and User Insights',
#    'timestamp': '2024-09-09T10:46:10',
#    'is_indexed': True,
#    'meeting_summary': "Robert provided **positive feedback** on **Vexa's clean interface** and **usability** compared to **Fireflies**, emphasizing the importance of a **non-bloated design**. He appreciates Vexa's **straightforward interface**, which allows for easy access to **call transcripts** and **chat functionalities**. Robert compared Vexa with Fireflies, highlighting Vexa's **superior features** and **user experience**. He noted that Fireflies' **AI summaries** were often too lengthy and not useful, while Vexa allows for **direct interaction** with the transcript. They discussed the **real-time transcription feature** of Vexa, with Robert indicating he finds it **distracting**. Robert shared his **workflow** using Vexa, detailing how he integrates it into his **note-taking process**. They discussed potential **collaboration** on **testimonials** to promote Vexa, with Robert expressing interest in providing a testimonial. Robert provided insights into **user preferences** for **interface design** and **functionality**, emphasizing a preference for **simpler interfaces**. They discussed **future improvements** for Vexa based on user feedback, including the need for **adaptive features** for different user types.",
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitry Grankin', 'Robert Hangu']},
#   {'meeting_id': '1be62b63-99ea-4aea-b284-a2ed45e44b82',
#    'meeting_name': 'Стратегия рекламы и аналитика',
#    'timestamp': '2024-10-08T11:25:03',
#    'is_indexed': True,
#    'meeting_summary': 'Обсуждение **приостановки Google Ads** и **тестирования рекламы на YouTube-каналах** для привлечения трафика. Анализ **трафика с Product Hunt**, включая **статистику пользователей** и **конверсию**. Планирование **сбора обратной связи от пользователей** для улучшения продукта. Разработка **контента и видео** для продвижения, включая **работу с подрядчиками и инфлюенсерами**. Обсуждение **возможностей работы с испаноязычной аудиторией** в **Бразилии** и **Мексике**.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin', 'Olga Nemirovskaya']},
#   {'meeting_id': 'd7c8bfce-a97b-4f0e-ad22-f925cad1460d',
#    'meeting_name': 'Обсуждение погоды и бизнес-инициатив',
#    'timestamp': '2024-10-09T13:02:19',
#    'is_indexed': True,
#    'meeting_summary': 'Обсуждение текущей **погоды** в **Финляндии**, где температура колеблется от **18 до 20 градусов**. **Дмитрий** готовит документы для подачи на **гражданство**. Команда **Дмитрия** заняла **шестое место** на **Product Hunt** с минимальной подготовкой. Обсуждение методов **маркетинга** и **привлечения пользователей**, включая **Google Ads**, но результаты были незначительными. Успешная интеграция с **инфлюенсером** в **Бразилии** привела к новым пользователям. **Надя** запускает платную подписку для **StoryMan** и пересматривает цены из-за увеличения генерации контента. Обсуждение проблем с **кредитами** и необходимостью введения лимитов. Планирование следующей встречи.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin', 'Nadya Gorodetskaya']},
#   {'meeting_id': 'c6bd2072-dcd6-45b9-8006-7b975bfe43ad',
#    'meeting_name': 'Увеличение видимости продуктов',
#    'timestamp': '2024-10-04T11:09:37',
#    'is_indexed': True,
#    'meeting_summary': 'Обсуждение **текущего статуса продуктов** на **Product Hunter**, включая их **видимость** и **позиции** в списках. Обсуждали, что некоторые продукты не показываются на главном экране, и что необходимо **улучшить видимость**, чтобы попасть в **первую десятку**. Также была поднята **необходимость ответов на комментарии пользователей** для повышения **вовлеченности** и **активности** в социальных сетях. Обсуждали **стратегию** по выходу в первую десятку, создание новых постов и анализ активных аккаунтов для взаимодействия.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin', 'Olga Nemirovskaya']},
#   {'meeting_id': 'f5f969d6-675f-4d55-a604-78208e545dcd',
#    'meeting_name': 'Обсуждение улучшений VEX.ai',
#    'timestamp': '2024-09-16T15:35:38',
#    'is_indexed': True,
#    'meeting_summary': 'Обсуждение **пользовательского опыта** с **VEX.ai**, включая **положительные** и **отрицательные аспекты**. Участники отметили **необходимость улучшения интерфейса**, в частности, **проблемы с видимостью окон** и **управлением ими**. Обсуждались **идеи по улучшению интерфейса** и **функционала**, такие как **анимации** и **визуализация информации**. Также была затронута **обратная связь** по **функционалу** и **интерфейсу**, включая **проблемы с API** и его **обслуживанием**. Участники обсудили **возможности fine-tuning** для **юридического ассистента** и **ценностное предложение нового продукта**.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin', 'Ilia Semukhin']},
#   {'meeting_id': '2e36140e-e62e-4657-bbb4-a0473dbf608e',
#    'meeting_name': 'Разработка мультиязычного ассистента',
#    'timestamp': '2024-09-10T10:05:24',
#    'is_indexed': True,
#    'meeting_summary': 'Обсуждение **разработки** мультиязычного **ассистента** для **транскрипции** звонков, который будет обеспечивать **контекстуальную информацию** и **мультиязычность**. **Создание дэшборда** для сбора данных о звонках, который должен быть реализован в течение **2-4 недель**. Обсуждение **проблем интеграции** в корпоративные системы из-за **требований безопасности данных**. Стратегии **маркетинга** для привлечения новых пользователей и возможность выхода на **корпоративный рынок** через **консалтинговые компании**. Идея создания **виртуального тренера** на основе собранных данных. Обсуждение статуса разработки и **финансирования проекта**.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitry Grankin', 'Slawa Kister']},
#   {'meeting_id': 'dbf8ad27-649c-4a16-b5a1-5ab3db002bd9',
#    'meeting_name': 'Маркетинг и стратегии продаж',
#    'timestamp': '2024-09-13T15:15:37.764000',
#    'is_indexed': True,
#    'meeting_summary': 'Обсуждение **текущих подходов** к **маркетингу** и **продажам**, включая использование **Google AdWords** и **Facebook Ads**. Дмитрий Чистов делится опытом использования **Google AdWords**, упоминая о необходимости пересмотра **стратегии** и поиска **целевой аудитории**. Обсуждаются **методы привлечения трафика** на **лендинг-пейджи**, проблемы с **продуктом** и его **позиционированием** на рынке, а также **стратегии создания лендинг-пейджей**. Также рассматривается **анализ конкурентов**, **планирование дальнейших шагов** по улучшению продукта и его маркетинга, а также использование **LinkedIn** для аутрича.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitrii Chistov', 'Dmitry Grankin']},
#   {'meeting_id': '7973854d-ce5a-4263-b0f5-74007ea7a630',
#    'meeting_name': 'Проблемы и улучшения системы',
#    'timestamp': '2024-11-15T14:32:26',
#    'is_indexed': True,
#    'meeting_summary': 'Обсуждение **проблем с индексацией встреч**, включая необходимость дождаться завершения индексации для получения актуальной информации. Рассмотрены **проблемы с платежами** и необходимость их решения. Обсуждены **идеи по улучшению функционала дашборда**, включая возможность логина и логаута. Обсуждены **планы по маркетингу** и запуску рекламы на Product Hunt. Обсуждение **пользовательского опыта** и фидбека от пользователей о системе. Рассмотрены **проблемы с отображением дат** и необходимость улучшения интерфейса. Обсуждение **стратегии позиционирования** продукта и его преимуществ.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin', 'Olga Nemirovskaya']},
#   {'meeting_id': 'ed953dc9-002d-4202-905e-269cc982a3f3',
#    'meeting_name': 'Создание экосистемы для дизайнеров',
#    'timestamp': '2024-09-30T15:35:51',
#    'is_indexed': True,
#    'meeting_summary': 'Обсуждение **важности создания впечатления** на ранних стадиях проектов и как **дизайн** может помочь в этом. **Татьяна** подчеркивает, что создание впечатления критически важно, и дизайн играет ключевую роль в этом процессе. **Дмитрий** объясняет концепцию **SAFE** и как можно использовать свои услуги вместо денег для получения **акций стартапов**, что может быть выгодно для дизайнеров. Обсуждение возможности создания **экосистемы** для дизайнеров, работающих по **бартерной модели**. Татьяна делится своим опытом работы с **логотипами** и страхами, связанными с конкурсами. Обсуждение текущих **проблем с финансированием** и возможных решений через бартерные модели. Обсуждение **дизайн-систем** и необходимости разработки их для стартапов.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin', 'Tatiana Sukhova']},
#   {'meeting_id': '40001390-7187-47a7-9284-a1dab5dc0df6',
#    'meeting_name': 'Форматы вебинаров и мастер-классов',
#    'timestamp': '2024-09-05T18:45:16.340000',
#    'is_indexed': True,
#    'meeting_summary': 'Обсуждение **оптимального количества участников** для **вебинаров** и **мастер-классов** для обеспечения **вовлеченности** и **обратной связи**. Оптимальное количество участников для вебинаров - **3-10 человек**. Обсуждение необходимости **разделения участников** на группы по интересам для более эффективного общения. Разработка формата **взаимодействия** с участниками после мастер-классов, включая **серии практических воркшопов**. Идея разработки **продукта для транскрибирования** и анализа звонков для **корпоративных клиентов** с акцентом на **безопасность** и **контроль данных**. Обсуждение **снижения конверсий** и **регистраций** пользователей, необходимость анализа причин. Разработка стратегии **email-рассылок** для активных пользователей. Поиск информации о **хакатонах** и **акселераторах** для участия.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin', 'Olga Nemirovskaya']},
#   {'meeting_id': '04de7398-49fd-4a57-962f-2798fc080b04',
#    'meeting_name': 'Рекламные кампании и таргетинг',
#    'timestamp': '2024-09-26T14:00:39',
#    'is_indexed': True,
#    'meeting_summary': 'Обсуждение **результатов рекламных кампаний** Google Ads, запущенных **20 августа**, с акцентом на **конверсии** и **целевые действия**. Рассмотрение **необходимости настройки таргетинга** на англоязычные страны для повышения эффективности рекламы. Планы по запуску рекламы по **брендовым запросам**, включая **Google Meet**, для привлечения целевой аудитории. Обсуждение **проблем с модерацией рекламы** в Facebook, особенно в преддверии американских выборов. Рассмотрение возможностей **ретаргетинга** для улучшения конверсий и привлечения клиентов.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin', 'Olga Nemirovskaya', 'Сергей Жилко']},
#   {'meeting_id': 'd894ee56-d144-4cd5-8c2c-74de222a6b31',
#    'meeting_name': 'Стартап и SEO: стратегии и инструменты',
#    'timestamp': '2024-10-03T09:00:34',
#    'is_indexed': True,
#    'meeting_summary': '**Дмитрий** начал развивать свой **стартап** и ищет способы улучшить **маркетинг**, включая взаимодействие с **SEO-специалистами**. Обсуждается **публикация статей** и использование **Surfer SEO** для анализа контента. **Оля** предлагает создать инструмент для **анализа звонков** и обучения сотрудников в **продажах**. Обсуждаются возможности использования **AI** для генерации контента и его оптимизации, включая использование **Humanizer** для улучшения качества статей. Также рассматриваются важные аспекты **SEO**, такие как **внутренняя перелинковка** и **авторитет домена**.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin', 'Olga Mykhoparkina']},
#   {'meeting_id': 'c450ea95-dc3b-4bf8-9e47-1d4f7b99e6b7',
#    'meeting_name': 'Стартапы и легализация врачей',
#    'timestamp': '2024-09-27T12:34:46',
#    'is_indexed': True,
#    'meeting_summary': 'Дмитрий и Игорь обсуждают **переезд** и **жизнь в разных странах**, таких как **Кипр** и **Португалия**, делятся опытом и **плюсами и минусами** жизни в этих местах. Дмитрий делится идеей своего **стартапа** по **транскрибированию встреч** в реальном времени, обсуждает **маркетинг** и **привлечение пользователей**. Игорь рассказывает о своем бизнесе, который помогает **врачам легализоваться в Эмиратах**, включая подготовку к экзаменам и помощь с документами. Также обсуждаются планы по созданию **сообщества для предпринимателей** и форматы встреч.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitry Grankin', 'Igor Vinidiktov']},
#   {'meeting_id': '288381d0-3ca7-4601-99b9-b42da8cd30d3',
#    'meeting_name': 'Функционал дэшборда и ассистента',
#    'timestamp': '2024-08-27T17:42:20',
#    'is_indexed': True,
#    'meeting_summary': 'Обсуждение **механизма фильтрации** в дэшборде, включая **выбор спикера**, **теги** и **диапазон дат** для удобства пользователей. Разработка **функционала выбора субсета встреч** для целенаправленного общения. Создание **интерфейса навигации** по звонкам с фильтрами по дате и спикерам. Оптимизация **поиска** по звонкам и транскриптам для быстрого доступа к информации. Создание **отчетов по активности спикеров** и интеграция с **платежными системами** для управления подписками. Обсуждение **дизайна лендинга** и **цветовой палитры** для маркетинга.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Alex Shevliakov', 'Dmitriy Grankin', 'Olga Nemirovskaya']},
#   {'meeting_id': 'ab27bb1f-93d5-4500-9865-6f5de4d433ea',
#    'meeting_name': 'Переход на новый dashboard и интеграции',
#    'timestamp': '2024-11-04T16:52:05',
#    'is_indexed': True,
#    'meeting_summary': 'Необходимы **нормальные локальные счета** и **работающий векторный поиск** для перехода на новый **dashboard**. Требуется **отладка Threads** и расширение **контекста** для поиска. Планируется работа с **интеграциями** и **email-маркетингом**, включая **регулярные посты** по маркетингу, минимум один пост в неделю. Обсуждается использование **VEX** для создания нормального локального счета и поиска, а также необходимость создания **контекстного summary** из **глобального индекса**.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin']},
#   {'meeting_id': 'e6ce439d-5802-4914-8271-4fbcea74ee94',
#    'meeting_name': 'Коробочные решения и анализ данных',
#    'timestamp': '2024-09-09T15:30:50.724000',
#    'is_indexed': True,
#    'meeting_summary': 'Обсуждение **коробочного решения** для компаний, позволяющего устанавливать **бэкэнд** в контуре организации для соблюдения **privacy concern**. Рассмотрение **анализа массивов текстов** для извлечения полезной информации и анализа конкурентов. Идея создания продукта для людей с ограничениями, включая **автоматическую транскрипцию** и перевод. Обсуждение **инвестиционных возможностей** для стартапов в области **HR** и **психологического тестирования**. Обсуждение **программного обеспечения** для **транскрипции** и **анализа данных** в реальном времени.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitry Grankin', 'Tatiana Illarionova-Zervas']},
#   {'meeting_id': 'db0e1e1a-8c83-4d8d-8ac5-c7d4a8264242',
#    'meeting_name': 'Интерфейс ассистента и дашборд',
#    'timestamp': '2024-09-12T10:00:07.800000',
#    'is_indexed': True,
#    'meeting_summary': 'Обсуждение **текущего состояния интерфейса** ассистента и его **функционала**, включая возможность **редактирования summary** и **автоматизации follow-up действий**. **Планирование разработки дашборда** с учетом **визуальных компонентов** и **логики**. Идеи по **автоматизации обработки звонков** и созданию **артефактов** на их основе. Обсуждение необходимости **разделения маркетинга и разработки** для повышения эффективности. Обсуждение текущих подходов к **продвижению и маркетингу**, включая использование **социальных сетей**.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Alex Shevliakov', 'Dmitry Grankin']},
#   {'meeting_id': '06e239a1-dbc9-4e3d-968c-a307f30c0adc',
#    'meeting_name': 'Установление контакта и сбор обратной связи',
#    'timestamp': '2024-10-09T12:06:01.180000',
#    'is_indexed': True,
#    'meeting_summary': 'Основная задача - **установить контакт** с пользователями, чтобы задать им вопросы о **ценности продукта** и их **ожиданиях**. Планируется **отправка писем** пользователям, с которыми нет уверенности в контакте, для сбора информации о их опыте использования. Необходимо **собрать обратную связь** через переписки и звонки, чтобы понять разницу между **ожидаемой и фактической ценностью**. Также обсуждается **анализ юзкейсов** и **проблемы с анбордингом** новых пользователей. Разработка стратегии **outreach** для связи с пользователями и **анализ конверсии** с лендинга также являются важными темами. Обсуждается возможность **публикации на платформе Early Birds** для привлечения новых пользователей.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin', 'Olga Nemirovskaya']},
#   {'meeting_id': '1c71070f-4427-4aae-ace0-2091f70dec5b',
#    'meeting_name': 'Оптимизация рабочего процесса и фриланс',
#    'timestamp': '2024-09-17T09:26:34',
#    'is_indexed': True,
#    'meeting_summary': 'Обсуждение **гибкости рабочего времени**, включая **фулл-тайм** и **фриланс** как оптимальный вариант, но с неуверенностью в необходимости полного рабочего времени. Рассмотрены **проблемы с дебаггингом**, включая трудности в воспроизведении ошибок и недостаточную квалификацию **тестировщиков**. Обсуждены методы **поиска фрилансеров** через знакомых и Telegram, а также негативный опыт с платформами, такими как **Upwork**. Обсуждение состояния **кода** и используемых технологий, необходимость использования современных фреймворков для оптимизации разработки. Рассмотрены аспекты **дизайна** и **UX**, их влияние на работу, а также проблемы с **фронт-энд** и **бэк-энд** разработкой.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Alex Shevliakov', 'Dmitriy Grankin']},
#   {'meeting_id': 'a2926b2d-f4eb-4bcc-864f-27607faa39fb',
#    'meeting_name': 'Обновление VEX и маркетинг',
#    'timestamp': '2024-08-30T17:04:58',
#    'is_indexed': True,
#    'meeting_summary': 'Обсуждение текущего состояния **VEX**, необходимость **обновления** и его функциональности. **Маркетинг** для привлечения новых клиентов, обсуждение стратегий и проблем с открытием **банковского счета** в США. **Управление активами** и налоговые стратегии для клиентов, а также идея создания **аудиокниг** с использованием технологий **генерации голоса** от **Eleven Labs**.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmtiry Grankin', 'Matt Lewis']},
#   {'meeting_id': 'cdf9078d-87e0-49cb-9b62-71596961f436',
#    'meeting_name': 'Training Course Development Strategy',
#    'timestamp': '2024-10-08T10:33:19',
#    'is_indexed': True,
#    'meeting_summary': "**Develop training courses** for **Search Chain's** **mobile** and **web applications**, focusing on **core functionalities** and **business processes**. Utilize **AI** to create engaging **training content**, improving upon basic outputs currently generated. Ensure training materials are produced in **SCORM format** for compatibility with **LMS systems**. Seek assistance in refining **prompt engineering** for AI-generated content. Plan follow-up meetings to discuss progress and refine AI outputs.",
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['David Sterry', 'Dmitry Grankin', 'Nadya Gorodetskaya']},
#   {'meeting_id': '8f275c86-e397-43fe-a884-b4535f7f82e3',
#    'meeting_name': 'Опыт в продажах и автоматизация',
#    'timestamp': '2024-11-26T15:01:52.630000',
#    'is_indexed': True,
#    'meeting_summary': 'AM делится своим **опытом** работы в **продажах**, акцентируя внимание на **зарубежных рынках** и подходах к **outreach**. DG представляет проект по **автоматизации звонков** в **Google Meet** с функцией **транскрипции** и **дашборда**. Обсуждаются **дальнейшие шаги** по **маркетингу**, включая обработку входящих запросов и улучшение системы. AM предлагает сформулировать **коммерческое предложение** и провести **тест** для оценки целевой аудитории.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Alisa Molokova', 'Dmitry Grankin']},
#   {'meeting_id': '5c63474d-b8a9-4e76-af92-a8d646097ae9',
#    'meeting_name': 'Работа над стартапом и проектами',
#    'timestamp': '2024-08-31T11:17:06',
#    'is_indexed': True,
#    'meeting_summary': 'Обсуждение текущей работы над **стартапом** и **личными проектами**, включая **планы по минимизации фриланса**. AS работает над **стартапом** и своим проектом, планирует уменьшить количество **фриланса**, чтобы сосредоточиться на более **бизнесовых задачах**. DG обсуждает возможность **совместной работы**. Обсуждение выделения **времени для работы** над проектами и возможного **бронирования часов**. AS и DG обсуждают **дизайн** и **функционал продукта**, включая **доработки** и **маркетинг**. Обсуждение **проблем с фулл-тайм сотрудниками** и их влияния на **стартап**. Планирование разработки **дэшборда** и интеграции **платежной системы**. Обсуждение **онбординга пользователей** и его улучшения. Необходимость обновления **логотипа** и **значка** для продукта. Использование **инструментов** для записи и **промоушена**, таких как **Screen Studio**.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Alex Shevliakov', 'Dmtiry Grankin']},
#   {'meeting_id': 'bdc05628-4278-4cda-9395-49906c348d7d',
#    'meeting_name': 'SEO Tools and Content Strategies',
#    'timestamp': '2024-10-01T09:18:00',
#    'is_indexed': True,
#    'meeting_summary': '**Testing search queries** for **influencer marketing articles** to generate optimized content. **Benchmarking content optimization tools** like **Surfer SEO** to improve article performance. **Creating articles based on scraped data** and updating old articles for better ranking. **Identifying keywords for SEO** and discussing the potential market for SEO tools. **Exploring pricing strategies** for SEO tools and iterating on the content creation process based on feedback and performance metrics. **Emphasizing the importance of content quality, optimization, and effective use of APIs** in the content development process.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin', 'Rick Tousseyn']},
#   {'meeting_id': 'b8880903-8d2c-4924-b6a8-64f73b8b52ad',
#    'meeting_name': 'AI Marketing Strategies and Collaborations',
#    'timestamp': '2024-10-10T18:45:30',
#    'is_indexed': True,
#    'meeting_summary': "**AI Marketing Directory** provides a **curated directory** of **AI business tools** and a **backend content service** primarily on **Twitter**, aiming to expand to other platforms. The company operates a **network of influencers** who share content related to **AI tools**, maximizing exposure for their partners. The **influencer marketing strategy** involves **paying influencers** to repost content, leveraging their larger followings to increase visibility. Successful campaigns include **Hautech**, while **Quick Blocks** faced challenges due to misalignment with the target audience. The focus is on **optimizing for clicks** while ensuring that campaigns lead to **sales conversions**. The service is offered at **$149 per month**, including multiple promotional threads for clients' products. Follow-up communication will be conducted via **LinkedIn** to finalize details and initiate collaboration.",
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['AI Marketing Directory', 'Dmitry Grankin', 'Ethan Noah']},
#   {'meeting_id': '553fcfe6-0143-4971-99e7-213245f63347',
#    'meeting_name': 'Оптимизация Vexa и новые идеи',
#    'timestamp': '2024-10-30T14:13:33',
#    'is_indexed': True,
#    'meeting_summary': 'Обсуждение **производительности фронтенда**, включая **синхронность** и **оптимизацию кода**. Планирование **доработки Vexa Multi Assistant** для улучшения функционала. Идея создания **white label версии** для юристов. Обсуждение возможности проведения **курсов по Vexa**. Планирование **роутинга** для нового функционала. Упоминание о **мобильной версии** продукта и его использовании в **судебных заседаниях**. Обсуждение **документов**, **инженерных навыков**, **прототипирования**, **маркировки**, **лайфкодинга** и **дизайн системы**.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin', 'Sergey Ryabenko']},
#   {'meeting_id': '37769a4e-fd8d-4193-8a91-f001a16649b2',
#    'meeting_name': 'Оптимизация фронтенда и бэкенда',
#    'timestamp': '2024-11-03T12:26:49',
#    'is_indexed': True,
#    'meeting_summary': 'Обсуждение **оптимальных решений** для **фронтенда** с целью **повышения эффективности** работы. **Дмитрий** предложил рассмотреть различные подходы, включая **парное программирование** и использование **Replit** для совместной работы. Также была обсуждена **необходимость публикации** текущей версии **бэкенда** на **NGX**. Обсуждались **методы работы с API** для получения данных о **встречах** и необходимость **обновления методов API** для корректной работы с фронтендом. Участники обсудили **подключение по SSH** и использование **токенов** для авторизации. В завершение, обсуждались аспекты **интеграции** и **коллаборации** в процессе разработки.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin', 'Sergey Ryabenko']},
#   {'meeting_id': '5e8bf76a-a7cf-4507-acd5-1e1d25152ded',
#    'meeting_name': 'Юзкейсы и оптимизация контента',
#    'timestamp': '2024-10-02T11:00:52',
#    'is_indexed': True,
#    'meeting_summary': 'Обсуждение актуальных **юзкейсов** для **ассистента**, включая **создание контента** для **LinkedIn**. Участники делятся **методами оптимизации** процесса создания контента и **улучшения качества** публикаций. Обсуждаются **проблемы** с качеством текстов и видео, а также **цели** использования LinkedIn для развития **социального капитала**. Рассматриваются **идеи** для публикаций и контента, а также **сложности** интеграции новых продуктов в компании.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Angelina Geru', 'Dmitry Grankin']},
#   {'meeting_id': '3be31222-1a97-4042-b613-e5b6234789a0',
#    'meeting_name': 'Стратегии маркетинга и SEO',
#    'timestamp': '2024-10-03T17:02:45',
#    'is_indexed': True,
#    'meeting_summary': 'Обсуждение **использования Vexus** для **автоматического создания краткого содержания** встреч с клиентами. **Маркетинговые стратегии** в Бразилии через **инфлюенс-маркетинг**. Разработка **SEO-стратегий** для увеличения трафика на сайт, включая **Programmatic SEO**. Проблемы с **открытием счета в Interactive Brokers**. Необходимость **создания контента и видео** для привлечения клиентов. Улучшение сайта для повышения **конверсии**.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin', 'Matt Lewis']},
#   {'meeting_id': '6e6e65ac-b626-4326-aab4-f2a8e9b0cdef',
#    'meeting_name': 'Разработка ассистента для звонков',
#    'timestamp': '2024-09-13T16:03:22',
#    'is_indexed': True,
#    'meeting_summary': 'Создание **ассистента** для **транскрибирования звонков** в реальном времени, который будет накапливать **знания** для улучшения качества последующих звонков. Формирование **базы знаний** на основе **транскриптов** и других артефактов, полученных из контекста разговоров. Создание новых **артефактов** (диаграмм, планов) на основе обсуждений во время звонков. Анализ **системы коммуникации** в организации для управления потоками информации и задач. Использование **искусственного интеллекта** для автоматизации и оптимизации **бизнес-процессов**. Разработка программ **обучения** для новых сотрудников и внедрение регламентов.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin', 'Александр Мелихов']},
#   {'meeting_id': '27959f97-ea15-48cb-87c8-88a5dce99da9',
#    'meeting_name': 'MVP and AI Course Development',
#    'timestamp': '2024-10-10T15:18:01.363999',
#    'is_indexed': True,
#    'meeting_summary': '**MVP Viability**: The product is viable for **training construction personnel**, but clarity on the **MVP concept** is needed. **AI Course Creation**: Explored the use of **AI for course creation** and potential alternatives to **ChatGPT**. **User-Friendly Interface**: Aim to develop a **user-friendly interface** for training courses, recognizing the complexity of the current interface. **Project Kickoff Details**: Outlined the **project kickoff** and **training course formats**, including **mobile and web app training** in **SCORM format**. **SCORM Format Importance**: Discussed the significance of **SCORM format** for compatibility with **LMS systems**. **Training Completion Tracking**: Emphasized the need for tracking **user training completion** and scores for approximately **5,000 users**. **Presentation Quality Improvement**: Focus on improving the quality of **presentation outputs**. **Graphics and Storytelling Integration**: Suggested integrating **graphics and storytelling** in training materials. **Alignment with Existing Materials**: Importance of aligning training content with existing materials. **Iterative Improvement Process**: Adopted an **iterative approach** to improve training materials.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['David Sterry', 'Dmitriy Grankin', 'Nadya Gorodetskaya']},
#   {'meeting_id': '2647ed9b-411e-46dc-ba53-c08ef2887479',
#    'meeting_name': 'Идеи по стартапам и токенизации',
#    'timestamp': '2024-10-18T15:23:30',
#    'is_indexed': True,
#    'meeting_summary': 'Обсуждение функционала нового **ассистента** для **звонков**, который записывает **аудио** и **видео**, а также позволяет **искать** и **фильтровать** звонки. Рассмотрены **планы** по стартапу в **Португалии**, где один из участников является **соло-фаундером**. Обсуждение **токенизации недвижимости** для упрощения доступа к инвестициям, а также использование **искусственного интеллекта** в **путешествиях**. Затронуты вопросы **гражданства** и жизни в **Аргентине** и **Португалии**, а также проблемы с реализацией **реального времени** в продукте. Обсуждены **планы** по улучшению функционала **VEX** и использование **криптовалют** в инвестициях.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin', 'Sergio Goriachev']},
#   {'meeting_id': 'b8fee8c4-a4d4-433d-a6bb-0407fc93b1e6',
#    'meeting_name': 'Testowanie funkcjonalności systemu',
#    'timestamp': '2024-11-19T09:38:49',
#    'is_indexed': True,
#    'meeting_summary': '**Testowanie** działania **systemu** w celu **weryfikacji** jego **funkcjonalności**. W trakcie spotkania przeprowadzono **testy systemu**, aby upewnić się, że działa poprawnie. Zidentyfikowano kilka **obszarów do poprawy**, które będą wymagały dalszej **analizy**.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': []},
#   {'meeting_id': 'd44d0430-2754-428b-b934-9264c255578c',
#    'meeting_name': 'Тестирование и мониторинг системы',
#    'timestamp': '2024-11-25T19:45:31.970000',
#    'is_indexed': True,
#    'meeting_summary': '**Тестирование системы**: Проведение **тестов** для проверки работоспособности системы. Тестирование включает в себя проверку различных компонентов системы на наличие **ошибок** и **стабильность** работы. Важно завершить тестирование до следующей итерации разработки. **Мониторинг статуса**: Отслеживание статуса системы и компонентов. Необходимо следить за статусом всех элементов системы, чтобы обеспечить их корректную работу и своевременное выявление **проблем**. Ответственный за мониторинг - команда разработки. **Обновления системы**: Ожидание и проверка обновлений системы. Обновления должны быть проверены на наличие новых функций и исправлений. Важно, чтобы все обновления были протестированы перед внедрением в рабочую среду.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin']},
#   {'meeting_id': '1a7354c8-649d-4356-94dd-0da191c3f665',
#    'meeting_name': 'Тестирование функциональности системы',
#    'timestamp': '2024-11-05T09:37:45',
#    'is_indexed': True,
#    'meeting_summary': 'Проведено **тестирование** работы **системы** для **проверки** её **функциональности** и выявления возможных **проблем**. Участник проводит **тестирование**, чтобы убедиться в её **работоспособности**.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': []},
#   {'meeting_id': '5738f21e-7b78-41bc-84d9-cb0bbbc24c12',
#    'meeting_name': 'Тестирование системы после интервенции',
#    'timestamp': '2024-11-24T14:53:49',
#    'is_indexed': True,
#    'meeting_summary': 'Проведено **тестирование** работы **системы** после **интервенции** для проверки её **функциональности**. **Тестирование** было проведено для оценки работы **системы** после проведённых изменений. Результаты **тестирования** будут проанализированы для выявления возможных проблем. Обсуждение результатов **тестирования** **системы**, проведенного после **интервенции**.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': []},
#   {'meeting_id': '43d29176-30cc-480b-b9d6-7be2e17a8e98',
#    'meeting_name': 'Тестирование системы',
#    'timestamp': '2024-11-10T12:45:23',
#    'is_indexed': True,
#    'meeting_summary': 'Обсуждение текущего процесса **тестирования системы**. Участники подтвердили, что **тестирование системы** продолжается и идет по **плану**.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': []},
#   {'meeting_id': '5b4c727b-ef5a-4fc6-8ef3-eb24973c1f59',
#    'meeting_name': 'Проблемы с активными встречами',
#    'timestamp': '2024-11-14T16:19:10',
#    'is_indexed': True,
#    'meeting_summary': 'Проведение **тестирования системы** с выявлением **проблем**. Обсуждение **отсутствия активных встреч**, необходимость выяснить причины и найти решения для улучшения функционала.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin']},
#   {'meeting_id': '4a0c9029-26e0-42fe-bf61-ac3351e111b9',
#    'meeting_name': 'Тестирование функциональности системы',
#    'timestamp': '2024-11-10T11:22:28.830000',
#    'is_indexed': True,
#    'meeting_summary': 'Проведено **тестирование** работы **системы** для **проверки** её **функциональности** и **стабильности**. Участник проводит **тестирование**, чтобы проверить её **работоспособность**.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': []},
#   {'meeting_id': 'db7e69e1-35f4-4d8e-a018-1d6c705b1fe3',
#    'meeting_name': 'Проблемы интерфейса и криптовалюты',
#    'timestamp': '2024-09-10T13:31:10',
#    'is_indexed': True,
#    'meeting_summary': 'Обсуждение **использования криптовалюты** и **интерфейса**, включая **проблемы** с **пониманием баланса** в долларах и других валютах. Участники делятся опытом работы с **криптовалютами**, обсуждают **недостатки** текущих инструментов для записи встреч и фиксации договоренностей. Обсуждаются идеи по **улучшению интерфейса** для удобства пользователей и необходимость четкой записи результатов встреч.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin', 'Илья Дзенски']},
#   {'meeting_id': 'bf174837-0662-4226-90bf-ca18ad302ae6',
#    'meeting_name': 'Интеграция TLDV и ChatGPT для юристов',
#    'timestamp': '2024-09-13T11:30:15',
#    'is_indexed': True,
#    'meeting_summary': 'Обсуждение **использования TLDV** для **автоматической записи** и **создания резюме встреч**, что позволяет **экономить время** и **упрощает доступ** к информации. **TLDV** рассматривается как полезный инструмент для **юристов**, позволяющий сохранять записи **консультаций** и быстро находить нужную информацию. Обсуждение возможности **интеграции TLDV с ChatGPT** для создания **рекомендаций** на основе записей встреч. Также обсуждался **функционал нового продукта** для юристов, проблемы с **автоматическим включением TLDV**, возможности **голосового ввода**, и **планирование дальнейших встреч**.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin',
#     'Ilia Semukhin',
#     'Ilia Semukhin (Presentation)']},
#   {'meeting_id': 'a6df69fa-e4c8-4c41-8d13-084b173662a0',
#    'meeting_name': 'Проверка системы и новые таланты',
#    'timestamp': '2024-11-13T12:35:54',
#    'is_indexed': True,
#    'meeting_summary': '**Проверка системы**: **Проверка работы системы** и её **стабильности**. Дмитрий проверяет, как работает система и не возникли ли **проблемы** с клиентами. Обсуждается возможность **перезагрузки системы** для устранения неполадок. **Обсуждение клиентов**: **Обсуждение состояния клиентов** и их реакции на систему. Дмитрий говорит о том, что клиенты, вероятно, не переживают по поводу текущих проблем, и это может быть связано с их **стабильной работой**. **Появление нового таланта**: Обсуждение появления **нового таланта** в команде. Упоминается о новом таланте, который должен появиться в команде, но детали не раскрыты.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin']},
#   {'meeting_id': 'ce153bcd-ef3d-4d86-a4ef-0c04fd7073da',
#    'meeting_name': 'Тестирование вкуса и его необходимость',
#    'timestamp': '2024-11-10T13:48:03',
#    'is_indexed': True,
#    'meeting_summary': 'Обсуждение процесса **тестирования** вкуса продукта, цель которого - определить, какой **вкус** будет **потерян** в процессе. Участник задает вопрос о целесообразности **тестирования** и его влиянии на восприятие **вкуса**. **Потеря** вкуса рассматривается как результат **тестирования**.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': []},
#   {'meeting_id': '6cf0b989-5e9c-4a57-a058-8f6ac0ca8025',
#    'meeting_name': 'WordPress Setup and SEO Strategies',
#    'timestamp': '2024-10-03T18:06:11',
#    'is_indexed': True,
#    'meeting_summary': 'DG is **setting up a WordPress site** using **Elementor** for customization. RT recommends **installing SEO plugins** like **Rank Math** and **Yoast** for better website ranking. They discuss the importance of **schema markup** for SEO and how it helps Google understand the website better. DG expresses concerns about **website speed** and performance, and RT suggests using plugins like **WP Rocket** and **Cloudflare**. They also cover creating a **linking structure** for SEO, conducting **website audits**, and performing **keyword research**. The implications of **AI-generated content** on SEO are discussed, highlighting the need for human oversight. RT shares tools like **Screaming Frog** and **PageSpeed Insights** for website analysis and optimization.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin',
#     'Rick Tousseyn',
#     'Rick Tousseyn (Presentation)']},
#   {'meeting_id': '5ec3a4c7-f9ba-435d-92d8-6e35bcbbc6f7',
#    'meeting_name': 'Тестирование процесса и проблемы',
#    'timestamp': '2024-11-04T10:01:44',
#    'is_indexed': True,
#    'meeting_summary': 'Обсуждение текущего состояния **тестирования** и выявление возможных **проблем**. На встрече обсуждалось, что происходит в процессе **тестирования**, с акцентом на выявление **проблем** и улучшение процесса. Обсуждение связано с **тестированием**, возможно, программного обеспечения или другого процесса, чтобы понять, что происходит в системе.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': []},
#   {'meeting_id': '2c857770-ec80-47b0-bbe5-f35d01f35677',
#    'meeting_name': 'Тестирование функциональности системы',
#    'timestamp': '2024-11-14T11:17:03',
#    'is_indexed': True,
#    'meeting_summary': '**Проверка функциональности системы** в **тестовом режиме**. **Цель тестирования** - выявить возможные **ошибки** и убедиться в **корректной работе системы**. Ожидается, что тестирование пройдет в течение **дня**.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': []},
#   {'meeting_id': 'ce84fa05-fe62-4484-8114-a1af9eed60e3',
#    'meeting_name': 'Тестирование работы системы',
#    'timestamp': '2024-11-15T14:18:11',
#    'is_indexed': True,
#    'meeting_summary': 'Основная цель встречи - **тестирование работы системы**, что повторялось несколько раз в ходе обсуждения. **Тестирование системы** включает в себя **проверку функциональности** и **стабильности**. Участники обсуждали различные аспекты **тестирования**, включая **готовность к тестированию** и **необходимость повторных проверок**.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin']},
#   {'meeting_id': '140b3e35-1fc9-4905-abb3-e608243a8543',
#    'meeting_name': 'Тестирование и индексация системы',
#    'timestamp': '2024-11-15T14:04:31',
#    'is_indexed': True,
#    'meeting_summary': '**Тестирование работы системы** продолжается, с акцентом на **выявление проблем** и **проверку функциональности**. **Дмитрий Гранкин** проводит тестирование системы, повторяя процесс несколько раз для проверки стабильности и функциональности. Обсуждаются **возможные проблемы**, которые могут возникнуть в процессе тестирования. Также обсуждается необходимость **снятия ограничений в индексации** для улучшения работы системы, что может повлиять на **производительность** и **эффективность индексации данных**. Дмитрий предлагает снять ограничения, чтобы система могла работать более эффективно, что может привести к улучшению производительности и устранению текущих проблем.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin']},
#   {'meeting_id': 'e77ea83e-fe07-4e8b-879b-2939f208775f',
#    'meeting_name': 'Тестирование работы системы',
#    'timestamp': '2024-11-01T12:34:48',
#    'is_indexed': True,
#    'meeting_summary': 'Обсуждение текущего состояния работы системы и выявление проблем. Участники обсуждают, что **система не работает должным образом** и требуется **время для тестирования**. Важно выяснить, как **система будет функционировать** после тестирования. Участники согласны **подождать некоторое время**, чтобы увидеть, как система будет работать после тестирования. Обсуждение текущего состояния **тестирования системы** и его результатов. Неясность в том, как **система работает или не работает**. Упоминание о необходимости **подождать какое-то время** для получения информации о работе системы.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': []},
#   {'meeting_id': 'c67de1f3-8677-4596-9dc0-831e11cac7fb',
#    'meeting_name': 'Проблемы сервера и оптимизация',
#    'timestamp': '2024-11-07T10:07:13',
#    'is_indexed': True,
#    'meeting_summary': 'Обсуждение **проблем с сервером**, который **не работает должным образом**. Необходимо провести **диагностику** и **устранить неполадки**. Также обсуждались **функционал глобального поиска** и его **оптимизация** для более **корректной и быстрой работы**. Проведение **дебага и тестирования** для выявления ошибок в приложении. Обсуждение **разработки интерфейса чата** и его **улучшения**. Рассмотрены **проблемы с подключением** и их влияние на **производительность** приложения.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin', 'Sergey Ryabenko']},
#   {'meeting_id': '8ff59e4c-7cf3-444d-88bc-c6b25392e3e2',
#    'meeting_name': 'Дебаг и интеграция локального чата',
#    'timestamp': '2024-11-06T15:42:37',
#    'is_indexed': True,
#    'meeting_summary': 'Необходимо провести **дебаг** **локального чата**, чтобы устранить текущие проблемы с его работой. Локальный чат должен работать аналогично **глобальному**, с использованием **thread id**. Обсуждались изменения в **API**, которые необходимы для корректной работы локального чата. Также необходимо создать и протестировать новые функции, такие как интеграция с **Google аутентификацией** и создание **лендинга** для чата. Обсуждались проблемы с **токенами**, которые мешают доступу к необходимым функциям, и планирование дальнейших шагов по интеграции новых функций и исправлению ошибок.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin', 'Sergey Ryabenko']},
#   {'meeting_id': '0c743875-dd3b-498c-ada8-6b75d45542ed',
#    'meeting_name': 'Индексация и функционал чата',
#    'timestamp': '2024-11-20T16:40:18',
#    'is_indexed': True,
#    'meeting_summary': 'Обсуждались **текущая настройка индексации** и **работа чата**, включая **необходимость улучшения функционала**. **Индексация** пока не настроена, необходимо доработать **функционал чата** для более удобного использования. Также обсуждались **проблемы с отображением тредов** в интерфейсе, **задача создания нового чата** и его функционала, использование **контекста** для улучшения запросов, а также **дебаг** и улучшение функционала чата.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Artem Puzik', 'Dmitriy Grankin']},
#   {'meeting_id': 'f7515f24-af43-4f07-9932-21255978d204',
#    'meeting_name': 'Spring Goal Synchronization and Updates',
#    'timestamp': '2024-09-12T09:16:15.900000',
#    'is_indexed': True,
#    'meeting_summary': 'The team discussed the need to **synchronize** their **progress** towards the **spring goal**, even though a specific goal was not defined. The primary goal is to **publish the 9.1 extension**, which is ready for release. **Karine** reported **critical bugs** in **build 9.1.0** that need to be addressed before the release, including **buttons not being fully visible**. **Dmitry** provided an update on the **research** for **fully aware agents**, indicating successful replication of the flow from previous projects. The team plans to start collaborating with **UX designer Alexey** to enhance the user experience. **Xut** provided an update on the **physical replica of the Postgres database**, indicating it is functioning as intended.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitry Grankin',
#     'Karine Stepanyan',
#     'Sergey Ryabenko',
#     'Xut tuX']},
#   {'meeting_id': '3540f190-1f83-4100-8d6f-e648752f336d',
#    'meeting_name': 'LinkedIn Lead Generation Strategies',
#    'timestamp': '2024-09-26T12:02:02',
#    'is_indexed': True,
#    'meeting_summary': 'The meeting focused on **lead generation via LinkedIn**, discussing its effectiveness as a primary channel for outreach. **Dmitry** expressed the need for a more strategic approach, noting that immediate networking has become **exhausting** and **not scalable**. **Andy** raised concerns about **Google Ads**, highlighting the **non-linear** nature of marketing and the difficulty in finding effective strategies. **Competitor analysis** was conducted, identifying key players like **Otter.ai**, **Fireflies**, and **Fathom**. The potential to target **larger companies** by addressing **data security** and **privacy concerns** was discussed, along with the importance of **content creation** for LinkedIn, particularly engaging **video content**. The use of **Google Keyword Planner** for identifying relevant keywords was also emphasized, alongside the need for **ad copy** and **landing page testing** to optimize conversion rates.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Andy Black', 'Dmitry Grankin']},
#   {'meeting_id': '71b06f9d-518a-4bf6-98f6-ba3492f918a6',
#    'meeting_name': 'Момент появления объекта',
#    'timestamp': '2024-11-19T10:01:29',
#    'is_indexed': True,
#    'meeting_summary': "Обсуждение **времени** появления **объекта**. Подтверждено, что **объект** появляется **сразу**, что важно для дальнейших действий. Уточняется, что **'она'** появляется **немедленно**.",
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': []},
#   {'meeting_id': 'fb2aea72-f75d-4790-99dc-bbc4c7219a31',
#    'meeting_name': 'Стратегия продвижения в соцсетях',
#    'timestamp': '2024-10-04T16:17:26',
#    'is_indexed': True,
#    'meeting_summary': 'Обсуждение **стратегии** по **взаимодействию** с **продакхантером** в **LinkedIn**, включая **отправку сообщений** и **создание постов**. **Планирование** публикации постов в **Instagram** и **TikTok** на **португальском** и **бразильском** языках. Анализ **конкуренции** в **Бразилии** и отсутствие активных конкурентов. Проблемы с **email-рассылкой** и ее **неэффективностью**. Вопросы соблюдения **GDPR** и **комплаенса**. Сбор **отзывов** от пользователей и их значимость.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin', 'Olga Nemirovskaya']},
#   {'meeting_id': 'dd65ab42-1870-4158-9e2a-276fa5bda674',
#    'meeting_name': 'Создание скрипта для контакт-центра',
#    'timestamp': '2024-10-10T16:34:37',
#    'is_indexed': True,
#    'meeting_summary': 'Обсуждение **разработки скрипта** для **первого звонка** в **контакт-центре**, включая **анализ звонков** для создания текстов, **использование AI** для обработки данных, **фильтрацию звонков** по качеству, **разработку MVP**, **интеграцию с API**, **оптимизацию работы с аудиофайлами**, и создание **обучающего материала** для операторов. Участники обсуждают **промпт-инжиниринг** и **модель AI** для улучшения взаимодействия с клиентами.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin', 'Igor Bessonov']},
#   {'meeting_id': 'a88412e4-3df6-4c31-92d7-78b354c741bc',
#    'meeting_name': 'Тестирование и алгоритм индексации',
#    'timestamp': '2024-11-10T18:59:16',
#    'is_indexed': True,
#    'meeting_summary': 'Обсуждение **тестирования** системы **шерстных**, необходимость дальнейших **тестов**. **Разработка** **алгоритма индексации** для системы, учитывающего состояния **завершенности** и **индексации**.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin']},
#   {'meeting_id': '54b5c296-4fa6-4708-bf90-e4524485b7a7',
#    'meeting_name': 'Разработка стартапа и AI-решения',
#    'timestamp': '2024-11-19T12:32:14',
#    'is_indexed': True,
#    'meeting_summary': '**Дмитрий** делится **прогрессом** в разработке своего **стартапа**, упоминая, что работа почти завершена, но есть еще некоторые **недоработки**. Он сталкивается с **трудностями** в **найме разработчиков**, что влияет на эффективность работы. **Дмитрий** делится опытом использования **AI** для ускорения процесса разработки и улучшения качества кода. **Татьяна** интересуется возможностью использования готовой **дизайн-системы** в проекте и обсуждает **интерфейс** приложения, отмечая необходимость улучшения некоторых элементов. Также **Татьяна** планирует **звонки** с участниками и обсуждает, как лучше организовать информацию о них.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin', 'Tatiana Sukhova']},
#   {'meeting_id': '081d04c6-827d-4375-af68-9f8fbd50b707',
#    'meeting_name': 'Конкуренция и развитие продукта',
#    'timestamp': '2024-09-10T12:01:58',
#    'is_indexed': True,
#    'meeting_summary': 'Обсуждение **конкуренции** с **Google** и **Zoom** в области **транскрипции** и **ассистентов** для видеозвонков. Участники отметили, что **Google** активно развивает свои продукты, создавая **конкуренцию**. Обсуждение **разработки интерфейса** и **UX**, который должен быть **удобным** и **интуитивно понятным** для пользователей. Обсуждение **проблем** с **транскрипцией** и **идентификацией голосов** в видеозвонках, а также необходимость **интеграции платежных систем** для **монетизации** продукта. Участники согласились, что важно понимать **потребности пользователей** и возможные **юзкейсы** для создания востребованного продукта. Обсуждение идеи создания **кроссплатформенного решения** для интеграции с различными сервисами.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitry Grankin', 'Eugene Tartakovsky']},
#   {'meeting_id': '9178c8e7-da6a-4883-9fe1-cc4ee30125ea',
#    'meeting_name': 'Маркетинговая стратегия для Бразилии',
#    'timestamp': '2024-09-26T17:02:41',
#    'is_indexed': True,
#    'meeting_summary': 'Обсуждение **особенностей бразильского рынка** и подходов к **маркетингу**, включая важность **локализации** и адаптации контента. Участники согласились на создание **контент-календаря** для социальных медиа, включая **образовательный**, **промоционный** и **инфлюенсерский контент**. Также обсуждались **предпочтения целевой аудитории** и их поведение в социальных медиа, а также необходимость **проверки эффективности** кампаний с инфлюенсерами.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin', 'Lara Vargas', 'Olga Nemirovskaya']},
#   {'meeting_id': 'a2e2ecfb-f579-4f20-9ddb-54e3566ba67c',
#    'meeting_name': 'エンドツーエンドテストの実施',
#    'timestamp': '2024-11-23T13:42:11',
#    'is_indexed': True,
#    'meeting_summary': '**テストの実施**: **エンドツーエンドのプロセス**を確認するための**テスト**を実施する。テストは**システム全体の動作**を確認するために行われ、問題が発生した場合は**修正**が必要。**エンドツーエンドの確認**: **システムのエンドツーエンドの動作**を確認することが目的。全体の**フロー**が正しく機能しているかを確認し、必要に応じて**改善策**を講じる。**тестирование**: Процесс проверки и оценки системы или продукта. Обсуждение **тестирования** в контексте **end-to-end процессов**. **end-to-end**: Подход к **тестированию**, охватывающий все этапы процесса. Упоминание о **тестировании end-to-end** как методе проверки функциональности системы.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': []},
#   {'meeting_id': '3630910d-a5e8-4f83-8b4e-bc0094c3987a',
#    'meeting_name': 'Обновление интерфейса и кнопок',
#    'timestamp': '2024-09-06T12:51:35',
#    'is_indexed': True,
#    'meeting_summary': 'Обсуждение текущего состояния **интерфейса** и **кнопок**, выявление **проблем** с их **отображением** и **функциональностью**. Участники отметили, что **кнопки** сливаются в одно и требуют **улучшения**. Также обсуждены проблемы с **читаемостью** **хайлайтов**, которые плохо воспринимаются. Участники согласились на необходимость **обновления** старых **кнопок** и **баннеров**. Обсуждены проблемы с **разметкой** интерфейса и отображением элементов, а также текущее состояние **логов** и их визуального оформления.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Alex Shevliakov', 'Dmitriy Grankin']},
#   {'meeting_id': 'c789fe81-bde1-4d8c-9aad-2c3f64bc9c28',
#    'meeting_name': 'Использование VEX AI для кастдевов',
#    'timestamp': '2024-09-05T16:30:34',
#    'is_indexed': True,
#    'meeting_summary': 'Обсуждение **применения VEX AI** для **транскрибирования** и **анализа встреч** в реальном времени. Участники делятся **опытом использования VEX AI** для **улучшения качества встреч** и получения полезной информации из **транскриптов**. Идея о **создании сообщества пользователей VEX AI** для обмена опытом и инструментами. Обсуждение **проблем** в проведении **кастдевов** и важности **проверки гипотез** через **обратную связь**. Участники делятся методами **сбора и анализа обратной связи** для улучшения продукта.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Alex Loktev',
#     'Anastasiia GULIAEVA',
#     'Dmitriy Grankin',
#     'Oleg Maleev',
#     'Olga Nemirovskaya',
#     'Илья Дзенски']},
#   {'meeting_id': '52be5305-ba39-44ca-9296-743c6555b61e',
#    'meeting_name': 'Разработка Митинг ассистента и облака',
#    'timestamp': '2024-11-04T11:15:56',
#    'is_indexed': True,
#    'meeting_summary': 'Обсуждение **разработки** Митинг ассистента для **Google Meet**, который будет **записывать** и **транскрибировать** встречи. **Планируется** перенос сервиса с домашнего сервера в **облако** для повышения **надежности** и **доступности**. Также обсуждается создание **чата** с доступом к **погоде** с использованием **API**. Участники обсуждают **интеграцию** LLM в процесс **программирования** и подходы к использованию **AI** в разработке.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitry Grankin', 'Po/vlad/is', 'Sergey Ryabenko']},
#   {'meeting_id': 'bb3e6008-ba22-467d-8cc8-814053688378',
#    'meeting_name': 'Проблемы с регистрацией и Моторжок',
#    'timestamp': '2024-11-10T12:14:52.070000',
#    'is_indexed': True,
#    'meeting_summary': 'Обсуждение **проблем с регистрацией** пользователей в системе. Участники отметили, что некоторые пользователи снова сталкиваются с **проблемами регистрации**. Необходимо выяснить **причины** и предложить **решения**. Также обсуждалась **работоспособность системы Моторжок**. Важно подтвердить ее **работоспособность** для дальнейшей работы. Дима Торжок задавал вопросы о **работоспособности системы** и упоминал о **регистрации**.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': []},
#   {'meeting_id': '7318b825-93cd-4891-a136-b906edd9edd1',
#    'meeting_name': 'Подтверждение данных для резиденции',
#    'timestamp': '2024-11-21T15:30:18',
#    'is_indexed': True,
#    'meeting_summary': 'Обсуждены **даты и места рождения участников**, включая **родителей** и их **фамилии**. Необходимо **подтвердить паспортные данные** участников для подачи документов. Обсуждено **изменение заявки на резиденцию**, включая **подтверждение даты рождения родителей**. Обсуждены **документы**, которые необходимо предоставить для подачи на резиденцию. Обсужден **процесс получения номера резиденции** и его временные рамки. Обсуждение **способов оплаты** через банк для подачи документов, включая использование **MBWay**.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitriy Grankin', 'Estevao Barrote']},
#   {'meeting_id': '7122979f-9b4e-4d0f-92c7-18f6b1034197',
#    'meeting_name': 'Стартапы в AI и ипотека в Португалии',
#    'timestamp': '2024-09-09T16:31:30',
#    'is_indexed': True,
#    'meeting_summary': '**Макс** и **Дмитрий** обсуждают свои **стартапы**, включая **AI Travel Guide** и **real-time meeting assistant** для **Google**. **Макс** делится опытом получения **ипотеки** в **Португалии**, включая взаимодействие с банками и брокерами. **Дмитрий** дает советы по покупке **недвижимости** и анализирует **ипотечные ставки** и условия. Обсуждаются технологии для записи встреч и использование **гранолы** для транскрипции. Также затрагиваются темы **инвестиций** и **рынка недвижимости** в **Кашкайше** и **Белошколе**.',
#    'access_level': 'search',
#    'is_owner': True,
#    'speakers': ['Dmitry Grankin', 'Max Mironov']}]}

# %%
import pandas as pd

# %%
pd.DataFrame(result['meetings'])
# Out:
#                              meeting_id                          meeting_name  \
# 0  4ff12d56-f520-4391-a283-03d6365b49e6      Vexa Usability and User Insights
# 1  1be62b63-99ea-4aea-b284-a2ed45e44b82         Стратегия рекламы и аналитика
# 2  d7c8bfce-a97b-4f0e-ad22-f925cad1460d  Обсуждение погоды и бизнес-инициатив
# 3  c6bd2072-dcd6-45b9-8006-7b975bfe43ad        Увеличение видимости продуктов
# 4  2e36140e-e62e-4657-bbb4-a0473dbf608e  Разработка мультиязычного ассистента
# 5  dbf8ad27-649c-4a16-b5a1-5ab3db002bd9          Маркетинг и стратегии продаж
# 6  f5f969d6-675f-4d55-a604-78208e545dcd           Обсуждение улучшений VEX.ai
# 7  ed953dc9-002d-4202-905e-269cc982a3f3    Создание экосистемы для дизайнеров
#
#                     timestamp  is_indexed  \
# 0         2024-09-09T10:46:10        True
# 1         2024-10-08T11:25:03        True
# 2         2024-10-09T13:02:19        True
# 3         2024-10-04T11:09:37        True
# 4         2024-09-10T10:05:24        True
# 5  2024-09-13T15:15:37.764000        True
# 6         2024-09-16T15:35:38        True
# 7         2024-09-30T15:35:51        True
#
#                                      meeting_summary access_level  is_owner  \
# 0  Robert provided **positive feedback** on **Vex...       search      True
# 1  Обсуждение **приостановки Google Ads** и **тес...       search      True
# 2  Обсуждение текущей **погоды** в **Финляндии**,...       search      True
# 3  Обсуждение **текущего статуса продуктов** на *...       search      True
# 4  Обсуждение **разработки** мультиязычного **асс...       search      True
# 5  Обсуждение **текущих подходов** к **маркетингу...       search      True
# 6  Обсуждение **пользовательского опыта** с **VEX...       search      True
# 7  Обсуждение **важности создания впечатления** н...       search      True
#
#                                 speakers
# 0         [Dmitry Grankin, Robert Hangu]
# 1   [Dmitriy Grankin, Olga Nemirovskaya]
# 2  [Dmitriy Grankin, Nadya Gorodetskaya]
# 3   [Dmitriy Grankin, Olga Nemirovskaya]
# 4         [Dmitry Grankin, Slawa Kister]
# 5      [Dmitrii Chistov, Dmitry Grankin]
# 6       [Dmitriy Grankin, Ilia Semukhin]
# 7     [Dmitriy Grankin, Tatiana Sukhova]
